# %%
from matplotlib import pyplot as plt
import numpy as np
import os
import sys
sys.path.append(os.path.abspath(".."))
from scipy import stats
import pandas as pd
from v1.Utils import ReadTheCsv,ReadTheSpill,append_to_dict

# %% [markdown]
# # Load simulation outputs

# %%
files = os.listdir("../toy/output/")
#print(files)

outputs = ["toy/output/" + item for item in files if ".npz" in item]
print(outputs)

simulation_list = {}

for output in outputs:
    print(output)
    filename   = output.split("/")[2]
    tau        = output.split("_")[1].replace("s","")
    theta      = output.split("_")[3]
    axial      = output.split("_")[5].replace("mK","")
    transverse = output.split("_")[7].replace("mK","")
    append_to_dict(simulation_list, output, float(tau))
    append_to_dict(simulation_list, output, float(theta))
    append_to_dict(simulation_list, output, float(axial))
    append_to_dict(simulation_list, output, float(transverse))
# Out:
# ['toy/output/tau_33.27s_theta_65_axial_2.28mK_transv_4.88mK_p_2.npz', 'toy/output/tau_27.02s_theta_38_axial_1.63mK_transv_3.39mK_p_2.npz', 'toy/output/tau_46.36s_theta_103_axial_7.58mK_transv_6.06mK_p_2.npz', 'toy/output/tau_22.63s_theta_163_axial_3.61mK_transv_1.59mK_p_2.npz', 'toy/output/tau_26.20s_theta_29_axial_2.62mK_transv_5.84mK_p_2.npz', 'toy/output/tau_36.66s_theta_169_axial_0.60mK_transv_6.08mK_p_2.npz', 'toy/output/tau_40.46s_theta_36_axial_2.07mK_transv_4.32mK_p_2.npz', 'toy/output/tau_21.66s_theta_179_axial_2.40mK_transv_3.17mK_p_2.npz', 'toy/output/tau_44.95s_theta_51_axial_3.13mK_transv_5.54mK_p_2.npz', 'toy/output/tau_35.50s_theta_65_axial_2.09mK_transv_4.98mK_p_2.npz', 'toy/output/tau_31.70s_theta_173_axial_1.93mK_transv_3.80mK_p_2.npz', 'toy/output/tau_31.70s_theta_61_axial_0.73mK_transv_3.90mK_p_2.npz', 'toy/output/tau_17.02s_theta_57_axial_1.54mK_transv_5.12mK_p_2.npz', 'toy/output/tau_30.45s_theta_43_axial_1.76mK_transv_3.91mK_p_2.npz', 'toy/output/tau_18.07s_theta_123_axial_3.61mK_transv_3.07mK_p_2.npz', 'toy/output/tau_45.53s_theta_85_axial_8.39mK_transv_2.27mK_p_2.npz', 'toy/output/tau_32.09s_theta_39_axial_7.44mK_transv_4.37mK_p_2.npz', 'toy/output/tau_46.47s_theta_157_axial_2.86mK_transv_1.12mK_p_2.npz', 'toy/output/tau_63.08s_theta_81_axial_5.60mK_transv_3.56mK_p_2.npz', 'toy/output/tau_43.91s_theta_46_axial_1.71mK_transv_4.81mK_p_2.npz', 'toy/output/tau_34.15s_theta_67_axial_0.89mK_transv_4.65mK_p_2.npz', 'toy/output/tau_5.36s_theta_109_axial_0.93mK_transv_2.88mK_p_2.npz', 'toy/output/tau_40.68s_theta_150_axial_2.02mK_transv_8.01mK_p_2.npz', 'toy/output/tau_27.90s_theta_33_axial_3.40mK_transv_4.06mK_p_2.npz', 'toy/output/tau_36.70s_theta_48_axial_2.53mK_transv_2.61mK_p_2.npz', 'toy/output/tau_33.16s_theta_43_axial_2.10mK_transv_5.15mK_p_2.npz', 'toy/output/tau_29.72s_theta_43_axial_1.91mK_transv_4.63mK_p_2.npz', 'toy/output/tau_90.99s_theta_43_axial_0.85mK_transv_6.17mK_p_2.npz', 'toy/output/tau_23.70s_theta_38_axial_1.84mK_transv_5.39mK_p_2.npz', 'toy/output/tau_30.49s_theta_174_axial_1.92mK_transv_3.83mK_p_2.npz', 'toy/output/tau_9.82s_theta_20_axial_3.20mK_transv_2.41mK_p_2.npz', 'toy/output/tau_70.26s_theta_62_axial_4.75mK_transv_2.46mK_p_2.npz', 'toy/output/tau_36.79s_theta_26_axial_1.24mK_transv_4.40mK_p_2.npz', 'toy/output/tau_13.19s_theta_48_axial_1.56mK_transv_5.36mK_p_2.npz', 'toy/output/tau_52.93s_theta_159_axial_2.80mK_transv_3.97mK_p_2.npz', 'toy/output/tau_19.46s_theta_13_axial_9.80mK_transv_2.50mK_p_2.npz', 'toy/output/tau_38.99s_theta_152_axial_1.08mK_transv_2.71mK_p_2.npz', 'toy/output/tau_24.44s_theta_35_axial_1.98mK_transv_4.29mK_p_2.npz', 'toy/output/tau_46.02s_theta_113_axial_3.41mK_transv_3.72mK_p_2.npz', 'toy/output/tau_32.95s_theta_179_axial_1.93mK_transv_2.76mK_p_2.npz', 'toy/output/tau_58.27s_theta_100_axial_1.78mK_transv_0.94mK_p_2.npz', 'toy/output/tau_29.61s_theta_127_axial_6.83mK_transv_4.44mK_p_2.npz', 'toy/output/tau_24.86s_theta_46_axial_1.21mK_transv_4.56mK_p_2.npz', 'toy/output/tau_21.05s_theta_36_axial_1.90mK_transv_3.70mK_p_2.npz', 'toy/output/tau_31.41s_theta_46_axial_1.86mK_transv_4.74mK_p_2.npz', 'toy/output/tau_83.94s_theta_126_axial_3.03mK_transv_4.46mK_p_2.npz', 'toy/output/tau_17.19s_theta_31_axial_2.84mK_transv_3.08mK_p_2.npz', 'toy/output/tau_56.91s_theta_23_axial_9.84mK_transv_6.36mK_p_2.npz', 'toy/output/tau_31.76s_theta_140_axial_1.00mK_transv_9.26mK_p_2.npz', 'toy/output/tau_40.58s_theta_54_axial_0.53mK_transv_4.54mK_p_2.npz', 'toy/output/tau_78.00s_theta_75_axial_0.68mK_transv_1.41mK_p_2.npz', 'toy/output/tau_28.51s_theta_45_axial_2.41mK_transv_1.95mK_p_2.npz', 'toy/output/tau_18.48s_theta_23_axial_1.18mK_transv_4.31mK_p_2.npz', 'toy/output/tau_49.84s_theta_170_axial_4.80mK_transv_2.79mK_p_2.npz', 'toy/output/tau_34.60s_theta_34_axial_2.99mK_transv_5.01mK_p_2.npz', 'toy/output/tau_29.32s_theta_170_axial_2.34mK_transv_3.92mK_p_2.npz', 'toy/output/tau_71.97s_theta_5_axial_2.70mK_transv_2.48mK_p_2.npz', 'toy/output/tau_20.33s_theta_20_axial_1.88mK_tran ...
# toy/output/tau_33.27s_theta_65_axial_2.28mK_transv_4.88mK_p_2.npz
# toy/output/tau_27.02s_theta_38_axial_1.63mK_transv_3.39mK_p_2.npz
# toy/output/tau_46.36s_theta_103_axial_7.58mK_transv_6.06mK_p_2.npz
# toy/output/tau_22.63s_theta_163_axial_3.61mK_transv_1.59mK_p_2.npz
# toy/output/tau_26.20s_theta_29_axial_2.62mK_transv_5.84mK_p_2.npz
# toy/output/tau_36.66s_theta_169_axial_0.60mK_transv_6.08mK_p_2.npz
# toy/output/tau_40.46s_theta_36_axial_2.07mK_transv_4.32mK_p_2.npz
# toy/output/tau_21.66s_theta_179_axial_2.40mK_transv_3.17mK_p_2.npz
# toy/output/tau_44.95s_theta_51_axial_3.13mK_transv_5.54mK_p_2.npz
# toy/output/tau_35.50s_theta_65_axial_2.09mK_transv_4.98mK_p_2.npz
# toy/output/tau_31.70s_theta_173_axial_1.93mK_transv_3.80mK_p_2.npz
# toy/output/tau_31.70s_theta_61_axial_0.73mK_transv_3.90mK_p_2.npz
# toy/output/tau_17.02s_theta_57_axial_1.54mK_transv_5.12mK_p_2.npz
# toy/output/tau_30.45s_theta_43_axial_1.76mK_transv_3.91mK_p_2.npz
# toy/output/tau_18.07s_theta_123_axial_3.61mK_transv_3.07mK_p_2.npz
# toy/output/tau_45.53s_theta_85_axial_8.39mK_transv_2.27mK_p_2.npz
# toy/output/tau_32.09s_theta_39_axial_7.44mK_transv_4.37mK_p_2.npz
# toy/output/tau_46.47s_theta_157_axial_2.86mK_transv_1.12mK_p_2.npz
# toy/output/tau_63.08s_theta_81_axial_5.60mK_transv_3.56mK_p_2.npz
# toy/output/tau_43.91s_theta_46_axial_1.71mK_transv_4.81mK_p_2.npz
# toy/output/tau_34.15s_theta_67_axial_0.89mK_transv_4.65mK_p_2.npz
# toy/output/tau_5.36s_theta_109_axial_0.93mK_transv_2.88mK_p_2.npz
# toy/output/tau_40.68s_theta_150_axial_2.02mK_transv_8.01mK_p_2.npz
# toy/output/tau_27.90s_theta_33_axial_3.40mK_transv_4.06mK_p_2.npz
# toy/output/tau_36.70s_theta_48_axial_2.53mK_transv_2.61mK_p_2.npz
# toy/output/tau_33.16s_theta_43_axial_2.10mK_transv_5.15mK_p_2.npz
# toy/output/tau_29.72s_theta_43_axial_1.91mK_transv_4.63mK_p_2.npz
# toy/output/tau_90.99s_theta_43_axial_0.85mK_transv_6.17mK_p_2.npz
# toy/output/tau_23.70s_theta_38_axial_1.84mK_transv_5.39mK_p_2.npz
# toy/output/tau_30.49s_theta_174_axial_1.92mK_transv_3.83mK_p_2.npz
# toy/output/tau_9.82s_theta_20_axial_3.20mK_transv_2.41mK_p_2.npz
# toy/output/tau_70.26s_theta_62_axial_4.75mK_transv_2.46mK_p_2.npz
# toy/output/tau_36.79s_theta_26_axial_1.24mK_transv_4.40mK_p_2.npz
# toy/output/tau_13.19s_theta_48_axial_1.56mK_transv_5.36mK_p_2.npz
# toy/output/tau_52.93s_theta_159_axial_2.80mK_transv_3.97mK_p_2.npz
# toy/output/tau_19.46s_theta_13_axial_9.80mK_transv_2.50mK_p_2.npz
# toy/output/tau_38.99s_theta_152_axial_1.08mK_transv_2.71mK_p_2.npz
# toy/output/tau_24.44s_theta_35_axial_1.98mK_transv_4.29mK_p_2.npz
# toy/output/tau_46.02s_theta_113_axial_3.41mK_transv_3.72mK_p_2.npz
# toy/output/tau_32.95s_theta_179_axial_1.93mK_transv_2.76mK_p_2.npz
# toy/output/tau_58.27s_theta_100_axial_1.78mK_transv_0.94mK_p_2.npz
# toy/output/tau_29.61s_theta_127_axial_6.83mK_transv_4.44mK_p_2.npz
# toy/output/tau_24.86s_theta_46_axial_1.21mK_transv_4.56mK_p_2.npz
# toy/output/tau_21.05s_theta_36_axial_1.90mK_transv_3.70mK_p_2.npz
# toy/output/tau_31.41s_theta_46_axial_1.86mK_transv_4.74mK_p_2.npz
# toy/output/tau_83.94s_theta_126_axial_3.03mK_transv_4.46mK_p_2.npz
# toy/output/tau_17.19s_theta_31_axial_2.84mK_transv_3.08mK_p_2.npz
# toy/output/tau_56.91s_theta_23_axial_9.84mK_transv_6.36mK_p_2.npz
# toy/output/tau_31.76s_theta_140_axial_1.00mK_transv_9.26mK_p_2.npz
# toy/output/tau_40.58s_theta_54_axial_0.53mK_transv_4.54mK_p_2.npz
# toy/output/tau_78.00s_theta_75_axial_0.68mK_transv_1.41mK_p_2.npz
# toy/output/tau_28.51s_theta_45_axial_2.41mK_transv_1.95mK_p_2.npz
# toy/output/tau_18.48s_theta_23_axial_1.18mK_transv_4.31mK_p_2.npz
# toy/output/tau_49.84s_theta_170_axial_4.80mK_transv_2.79mK_p_2.npz
# toy/output/tau_34.60s_theta_34_axial_2.99mK_transv_5.01mK_p_2.npz
# toy/output/tau_29.32s_theta_170_axial_2.34mK_transv_3.92mK_p_2.npz
# toy/output/tau_71.97s_theta_5_axial_2.70mK_transv_2.48mK_p_2.npz
# toy/output/tau_20.33s_theta_20_axial_1.88mK_transv_3.70mK_p_2.npz
# toy/output/tau_37.11s_theta_159_axial_1.42mK_transv_2.13mK_p_2.npz
# toy/output/tau_96.87s_theta_42_axial_9.06mK_transv_8.99mK_p_2.npz
# toy/output/tau_34.60s_theta_142_axial_1.26mK_transv_0.81mK_p_2.npz
# toy/output/tau_85.38s_theta_164_axial_3.19mK_transv_5.73mK_p_2.npz
# toy/output/tau_60.01s_theta_134_axial_6.41mK_transv_3.97mK_p_2.npz
# toy/output/tau_9.27s_theta_46_axial_1.31mK_transv_4.53mK_p_2.npz
# toy/output/tau_15.73s_theta_24_axial_2.81mK_transv_2.76mK_p_2.npz
# toy/output/tau_53.62s_theta_160_axial_2.75mK_transv_3.17mK_p_2.npz
# toy/output/tau_17.08s_theta_162_axial_2.73mK_transv_3.43mK_p_2.npz
# toy/output/tau_32.36s_theta_153_axial_1.73mK_transv_1.63mK_p_2.npz
# toy/output/tau_19.28s_theta_73_axial_1.77mK_transv_3.57mK_p_2.npz
# toy/output/tau_48.39s_theta_32_axial_1.67mK_transv_4.82mK_p_2.npz
# toy/output/tau_75.30s_theta_27_axial_1.20mK_transv_7.60mK_p_2.npz
# toy/output/tau_65.24s_theta_136_axial_3.61mK_transv_2.55mK_p_2.npz
# toy/output/tau_24.97s_theta_35_axial_2.84mK_transv_3.85mK_p_2.npz
# toy/output/tau_14.22s_theta_21_axial_3.14mK_transv_2.39mK_p_2.npz
# toy/output/tau_27.21s_theta_152_axial_2.35mK_transv_2.95mK_p_2.npz
# toy/output/tau_22.47s_theta_16_axial_1.44mK_transv_5.48mK_p_2.npz
# toy/output/tau_38.08s_theta_74_axial_1.38mK_transv_4.74mK_p_2.npz
# toy/output/tau_14.00s_theta_135_axial_1.49mK_transv_2.11mK_p_2.npz
# toy/output/tau_26.19s_theta_34_axial_3.32mK_transv_3.84mK_p_2.npz
# toy/output/tau_16.79s_theta_10_axial_2.80mK_transv_2.75mK_p_2.npz
# toy/output/tau_31.98s_theta_28_axial_2.32mK_transv_7.96mK_p_2.npz
# toy/output/tau_11.72s_theta_153_axial_2.44mK_transv_3.20mK_p_2.npz
# toy/output/tau_7.40s_theta_118_axial_3.85mK_transv_7.06mK_p_2.npz
# toy/output/tau_23.07s_theta_97_axial_3.93mK_transv_2.32mK_p_2.npz
# toy/output/tau_34.52s_theta_87_axial_0.81mK_transv_3.72mK_p_2.npz
# toy/output/tau_26.81s_theta_173_axial_4.47mK_transv_3.51mK_p_2.npz
# toy/output/tau_24.54s_theta_42_axial_2.95mK_transv_3.62mK_p_2.npz
# toy/output/tau_28.42s_theta_8_axial_8.08mK_transv_6.33mK_p_2.npz
# toy/output/tau_39.01s_theta_40_axial_1.38mK_transv_4.60mK_p_2.npz
# toy/output/tau_23.04s_theta_140_axial_1.11mK_transv_2.19mK_p_2.npz
# toy/output/tau_29.30s_theta_66_axial_2.60mK_transv_4.16mK_p_2.npz
# toy/output/tau_58.14s_theta_97_axial_4.14mK_transv_4.15mK_p_2.npz
# toy/output/tau_86.14s_theta_127_axial_4.10mK_transv_4.91mK_p_2.npz
# toy/output/tau_30.69s_theta_51_axial_2.57mK_transv_5.71mK_p_2.npz
# toy/output/tau_28.17s_theta_34_axial_3.29mK_transv_2.41mK_p_2.npz
# toy/output/tau_36.01s_theta_52_axial_2.88mK_transv_3.00mK_p_2.npz
# toy/output/tau_35.02s_theta_153_axial_1.96mK_transv_3.45mK_p_2.npz
# toy/output/tau_42.88s_theta_148_axial_1.87mK_transv_5.29mK_p_2.npz
# toy/output/tau_25.79s_theta_171_axial_0.57mK_transv_1.86mK_p_2.npz
# toy/output/tau_10.71s_theta_25_axial_3.20mK_transv_2.37mK_p_2.npz
# toy/output/tau_15.88s_theta_165_axial_3.20mK_transv_4.43mK_p_2.npz
# toy/output/tau_28.26s_theta_7_axial_2.20mK_transv_3.37mK_p_2.npz
# toy/output/tau_9.52s_theta_17_axial_3.83mK_transv_1.86mK_p_2.npz
# toy/output/tau_28.65s_theta_163_axial_2.22mK_transv_3.24mK_p_2.npz
# toy/output/tau_21.52s_theta_57_axial_1.03mK_transv_4.71mK_p_2.npz
# toy/output/tau_24.94s_theta_26_axial_5.46mK_transv_3.49mK_p_2.npz
# toy/output/tau_31.65s_theta_37_axial_1.87mK_transv_4.33mK_p_2.npz
# toy/output/tau_42.33s_theta_60_axial_6.06mK_transv_5.24mK_p_2.npz
# toy/output/tau_36.76s_theta_166_axial_1.71mK_transv_3.14mK_p_2.npz
# toy/output/tau_9.49s_theta_17_axial_3.94mK_transv_2.41mK_p_2.npz
# toy/output/tau_19.59s_theta_22_axial_2.81mK_transv_2.71mK_p_2.npz
# toy/output/tau_24.44s_theta_35_axial_1.17mK_transv_4.02mK_p_2.npz
# toy/output/tau_97.31s_theta_177_axial_4.73mK_transv_4.16mK_p_2.npz
# toy/output/tau_50.72s_theta_116_axial_3.01mK_transv_4.63mK_p_2.npz
# toy/output/tau_39.98s_theta_30_axial_2.04mK_transv_4.27mK_p_2.npz
# toy/output/tau_76.80s_theta_52_axial_1.94mK_transv_2.94mK_p_2.npz
# toy/output/tau_40.33s_theta_166_axial_2.13mK_transv_4.18mK_p_2.npz
# toy/output/tau_20.88s_theta_179_axial_2.41mK_transv_9.95mK_p_2.npz
# toy/output/tau_42.93s_theta_12_axial_2.12mK_transv_4.17mK_p_2.npz
# toy/output/tau_33.37s_theta_36_axial_1.96mK_transv_4.61mK_p_2.npz
# toy/output/tau_52.82s_theta_147_axial_1.56mK_transv_3.21mK_p_2.npz
# toy/output/tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK_p_2.npz
# toy/output/tau_26.16s_theta_144_axial_2.38mK_transv_3.14mK_p_2.npz
# toy/output/tau_41.90s_theta_17_axial_0.96mK_transv_3.73mK_p_2.npz
# toy/output/tau_34.98s_theta_176_axial_2.10mK_transv_3.17mK_p_2.npz

# %% [markdown]
# ## Z cuts in 2025 dataset

# %%
mirG_center = -415
mirA_center = -671
zmin = mirA_center - 200
zgap_min = mirA_center
zmax = mirG_center + 200
zgap_max = mirG_center
CutsType = "CutsType2"

class Zcuts:
    def __init__(self,a,b, cuts):
        self.mirG_center = a
        self.mirA_center = b
        self.zmin = b - 200
        self.zmax = a + 200
        self.zgap_min = b
        self.zgap_max = a
        self.CutsType = cuts

ZCUTS = Zcuts(-415,-671, CutsType)

# %% [markdown]
# # Define the analysis functions for data and simulation

# %%
def analysis_function(output):
    file = np.load(output)
    R_array           = file['position']
    Time_Annihilation = file['Time']
    Time_Annihilation = Time_Annihilation[np.isfinite(Time_Annihilation)] # delete atoms that are still trapped, identified with 'nan'
    counts, edges     = np.histogram(Time_Annihilation, bins = 50, range = (0,398.1), density = False)
    return Time_Annihilation, counts, edges

def analysis_data(file, Zcuts):
    # read the file
    dataset = ReadTheCsv(file, "-1", Zcuts.zmin, Zcuts.zmax, ZCUTS.CutsType)
    # Three Segment Ramp Down
    start_mbmf_rampdown0, stop_mbmf_rampdown0 = ReadTheSpill(file,"\"MBMF RampDown\"[0]")
    start_mbmf_rampdown1, stop_mbmf_rampdown1 = ReadTheSpill(file,"\"MBMF RampDown\"[1]")
    start_mbmf_rampdown2, stop_mbmf_rampdown2 = ReadTheSpill(file,"\"MBMF RampDown\"[2]")

    # print(f"{start_mbmf_rampdown0[0] - start_mbmf_rampdown0[0]}; {stop_mbmf_rampdown0[0] - start_mbmf_rampdown0[0]} ")
    # print(f"{start_mbmf_rampdown1[0] - start_mbmf_rampdown0[0]}; {stop_mbmf_rampdown1[0] - start_mbmf_rampdown1[0]} ")
    # print(f"{start_mbmf_rampdown2[0] - start_mbmf_rampdown0[0]}; {stop_mbmf_rampdown2[0] - start_mbmf_rampdown2[0]} ")
    mask      = ((dataset[CutsType] == 1) & 
                (dataset["Z"] > ZCUTS.zmin) & 
                (dataset["Z"] < ZCUTS.zmax))
    mask_time = ((dataset["run time"] > start_mbmf_rampdown0[0]) & 
                 (dataset["run time"] < start_mbmf_rampdown0[0] + 398.1))

    Event_Distribution = dataset["run time"][mask & mask_time].to_numpy() - start_mbmf_rampdown0[0]
    X_distribution = dataset["X"][mask & mask_time].to_numpy()
    Y_distribution = dataset["Y"][mask & mask_time].to_numpy()
    Z_distribution = dataset["Z"][mask & mask_time].to_numpy()

    counts, edges = np.histogram(Event_Distribution, bins = 50, range = (0,398.1), density = False)
    
    return Event_Distribution, counts, edges

# %% [markdown]
# # Main Loop LR statitics and visualization

# %%
# !ls
# Out:
# Comparison.ipynb  simulation_results.png

# %%
list_dataset = ["v1/ag14100/ag14100.vertex.csv",
                "v1/ag14106/ag14106.vertex.csv",
                "v1/ag14268/ag14268.vertex.csv",
                "v1/ag14286/ag14286.vertex.csv",
                "v1/ag14308/ag14308.vertex.csv"]

best_for_dataset = []
best_sim         = ""
stringa          = ""

dict_runs = {}
for dataset in list_dataset:
    Event_Distribution, counts_obs, edges_obs = analysis_data("../" + dataset, ZCUTS)
    append_to_dict(dict_runs, dataset, counts_obs)

best_LR     = 1e6
best_pvalue = 0.0

for file in outputs:
    LR_total    = 0
    Pvalue_tot  = 0
    Time_Simulation, counts_sim, edges_sim =  analysis_function("../" + file)
    
    for dataset in list_dataset:        
        counts_obs    = dict_runs[dataset][0]
        counts_sim    = counts_sim * counts_obs.sum() / counts_sim.sum()
        
        LR, pvalue_lr = stats.power_divergence(counts_obs, counts_sim, lambda_="log-likelihood")
        LR_total     += LR
        Pvalue_tot   += -2*np.log(pvalue_lr)
        
        print(f"LR statistic = {LR:.4}/{(len(counts_obs) - 1)}")
        print(f"p-value      = {pvalue_lr}")

    if not np.isfinite(LR_total):
        LR_total    = 9999999
    
    if(LR_total < best_LR):
        print(f'New Best Found: [{file} {LR_total}]  [{best_sim} {best_LR}]')
        best_sim    = file
        best_pvalue = Pvalue_tot/5
        best_LR     = LR_total
        stringa     = f"Best LR: {LR_total:.5}/245, pvalue = {best_pvalue:.4}"


    append_to_dict(simulation_list, file, LR_total)
    
    print(f"best pvalue {best_pvalue}")
    print(f"best LR {best_LR}")
    print("-"*16)

print(best_sim)
best_for_dataset.append((best_sim, stringa))
# Out:
# ../v1/ag14100/ag14100.vertex.csv
#    [26850.997-26862.199]=  11.202s |          "MBMF RampDown"[0]          |    1074       61       53       29      499      396     1214      852     1931         6
#
# ../v1/ag14100/ag14100.vertex.csv
#    [26983.913-26995.115]=  11.202s |          "MBMF RampDown"[1]          |    1148       51       53       31      545      420     1317     1208     2690       116
#
# ../v1/ag14100/ag14100.vertex.csv
#    [27116.943-27128.146]=  11.202s |          "MBMF RampDown"[2]          |    1104       56       55       42      545      447     1307     1285     2653       142
#
# ../v1/ag14106/ag14106.vertex.csv
#    [23785.519-23796.721]=  11.202s |          "MBMF RampDown"[0]          |    1670       81       83       75     1093      800     2652      958     3535         8
#
# ../v1/ag14106/ag14106.vertex.csv
#    [23918.318-23929.520]=  11.202s |          "MBMF RampDown"[1]          |    1150       60       61       41      534      426     1250     1245     2562        99
#
# ../v1/ag14106/ag14106.vertex.csv
#    [24051.306-24062.508]=  11.202s |          "MBMF RampDown"[2]          |    1162       47       57       46      517      380     1268     1177     2345       105
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26321.536-26332.738]=  11.202s |          "MBMF RampDown"[0]          |    1109       67       52       46      542      388     1216      814     2373         2
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26454.276-26465.478]=  11.202s |          "MBMF RampDown"[1]          |    1138       56       45       44      565      389     1312     1167     2476        89
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26587.290-26598.492]=  11.202s |          "MBMF RampDown"[2]          |    1071       43       65       31      577      386     1322     1206     2697       121
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24671.299-24682.501]=  11.202s |          "MBMF RampDown"[0]          |    1684       95       87       80     1135      801     2645      891     3354         3
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24804.010-24815.212]=  11.202s |          "MBMF RampDown"[1]          |    1124       46       57       37      520      403     1231     1225     2584       104
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24936.880-24948.082]=  11.202s |          "MBMF RampDown"[2]          |    1085       54       45       37      529      359     1282     1290     2478       148
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25127.404-25138.606]=  11.202s |          "MBMF RampDown"[0]          |    1141       57       58       45      525      375     1278      874     2206        16
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25260.259-25271.461]=  11.202s |          "MBMF RampDown"[1]          |    1134       61       49       43      525      375     1310     1251     2743       117
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25393.143-25404.345]=  11.202s |          "MBMF RampDown"[2]          |    1096       62       47       40      506      424     1300     1168     2368       106
#
# LR statistic = 187.7/49
# p-value      = 4.1678846897965895e-18
# LR statistic = 179.2/49
# p-value      = 9.906156256633468e-17
# LR statistic = 221.3/49
# p-value      = 9.711031579553518e-24
# LR statistic = 129.0/49
# p-value      = 3.960998412474902e-09
# LR statistic = 91.24/49
# p-value      = 0.0002367995242394704
# New Best Found: [toy/output/tau_33.27s_theta_65_axial_2.28mK_transv_4.88mK_p_2.npz 808.4164036402576]  [ 1000000.0]
# best pvalue 63.02150372313156
# best LR 808.4164036402576
# ----------------
# LR statistic = 132.1/49
# p-value      = 1.4883170670677771e-09
# LR statistic = 111.2/49
# p-value      = 9.807586978888505e-07
# LR statistic = 103.9/49
# p-value      = 8.120302214012152e-06
# LR statistic = 46.17/49
# p-value      = 0.5886829953973024
# LR statistic = 146.2/49
# p-value      = 1.3291432859670729e-11
# New Best Found: [toy/output/tau_27.02s_theta_38_axial_1.63mK_transv_3.39mK_p_2.npz 539.4616211484896]  [toy/output/tau_33.27s_theta_65_axial_2.28mK_transv_4.88mK_p_2.npz 808.4164036402576]
# best pvalue 28.58218851693393
# best LR 539.4616211484896
# ----------------
# LR statistic = 430.0/49
# p-value      = 2.397125452502986e-62
# LR statistic = 415.3/49
# p-value      = 1.7095577837145296e-59
# LR statistic = 538.8/49
# p-value      = 1.116576973241829e-83
# LR statistic = 285.0/49
# p-value      = 5.136107372929877e-35
# LR statistic = 264.0/49
# p-value      = 3.044407594381922e-31
# best pvalue 28.58218851693393
# best LR 539.4616211484896
# ----------------
# LR statistic = 155.0/49
# p-value      = 6.115233309828255e-13
# LR statistic = 143.8/49
# p-value      = 2.9689616902632106e-11
# LR statistic = 119.9/49
# p-value      = 7.146725255598258e-08
# LR statistic = 59.5/49
# p-value      = 0.14467041016518908
# LR statistic = 149.8/49
# p-value      = 3.838862403535962e-12
# best pvalue 28.58218851693393
# best LR 539.4616211484896
# ----------------
# LR statistic = 127.6/49
# p-value      = 6.282906194039218e-09
# LR statistic = 127.7/49
# p-value      = 6.070512716991349e-09
# LR statistic = 184.6/49
# p-value      = 1.3372554966168147e-17
# LR statistic = 104.1/49
# p-value      = 7.544217484242429e-06
# LR statistic = 62.76/49
# p-value      = 0.08958142954313851
# best pvalue 28.58218851693393
# best LR 539.4616211484896
# ----------------
# LR statistic = 125.3/49
# p-value      = 1.2983607118838375e-08
# LR statistic = 121.9/49
# p-value      = 3.8260565466611536e-08
# LR statistic = 157.7/49
# p-value      = 2.375402042598761e-13
# LR statistic = 95.59/49
# p-value      = 7.714932801200198e-05
# LR statistic = 73.68/49
# p-value      = 0.0128343371523572
# best pvalue 28.58218851693393
# best LR 539.4616211484896
# ----------------
# LR statistic = 94.12/49
# p-value      = 0.00011322473545164674
# LR statistic = 98.35/49
# p-value      = 3.698351799400212e-05
# LR statistic = 122.2/49
# p-value      = 3.4374741407437924e-08
# LR statistic = 66.37/49
# p-value      = 0.04975378839998304
# LR statistic = 90.86/49
# p-value      = 0.0002602006942280751
# New Best Found: [toy/output/tau_40.46s_theta_36_axial_2.07mK_transv_4.32mK_p_2.npz 471.9312159167863]  [toy/output/tau_27.02s_theta_38_axial_1.63mK_transv_3.39mK_p_2.npz 539.4616211484896]
# best pvalue 19.09273756249774
# best LR 471.9312159167863
# ----------------
# LR statistic = 128.9/49
# p-value      = 4.1895022612112825e-09
# LR statistic = 127.6/49
# p-value      = 6.253103841328987e-09
# LR statistic = 134.0/49
# p-value      = 7.957044015609813e-10
# LR statistic = 79.71/49
# p-value      = 0.0036284939422780017
# LR statistic = 89.66/49
# p-value      = 0.00035136948941681684
# best pvalue 19.09273756249774
# best LR 471.9312159167863
# ----------------
# LR statistic = 169.7/49
# p-value      = 3.207683679457324e-15
# LR statistic = 182.0/49
# p-value      = 3.498157437297699e-17
# LR statistic = 254.1/49
# p-value      = 1.7622548144272382e-29
# LR statistic = 130.7/49
# p-value      = 2.3341519825641395e-09
# LR statistic = 90.68/49
# p-value      = 0.00027262115440967663
# best pvalue 19.09273756249774
# best LR 471.9312159167863
# ----------------
# LR statistic = 157.2/49
# p-value      = 2.8674596701265663e-13
# LR statistic = 155.9/49
# p-value      = 4.615200552666419e-13
# LR statistic = 194.8/49
# p-value      = 2.815382225440603e-19
# LR statistic = 113.4/49
# p-value      = 5.090098138702132e-07
# LR statistic = 77.11/49
# p-value      = 0.00634834705511174
# best pvalue 19.09273756249774
# best LR 471.9312159167863
# ----------------
# LR statistic = 94.37/49
# p-value      = 0.00010597485495559452
# LR statistic = 102.7/49
# p-value      = 1.1194318727411219e-05
# LR statistic = 125.8/49
# p-value      = 1.1288767504608372e-08
# LR statistic = 66.07/49
# p-value      = 0.05231682556996799
# LR statistic = 67.19/49
# p-value      = 0.043157796692937775
# New Best Found: [toy/output/tau_31.70s_theta_173_axial_1.93mK_transv_3.80mK_p_2.npz 456.1165922367338]  [toy/output/tau_40.46s_theta_36_axial_2.07mK_transv_4.32mK_p_2.npz 471.9312159167863]
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 125.4/49
# p-value      = 1.2769960305260425e-08
# LR statistic = 111.7/49
# p-value      = 8.436665193860385e-07
# LR statistic = 101.0/49
# p-value      = 1.815071892346581e-05
# LR statistic = 46.07/49
# p-value      = 0.5926661596933752
# LR statistic = 128.6/49
# p-value      = 4.617868281486263e-09
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 230.4/49
# p-value      = 2.5634560839766263e-25
# LR statistic = 218.7/49
# p-value      = 2.6644373764893775e-23
# LR statistic = 261.8/49
# p-value      = 7.8024983162605364e-31
# LR statistic = 156.5/49
# p-value      = 3.7170813589135527e-13
# LR statistic = 125.9/49
# p-value      = 1.092401831368248e-08
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 105.4/49
# p-value      = 5.2621462690774375e-06
# LR statistic = 100.6/49
# p-value      = 1.995381695334738e-05
# LR statistic = 119.2/49
# p-value      = 8.676101219046933e-08
# LR statistic = 62.44/49
# p-value      = 0.0940661763385517
# LR statistic = 91.04/49
# p-value      = 0.00024878093761354923
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 306.5/49
# p-value      = 5.8176878389408924e-39
# LR statistic = 298.9/49
# p-value      = 1.4658877586532608e-37
# LR statistic = 354.4/49
# p-value      = 7.116401466742453e-48
# LR statistic = 209.8/49
# p-value      = 8.832955811192607e-22
# LR statistic = 197.0/49
# p-value      = 1.2341594446590444e-19
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 157.1/49
# p-value      = 3.007091034615263e-13
# LR statistic = 149.8/49
# p-value      = 3.854535661268831e-12
# LR statistic = 200.8/49
# p-value      = 2.8376810773842113e-20
# LR statistic = 112.3/49
# p-value      = 7.06712678353329e-07
# LR statistic = 83.18/49
# p-value      = 0.0016598440442679113
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 211.9/49
# p-value      = 3.838843799895588e-22
# LR statistic = 217.1/49
# p-value      = 4.943587132773444e-23
# LR statistic = 300.1/49
# p-value      = 8.743670297632785e-38
# LR statistic = 168.9/49
# p-value      = 4.305994145955114e-15
# LR statistic = 116.4/49
# p-value      = 2.0958658730941e-07
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = nan/49
# p-value      = nan
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 166.6/49
# p-value      = 1.003706872499782e-14
# LR statistic = 180.8/49
# p-value      = 5.379915642842167e-17
# LR statistic = 249.8/49
# p-value      = 1.0456424808643553e-28
# LR statistic = 129.5/49
# p-value      = 3.364279118367686e-09
# LR statistic = 90.46/49
# p-value      = 0.0002882507881695259
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 113.1/49
# p-value      = 5.624109530449549e-07
# LR statistic = 113.5/49
# p-value      = 4.992534840971789e-07
# LR statistic = 130.8/49
# p-value      = 2.234438117848336e-09
# LR statistic = 66.94/49
# p-value      = 0.04506174781693179
# LR statistic = 82.3/49
# p-value      = 0.002031611076412365
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 108.2/49
# p-value      = 2.368546858006888e-06
# LR statistic = 107.9/49
# p-value      = 2.5792475633616154e-06
# LR statistic = 114.0/49
# p-value      = 4.281291483604675e-07
# LR statistic = 67.44/49
# p-value      = 0.041345850966602475
# LR statistic = 84.6/49
# p-value      = 0.0011924827976903976
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 373.5/49
# p-value      = 1.713312082049339e-51
# LR statistic = 338.5/49
# p-value      = 6.649385961545087e-45
# LR statistic = 314.4/49
# p-value      = 2.0723851460330333e-40
# LR statistic = 208.1/49
# p-value      = 1.6514038333757298e-21
# LR statistic = 374.5/49
# p-value      = 1.0702831152954523e-51
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 315.7/49
# p-value      = 1.1897776513271421e-40
# LR statistic = 323.5/49
# p-value      = 4.318670531553047e-42
# LR statistic = 417.6/49
# p-value      = 6.030909616918416e-60
# LR statistic = 220.9/49
# p-value      = 1.1072203732850239e-23
# LR statistic = 177.8/49
# p-value      = 1.669942262090318e-16
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 110.9/49
# p-value      = 1.062215602096061e-06
# LR statistic = 118.2/49
# p-value      = 1.1796548715277322e-07
# LR statistic = 164.7/49
# p-value      = 1.9981420860801912e-14
# LR statistic = 93.49/49
# p-value      = 0.00013327810729061516
# LR statistic = 58.63/49
# p-value      = 0.16305587932582735
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 126.8/49
# p-value      = 8.056650870714271e-09
# LR statistic = 120.0/49
# p-value      = 6.802213460908589e-08
# LR statistic = 120.4/49
# p-value      = 6.048974650720764e-08
# LR statistic = 49.51/49
# p-value      = 0.4527676401334692
# LR statistic = 137.6/49
# p-value      = 2.391445233942717e-10
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 128.4/49
# p-value      = 4.861455733221885e-09
# LR statistic = 119.8/49
# p-value      = 7.299753715626726e-08
# LR statistic = 154.8/49
# p-value      = 6.635136534425137e-13
# LR statistic = 93.6/49
# p-value      = 0.00012964950608978945
# LR statistic = 62.71/49
# p-value      = 0.09016292970079023
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 115.4/49
# p-value      = 2.770468587604732e-07
# LR statistic = 116.9/49
# p-value      = 1.7903660865276808e-07
# LR statistic = 140.3/49
# p-value      = 9.694732584083427e-11
# LR statistic = 77.74/49
# p-value      = 0.005551824751531442
# LR statistic = 70.5/49
# p-value      = 0.023756740589208458
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 177.8/49
# p-value      = 1.6434671993922265e-16
# LR statistic = 182.5/49
# p-value      = 2.8691496240260704e-17
# LR statistic = 186.8/49
# p-value      = 5.767020381087788e-18
# LR statistic = 76.32/49
# p-value      = 0.00749697154534574
# LR statistic = 179.9/49
# p-value      = 7.516950450299428e-17
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 133.4/49
# p-value      = 9.580356505179776e-10
# LR statistic = 130.5/49
# p-value      = 2.4711733549124624e-09
# LR statistic = 164.1/49
# p-value      = 2.45572227133364e-14
# LR statistic = 95.48/49
# p-value      = 7.93237121135472e-05
# LR statistic = 62.85/49
# p-value      = 0.08824024627296212
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 118.3/49
# p-value      = 1.155808090142149e-07
# LR statistic = 109.6/49
# p-value      = 1.5497117021830803e-06
# LR statistic = 118.9/49
# p-value      = 9.565437299702188e-08
# LR statistic = 67.3/49
# p-value      = 0.04236112940893352
# LR statistic = 79.81/49
# p-value      = 0.0035498904858085887
# best pvalue 17.97807997705938
# best LR 456.1165922367338
# ----------------
# LR statistic = 92.58/49
# p-value      = 0.0001683342682882941
# LR statistic = 75.79/49
# p-value      = 0.008366908353530843
# LR statistic = 78.17/49
# p-value      = 0.005067996016762698
# LR statistic = 52.57/49
# p-value      = 0.33763063467943333
# LR statistic = 76.53/49
# p-value      = 0.007178953986309113
# New Best Found: [toy/output/tau_9.82s_theta_20_axial_3.20mK_transv_2.41mK_p_2.npz 375.62854942811674]  [toy/output/tau_31.70s_theta_173_axial_1.93mK_transv_3.80mK_p_2.npz 456.1165922367338]
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 162.8/49
# p-value      = 3.9439839677300806e-14
# LR statistic = 171.8/49
# p-value      = 1.534549729018767e-15
# LR statistic = 233.4/49
# p-value      = 7.907087838743867e-26
# LR statistic = 115.5/49
# p-value      = 2.725582740406279e-07
# LR statistic = 126.7/49
# p-value      = 8.477964148650983e-09
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 210.9/49
# p-value      = 5.659979766208178e-22
# LR statistic = 191.2/49
# p-value      = 1.1128054273277229e-18
# LR statistic = 155.5/49
# p-value      = 5.25659324998639e-13
# LR statistic = 66.43/49
# p-value      = 0.04919439567592946
# LR statistic = 270.3/49
# p-value      = 2.3064598391083916e-32
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 275.8/49
# p-value      = 2.343131535696756e-33
# LR statistic = 281.9/49
# p-value      = 1.8489633898346818e-34
# LR statistic = 320.8/49
# p-value      = 1.3456245385230228e-41
# LR statistic = 187.6/49
# p-value      = 4.274750398575189e-18
# LR statistic = 169.8/49
# p-value      = 3.133327095362033e-15
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 134.1/49
# p-value      = 7.727116174289261e-10
# LR statistic = 148.4/49
# p-value      = 6.1403459099287824e-12
# LR statistic = 194.0/49
# p-value      = 3.7774981227507514e-19
# LR statistic = 99.17/49
# p-value      = 2.964155246707395e-05
# LR statistic = 76.84/49
# p-value      = 0.006722863939813167
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 455.5/49
# p-value      = 2.68870372317074e-67
# LR statistic = 485.9/49
# p-value      = 3.11164974838448e-73
# LR statistic = 624.3/49
# p-value      = 9.588998665711524e-101
# LR statistic = 320.1/49
# p-value      = 1.780877612306162e-41
# LR statistic = 367.8/49
# p-value      = 2.0522338166104945e-50
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 95.98/49
# p-value      = 6.951298335942151e-05
# LR statistic = 95.48/49
# p-value      = 7.929044041911744e-05
# LR statistic = 114.4/49
# p-value      = 3.739498536622489e-07
# LR statistic = 63.65/49
# p-value      = 0.0778477888293932
# LR statistic = 56.92/49
# p-value      = 0.2039854690208527
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 159.3/49
# p-value      = 1.3752262202277013e-13
# LR statistic = 162.1/49
# p-value      = 5.063965690514242e-14
# LR statistic = 207.1/49
# p-value      = 2.5248210839361297e-21
# LR statistic = 114.8/49
# p-value      = 3.39700649791667e-07
# LR statistic = 80.84/49
# p-value      = 0.0028211441014563336
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 153.7/49
# p-value      = 9.92913897060957e-13
# LR statistic = 137.6/49
# p-value      = 2.383101816781295e-10
# LR statistic = 114.9/49
# p-value      = 3.2441938772127835e-07
# LR statistic = 50.47/49
# p-value      = 0.41533775918847404
# LR statistic = 167.9/49
# p-value      = 6.187219345655426e-15
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 402.7/49
# p-value      = 4.420126770423571e-57
# LR statistic = 408.7/49
# p-value      = 3.184883958610861e-58
# LR statistic = 506.7/49
# p-value      = 2.5125778646197152e-77
# LR statistic = 271.2/49
# p-value      = 1.5778136090535913e-32
# LR statistic = 243.4/49
# p-value      = 1.4154800212828044e-27
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 104.4/49
# p-value      = 6.971634116770393e-06
# LR statistic = 97.22/49
# p-value      = 5.001349573035165e-05
# LR statistic = 108.7/49
# p-value      = 2.0494752489757227e-06
# LR statistic = 65.04/49
# p-value      = 0.06217156276095861
# LR statistic = 72.29/49
# p-value      = 0.016874374301943836
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 100.1/49
# p-value      = 2.2997550320368096e-05
# LR statistic = 92.97/49
# p-value      = 0.00015241848924955545
# LR statistic = 88.11/49
# p-value      = 0.0005146016572882371
# LR statistic = 52.4/49
# p-value      = 0.34352924828216685
# LR statistic = 85.28/49
# p-value      = 0.0010175174767314216
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 104.0/49
# p-value      = 7.82476710316278e-06
# LR statistic = 99.48/49
# p-value      = 2.7235235388317788e-05
# LR statistic = 138.3/49
# p-value      = 1.8719657221144843e-10
# LR statistic = 76.64/49
# p-value      = 0.00700350958196058
# LR statistic = 55.13/49
# p-value      = 0.2540770189173443
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 146.7/49
# p-value      = 1.1103676490099742e-11
# LR statistic = 179.4/49
# p-value      = 9.238208642173118e-17
# LR statistic = 247.7/49
# p-value      = 2.3943910745881255e-28
# LR statistic = 118.7/49
# p-value      = 1.0119893559165222e-07
# LR statistic = 103.6/49
# p-value      = 8.656224542022152e-06
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 91.27/49
# p-value      = 0.00023490750279734536
# LR statistic = 83.06/49
# p-value      = 0.001707502726464952
# LR statistic = 96.87/49
# p-value      = 5.498795973176275e-05
# LR statistic = 57.68/49
# p-value      = 0.18500815478742816
# LR statistic = 63.55/49
# p-value      = 0.07906630857135155
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 603.2/49
# p-value      = 1.6436755324743923e-96
# LR statistic = 622.8/49
# p-value      = 1.9452467257668717e-100
# LR statistic = 789.9/49
# p-value      = 2.582179207517715e-134
# LR statistic = 387.6/49
# p-value      = 3.412594269811556e-54
# LR statistic = 476.1/49
# p-value      = 2.6121992008107453e-71
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 366.3/49
# p-value      = 3.948200811360755e-50
# LR statistic = 349.5/49
# p-value      = 5.800069083169911e-47
# LR statistic = 439.2/49
# p-value      = 4.055462417400557e-64
# LR statistic = 237.8/49
# p-value      = 1.3076343797321456e-26
# LR statistic = 217.9/49
# p-value      = 3.60567353893806e-23
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 133.1/49
# p-value      = 1.0569419591679278e-09
# LR statistic = 115.0/49
# p-value      = 3.1962324304109085e-07
# LR statistic = 101.7/49
# p-value      = 1.4638554936150076e-05
# LR statistic = 49.26/49
# p-value      = 0.46257383367564264
# LR statistic = 130.1/49
# p-value      = 2.8399180738780218e-09
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# /home/adriano/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:8025: RuntimeWarning: divide by zero encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# /tmp/ipykernel_51344/4059634069.py:30: RuntimeWarning: divide by zero encountered in log
#   Pvalue_tot   += -2*np.log(pvalue_lr)
# /home/adriano/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:8025: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# LR statistic = 161.4/49
# p-value      = 6.3818317278818e-14
# LR statistic = 150.1/49
# p-value      = 3.389505682009257e-12
# LR statistic = 117.0/49
# p-value      = 1.7424666501874088e-07
# LR statistic = 46.59/49
# p-value      = 0.5712939431684022
# LR statistic = 207.4/49
# p-value      = 2.1812163646437748e-21
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 152.5/49
# p-value      = 1.517672583640364e-12
# LR statistic = 127.1/49
# p-value      = 7.468334760549206e-09
# LR statistic = 107.3/49
# p-value      = 3.0311321044502286e-06
# LR statistic = 48.14/49
# p-value      = 0.5080765315853636
# LR statistic = 172.8/49
# p-value      = 1.0475519482383997e-15
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 112.2/49
# p-value      = 7.307724240135381e-07
# LR statistic = 131.5/49
# p-value      = 1.7819518584724804e-09
# LR statistic = 175.3/49
# p-value      = 4.148893237030609e-16
# LR statistic = 93.6/49
# p-value      = 0.0001295010790107244
# LR statistic = 82.71/49
# p-value      = 0.0018504968547893121
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 126.2/49
# p-value      = 9.786160831394832e-09
# LR statistic = 140.5/49
# p-value      = 9.062207506086007e-11
# LR statistic = 184.1/49
# p-value      = 1.6053114823155732e-17
# LR statistic = 97.58/49
# p-value      = 4.551890828187886e-05
# LR statistic = 69.01/49
# p-value      = 0.03125637288914199
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 119.8/49
# p-value      = 7.420204782517921e-08
# LR statistic = 133.1/49
# p-value      = 1.0633872871687983e-09
# LR statistic = 164.1/49
# p-value      = 2.4146874854475636e-14
# LR statistic = 93.54/49
# p-value      = 0.00013140122617020684
# LR statistic = 69.68/49
# p-value      = 0.027616647399628283
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 1.624e+03/49
# p-value      = 4.894649976505664e-308
# LR statistic = 1.593e+03/49
# p-value      = 1.3300933071799135e-301
# LR statistic = 1.835e+03/49
# p-value      = 0.0
# LR statistic = 857.7/49
# p-value      = 3.356629982593031e-148
# LR statistic = 1.59e+03/49
# p-value      = 8.11330392626327e-301
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 126.7/49
# p-value      = 8.422024090612061e-09
# LR statistic = 104.6/49
# p-value      = 6.619554122897621e-06
# LR statistic = 102.1/49
# p-value      = 1.3207923389795642e-05
# LR statistic = 51.34/49
# p-value      = 0.38210711087232785
# LR statistic = 146.9/49
# p-value      = 1.0308176430543155e-11
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = nan/49
# p-value      = nan
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 560.4/49
# p-value      = 5.804566018843478e-88
# LR statistic = 576.7/49
# p-value      = 3.250681992159182e-91
# LR statistic = 741.6/49
# p-value      = 1.878892103823073e-124
# LR statistic = 362.1/49
# p-value      = 2.4104698186862546e-49
# LR statistic = 413.9/49
# p-value      = 3.170319670696519e-59
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 220.4/49
# p-value      = 1.3807266578239088e-23
# LR statistic = 229.0/49
# p-value      = 4.453127817889012e-25
# LR statistic = 310.6/49
# p-value      = 1.0385026233877362e-39
# LR statistic = 155.7/49
# p-value      = 4.889118557736699e-13
# LR statistic = 143.2/49
# p-value      = 3.6410314003872233e-11
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 208.3/49
# p-value      = 1.5350834150264417e-21
# LR statistic = 229.1/49
# p-value      = 4.35940195352367e-25
# LR statistic = 309.1/49
# p-value      = 1.940489291558589e-39
# LR statistic = 162.0/49
# p-value      = 5.196222557220342e-14
# LR statistic = 115.2/49
# p-value      = 2.9925389545843083e-07
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 263.3/49
# p-value      = 4.1772882299490615e-31
# LR statistic = 248.5/49
# p-value      = 1.7784366566949033e-28
# LR statistic = 280.2/49
# p-value      = 3.76731511861291e-34
# LR statistic = 173.8/49
# p-value      = 7.216901220528266e-16
# LR statistic = 173.6/49
# p-value      = 7.830159344126909e-16
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 87.04/49
# p-value      = 0.000668092825584357
# LR statistic = 76.44/49
# p-value      = 0.007312863070807103
# LR statistic = 85.5/49
# p-value      = 0.0009661859515377382
# LR statistic = 47.17/49
# p-value      = 0.5477780275044806
# LR statistic = 88.63/49
# p-value      = 0.00045381614714178764
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 110.1/49
# p-value      = 1.3495616481628086e-06
# LR statistic = 118.7/49
# p-value      = 1.0231433067158187e-07
# LR statistic = 140.5/49
# p-value      = 9.21858973583642e-11
# LR statistic = 74.96/49
# p-value      = 0.00992359212817443
# LR statistic = 103.2/49
# p-value      = 9.780675084153875e-06
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 226.8/49
# p-value      = 1.07866748785452e-24
# LR statistic = 221.6/49
# p-value      = 8.549295858445109e-24
# LR statistic = 261.8/49
# p-value      = 7.79147640598484e-31
# LR statistic = 154.1/49
# p-value      = 8.550029701588064e-13
# LR statistic = 145.4/49
# p-value      = 1.7114856786361826e-11
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 165.4/49
# p-value      = 1.5313350345018174e-14
# LR statistic = 169.2/49
# p-value      = 3.854976170038082e-15
# LR statistic = 179.8/49
# p-value      = 7.885055332500184e-17
# LR statistic = 104.7/49
# p-value      = 6.497898886917045e-06
# LR statistic = 114.2/49
# p-value      = 4.010613950358895e-07
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 130.2/49
# p-value      = 2.7020736731160096e-09
# LR statistic = 134.2/49
# p-value      = 7.499146921794859e-10
# LR statistic = 153.1/49
# p-value      = 1.2086961696244334e-12
# LR statistic = 69.85/49
# p-value      = 0.026785127924251372
# LR statistic = 133.4/49
# p-value      = 9.50777928593471e-10
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 181.2/49
# p-value      = 4.71659063430896e-17
# LR statistic = 181.0/49
# p-value      = 5.164052288498701e-17
# LR statistic = 199.0/49
# p-value      = 5.58222700946873e-20
# LR statistic = 78.33/49
# p-value      = 0.004889752698714545
# LR statistic = 198.1/49
# p-value      = 7.897159168843077e-20
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 122.1/49
# p-value      = 3.58077580835582e-08
# LR statistic = 128.1/49
# p-value      = 5.355946256324772e-09
# LR statistic = 165.6/49
# p-value      = 1.4278492848330056e-14
# LR statistic = 79.47/49
# p-value      = 0.003822895776419635
# LR statistic = 95.48/49
# p-value      = 7.928857839275087e-05
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 103.0/49
# p-value      = 1.042383479918213e-05
# LR statistic = 96.79/49
# p-value      = 5.620832660566426e-05
# LR statistic = 131.1/49
# p-value      = 2.063494734352748e-09
# LR statistic = 79.64/49
# p-value      = 0.0036813098756504283
# LR statistic = 52.71/49
# p-value      = 0.33247782433059014
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 88.51/49
# p-value      = 0.00046725760323684205
# LR statistic = 78.63/49
# p-value      = 0.0045875829990319195
# LR statistic = 94.68/49
# p-value      = 9.779363543202373e-05
# LR statistic = 46.6/49
# p-value      = 0.5710927425493382
# LR statistic = 96.03/49
# p-value      = 6.864860974229806e-05
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 128.1/49
# p-value      = 5.320946013647407e-09
# LR statistic = 112.5/49
# p-value      = 6.764730921281429e-07
# LR statistic = 109.9/49
# p-value      = 1.4457645100223161e-06
# LR statistic = 65.28/49
# p-value      = 0.05975315079964472
# LR statistic = 106.4/49
# p-value      = 3.908568324112951e-06
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 157.0/49
# p-value      = 3.070405779531211e-13
# LR statistic = 143.5/49
# p-value      = 3.3571769120774864e-11
# LR statistic = 137.9/49
# p-value      = 2.1943255163150573e-10
# LR statistic = 54.98/49
# p-value      = 0.25850727571175924
# LR statistic = 192.6/49
# p-value      = 6.592350521176251e-19
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 125.0/49
# p-value      = 1.4340753291373853e-08
# LR statistic = 122.9/49
# p-value      = 2.7514342347299612e-08
# LR statistic = 144.9/49
# p-value      = 2.0344483697022826e-11
# LR statistic = 79.62/49
# p-value      = 0.003696643770932196
# LR statistic = 71.56/49
# p-value      = 0.019417197604798188
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 231.6/49
# p-value      = 1.6110945280053738e-25
# LR statistic = 204.0/49
# p-value      = 8.146176622434782e-21
# LR statistic = 143.3/49
# p-value      = 3.505109382380216e-11
# LR statistic = 75.84/49
# p-value      = 0.008281528222923606
# LR statistic = 268.6/49
# p-value      = 4.6786094170299383e-32
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 97.1/49
# p-value      = 5.163250992532972e-05
# LR statistic = 107.6/49
# p-value      = 2.8416316239770102e-06
# LR statistic = 142.2/49
# p-value      = 5.1761850015539744e-11
# LR statistic = 84.13/49
# p-value      = 0.0013316416031760188
# LR statistic = 51.92/49
# p-value      = 0.36095279429237315
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 222.2/49
# p-value      = 6.629575615058565e-24
# LR statistic = 254.7/49
# p-value      = 1.4207567813721219e-29
# LR statistic = 292.9/49
# p-value      = 1.8375714658778097e-36
# LR statistic = 144.0/49
# p-value      = 2.8043416622729756e-11
# LR statistic = 245.1/49
# p-value      = 7.077834607495165e-28
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 166.4/49
# p-value      = 1.0814927800613658e-14
# LR statistic = 176.5/49
# p-value      = 2.676800743448302e-16
# LR statistic = 235.7/49
# p-value      = 3.1351848253102357e-26
# LR statistic = 129.4/49
# p-value      = 3.5801235025452407e-09
# LR statistic = 88.01/49
# p-value      = 0.0005274616474079735
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 321.2/49
# p-value      = 1.1403362919163728e-41
# LR statistic = 303.0/49
# p-value      = 2.563925628118153e-38
# LR statistic = 338.0/49
# p-value      = 8.382289794687034e-45
# LR statistic = 202.7/49
# p-value      = 1.3377922710389743e-20
# LR statistic = 223.6/49
# p-value      = 3.784186724283859e-24
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 1.288e+03/49
# p-value      = 1.7762970378586256e-237
# LR statistic = 1.25e+03/49
# p-value      = 1.5680395702395404e-229
# LR statistic = 1.432e+03/49
# p-value      = 1.3915668814337904e-267
# LR statistic = 758.7/49
# p-value      = 6.190420772412706e-128
# LR statistic = 1.005e+03/49
# p-value      = 1.5333260987862558e-178
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 194.6/49
# p-value      = 3.0664376646567594e-19
# LR statistic = 199.2/49
# p-value      = 5.209863208701004e-20
# LR statistic = 198.8/49
# p-value      = 6.04196504479364e-20
# LR statistic = 121.1/49
# p-value      = 4.831020808483276e-08
# LR statistic = 139.9/49
# p-value      = 1.1055836130035893e-10
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 130.6/49
# p-value      = 2.418127875864318e-09
# LR statistic = 113.9/49
# p-value      = 4.380951532911348e-07
# LR statistic = 102.3/49
# p-value      = 1.2418215540434786e-05
# LR statistic = 54.15/49
# p-value      = 0.28424730079448035
# LR statistic = 125.0/49
# p-value      = 1.4554576111073428e-08
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 182.6/49
# p-value      = 2.7657009487902252e-17
# LR statistic = 195.9/49
# p-value      = 1.8768926834701425e-19
# LR statistic = 237.7/49
# p-value      = 1.3923025962577295e-26
# LR statistic = 137.9/49
# p-value      = 2.199664887768159e-10
# LR statistic = 100.0/49
# p-value      = 2.344205724338115e-05
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 111.8/49
# p-value      = 8.318365949699876e-07
# LR statistic = 107.7/49
# p-value      = 2.7120917768254222e-06
# LR statistic = 135.3/49
# p-value      = 5.191198181934494e-10
# LR statistic = 79.18/49
# p-value      = 0.004069937792706671
# LR statistic = 62.51/49
# p-value      = 0.09299509697920832
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 770.0/49
# p-value      = 3.0922487304646437e-130
# LR statistic = 803.5/49
# p-value      = 4.338235829301582e-137
# LR statistic = 992.0/49
# p-value      = 7.110888085927114e-176
# LR statistic = 485.2/49
# p-value      = 4.325100859749046e-73
# LR statistic = 652.7/49
# p-value      = 1.90032801511295e-106
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 139.8/49
# p-value      = 1.1466125305090115e-10
# LR statistic = 116.2/49
# p-value      = 2.1993300308655575e-07
# LR statistic = 124.5/49
# p-value      = 1.6866941506086168e-08
# LR statistic = 57.54/49
# p-value      = 0.18835573146633502
# LR statistic = 117.9/49
# p-value      = 1.3219797898415094e-07
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 308.8/49
# p-value      = 2.186647397029924e-39
# LR statistic = 249.3/49
# p-value      = 1.2804423059150533e-28
# LR statistic = 176.1/49
# p-value      = 3.1299742679403746e-16
# LR statistic = 72.38/49
# p-value      = 0.016569891657870955
# LR statistic = 359.3/49
# p-value      = 8.141453619210675e-49
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 151.9/49
# p-value      = 1.8506642842232772e-12
# LR statistic = 149.8/49
# p-value      = 3.798279921144411e-12
# LR statistic = 188.5/49
# p-value      = 3.1039000287922433e-18
# LR statistic = 112.7/49
# p-value      = 6.358649724561764e-07
# LR statistic = 75.85/49
# p-value      = 0.008254359723363887
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 164.2/49
# p-value      = 2.378277609160166e-14
# LR statistic = 178.6/49
# p-value      = 1.2166966862635088e-16
# LR statistic = 232.0/49
# p-value      = 1.372326793870457e-25
# LR statistic = 126.8/49
# p-value      = 8.17462636519632e-09
# LR statistic = 89.44/49
# p-value      = 0.0003710492222822871
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 222.8/49
# p-value      = 5.324389425838467e-24
# LR statistic = 245.2/49
# p-value      = 6.744871169796798e-28
# LR statistic = 331.4/49
# p-value      = 1.4361389817890498e-43
# LR statistic = 164.0/49
# p-value      = 2.5081447167763496e-14
# LR statistic = 131.7/49
# p-value      = 1.6577401141686575e-09
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 198.1/49
# p-value      = 7.891929394698953e-20
# LR statistic = 212.7/49
# p-value      = 2.8097108118811567e-22
# LR statistic = 278.2/49
# p-value      = 8.665256329378574e-34
# LR statistic = 149.4/49
# p-value      = 4.424542930636034e-12
# LR statistic = 101.6/49
# p-value      = 1.5044029116283215e-05
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 85.0/49
# p-value      = 0.0010870711390169139
# LR statistic = 88.61/49
# p-value      = 0.00045547922225240876
# LR statistic = 105.6/49
# p-value      = 5.020960410062761e-06
# LR statistic = 60.01/49
# p-value      = 0.13466913787057203
# LR statistic = 86.64/49
# p-value      = 0.0007345424936188486
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 93.96/49
# p-value      = 0.0001179271675105354
# LR statistic = 99.86/49
# p-value      = 2.4559473305875307e-05
# LR statistic = 107.5/49
# p-value      = 2.917661319507046e-06
# LR statistic = 59.76/49
# p-value      = 0.13955651568309857
# LR statistic = 81.25/49
# p-value      = 0.00257473135613745
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 107.8/49
# p-value      = 2.6751563112373774e-06
# LR statistic = 103.0/49
# p-value      = 1.0210939197355786e-05
# LR statistic = 104.6/49
# p-value      = 6.623000423513275e-06
# LR statistic = 60.67/49
# p-value      = 0.12242726525037909
# LR statistic = 84.26/49
# p-value      = 0.0012917162338479766
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 134.0/49
# p-value      = 8.015708721358751e-10
# LR statistic = 143.0/49
# p-value      = 3.894326020263731e-11
# LR statistic = 179.0/49
# p-value      = 1.0688797701654007e-16
# LR statistic = 102.0/49
# p-value      = 1.357803658592644e-05
# LR statistic = 74.52/49
# p-value      = 0.010836907934694504
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 104.3/49
# p-value      = 7.095728180822419e-06
# LR statistic = 85.42/49
# p-value      = 0.0009826994862581113
# LR statistic = 83.74/49
# p-value      = 0.0014580320282878085
# LR statistic = 56.1/49
# p-value      = 0.22613555143897243
# LR statistic = 104.3/49
# p-value      = 7.260817323646134e-06
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 374.3/49
# p-value      = 1.1829744725231239e-51
# LR statistic = 366.4/49
# p-value      = 3.7921245343507235e-50
# LR statistic = 445.2/49
# p-value      = 2.7084663930485756e-65
# LR statistic = 253.0/49
# p-value      = 2.8687113245072375e-29
# LR statistic = 224.6/49
# p-value      = 2.6166240306832614e-24
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = inf/49
# p-value      = 0.0
# LR statistic = nan/49
# p-value      = nan
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 97.37/49
# p-value      = 4.806464221032865e-05
# LR statistic = 79.13/49
# p-value      = 0.004118658113963837
# LR statistic = 96.53/49
# p-value      = 6.020781254025349e-05
# LR statistic = 63.45/49
# p-value      = 0.08032797074874234
# LR statistic = 72.56/49
# p-value      = 0.016012847005815362
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 114.8/49
# p-value      = 3.383475316795939e-07
# LR statistic = 115.3/49
# p-value      = 2.849301190650553e-07
# LR statistic = 122.8/49
# p-value      = 2.90210817320694e-08
# LR statistic = 67.17/49
# p-value      = 0.04336248873190426
# LR statistic = 85.59/49
# p-value      = 0.000944641368289409
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 151.8/49
# p-value      = 1.935334680068728e-12
# LR statistic = 143.7/49
# p-value      = 3.117875513152512e-11
# LR statistic = 159.8/49
# p-value      = 1.1349610437455184e-13
# LR statistic = 95.05/49
# p-value      = 8.888676121138699e-05
# LR statistic = 85.34/49
# p-value      = 0.0010017209465768612
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 164.4/49
# p-value      = 2.1874990368326563e-14
# LR statistic = 172.1/49
# p-value      = 1.344512168661857e-15
# LR statistic = 249.7/49
# p-value      = 1.07241602302961e-28
# LR statistic = 137.5/49
# p-value      = 2.489994192829646e-10
# LR statistic = 93.05/49
# p-value      = 0.00014910737084686306
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 105.4/49
# p-value      = 5.234434523298725e-06
# LR statistic = 110.9/49
# p-value      = 1.0853218394173358e-06
# LR statistic = 118.9/49
# p-value      = 9.688853190687369e-08
# LR statistic = 61.58/49
# p-value      = 0.10718051774609084
# LR statistic = 83.95/49
# p-value      = 0.0013899399085895924
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 289.3/49
# p-value      = 8.348054257384844e-36
# LR statistic = 287.2/49
# p-value      = 2.0513489985657852e-35
# LR statistic = 376.4/49
# p-value      = 4.7238623255261434e-52
# LR statistic = 204.9/49
# p-value      = 5.845178735436968e-21
# LR statistic = 158.6/49
# p-value      = 1.734966703640705e-13
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 116.5/49
# p-value      = 2.0393505482414166e-07
# LR statistic = 111.3/49
# p-value      = 9.485028531288575e-07
# LR statistic = 109.1/49
# p-value      = 1.802071570103326e-06
# LR statistic = 51.25/49
# p-value      = 0.38564996508422106
# LR statistic = 124.2/49
# p-value      = 1.8581497731933484e-08
# best pvalue 9.912097547782583
# best LR 375.62854942811674
# ----------------
# LR statistic = 71.91/49
# p-value      = 0.01814083646392536
# LR statistic = 75.96/49
# p-value      = 0.00807304454162283
# LR statistic = 91.4/49
# p-value      = 0.00022714794282247507
# LR statistic = 66.87/49
# p-value      = 0.04565582132344246
# LR statistic = 58.79/49
# p-value      = 0.15947956653686318
# New Best Found: [toy/output/tau_9.49s_theta_17_axial_3.94mK_transv_2.41mK_p_2.npz 364.9411969479575]  [toy/output/tau_9.82s_theta_20_axial_3.20mK_transv_2.41mK_p_2.npz 375.62854942811674]
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 101.4/49
# p-value      = 1.6237057810698005e-05
# LR statistic = 88.85/49
# p-value      = 0.0004299137471639533
# LR statistic = 114.2/49
# p-value      = 4.0618738134854933e-07
# LR statistic = 62.46/49
# p-value      = 0.09377899627301162
# LR statistic = 91.01/49
# p-value      = 0.00025068410181186085
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 117.5/49
# p-value      = 1.4698502249770443e-07
# LR statistic = 109.8/49
# p-value      = 1.4756549730682988e-06
# LR statistic = 98.91/49
# p-value      = 3.181473884583803e-05
# LR statistic = 46.75/49
# p-value      = 0.564923955610839
# LR statistic = 124.3/49
# p-value      = 1.7809678935957443e-08
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 298.5/49
# p-value      = 1.7169432852831267e-37
# LR statistic = 319.2/49
# p-value      = 2.692624057385313e-41
# LR statistic = 427.5/49
# p-value      = 7.3337939783949775e-62
# LR statistic = 205.0/49
# p-value      = 5.6433616184401735e-21
# LR statistic = 237.0/49
# p-value      = 1.8394666095879572e-26
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 168.7/49
# p-value      = 4.656398951538756e-15
# LR statistic = 179.2/49
# p-value      = 9.88603869601617e-17
# LR statistic = 237.8/49
# p-value      = 1.3542640563495354e-26
# LR statistic = 126.6/49
# p-value      = 8.69750497230149e-09
# LR statistic = 87.95/49
# p-value      = 0.0005358752903149695
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 128.2/49
# p-value      = 5.222242242654883e-09
# LR statistic = 132.0/49
# p-value      = 1.5119403793068347e-09
# LR statistic = 143.9/49
# p-value      = 2.8631990709172413e-11
# LR statistic = 66.38/49
# p-value      = 0.049641690636131754
# LR statistic = 138.3/49
# p-value      = 1.891931706941206e-10
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 183.9/49
# p-value      = 1.708708154499686e-17
# LR statistic = 181.4/49
# p-value      = 4.4198005359276164e-17
# LR statistic = 187.5/49
# p-value      = 4.519982944548418e-18
# LR statistic = 73.23/49
# p-value      = 0.014025887195276832
# LR statistic = 208.2/49
# p-value      = 1.6276745695585951e-21
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 104.4/49
# p-value      = 7.000526568614561e-06
# LR statistic = 107.4/49
# p-value      = 2.9529866002116033e-06
# LR statistic = 137.7/49
# p-value      = 2.2969177400323752e-10
# LR statistic = 80.88/49
# p-value      = 0.002798765766307606
# LR statistic = 67.73/49
# p-value      = 0.039285404262652604
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 630.8/49
# p-value      = 4.804344842069775e-102
# LR statistic = 624.9/49
# p-value      = 7.452533939900198e-101
# LR statistic = 755.0/49
# p-value      = 3.382705855636162e-127
# LR statistic = 395.5/49
# p-value      = 1.0607482215051458e-55
# LR statistic = 421.2/49
# p-value      = 1.202401564666399e-60
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 424.2/49
# p-value      = 3.2745097012514205e-61
# LR statistic = 407.3/49
# p-value      = 5.773145467225438e-58
# LR statistic = 468.2/49
# p-value      = 9.027550110478075e-70
# LR statistic = 219.8/49
# p-value      = 1.6987675631213203e-23
# LR statistic = 464.1/49
# p-value      = 5.822535107879368e-69
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 115.0/49
# p-value      = 3.162864728615442e-07
# LR statistic = 95.18/49
# p-value      = 8.596089848142022e-05
# LR statistic = 122.0/49
# p-value      = 3.6963668944791626e-08
# LR statistic = 63.08/49
# p-value      = 0.08521701269714008
# LR statistic = 83.38/49
# p-value      = 0.0015837379026679497
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 145.3/49
# p-value      = 1.7967939605449912e-11
# LR statistic = 132.5/49
# p-value      = 1.275728413467778e-09
# LR statistic = 122.4/49
# p-value      = 3.307597995182171e-08
# LR statistic = 46.99/49
# p-value      = 0.5551199531981433
# LR statistic = 157.7/49
# p-value      = 2.4147637274306024e-13
# best pvalue 8.856474792412111
# best LR 364.9411969479575
# ----------------
# LR statistic = 80.85/49
# p-value      = 0.002815051868826773
# LR statistic = 65.42/49
# p-value      = 0.05841656176055137
# LR statistic = 66.48/49
# p-value      = 0.04882281084679067
# LR statistic = 38.63/49
# p-value      = 0.8562926691426919
# LR statistic = 91.77/49
# p-value      = 0.00020671231755928479
# New Best Found: [toy/output/tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK_p_2.npz 343.14721080658154]  [toy/output/tau_9.49s_theta_17_axial_3.94mK_transv_2.41mK_p_2.npz 364.9411969479575]
# best pvalue 8.148725451538219
# best LR 343.14721080658154
# ----------------
# LR statistic = 132.2/49
# p-value      = 1.4124314852210956e-09
# LR statistic = 132.4/49
# p-value      = 1.3318503821244212e-09
# LR statistic = 141.8/49
# p-value      = 5.891697021374223e-11
# LR statistic = 84.07/49
# p-value      = 0.0013503576315441897
# LR statistic = 90.59/49
# p-value      = 0.00027834449634772245
# best pvalue 8.148725451538219
# best LR 343.14721080658154
# ----------------
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# LR statistic = nan/49
# p-value      = nan
# best pvalue 8.148725451538219
# best LR 343.14721080658154
# ----------------
# LR statistic = 116.2/49
# p-value      = 2.2271888156202588e-07
# LR statistic = 108.6/49
# p-value      = 2.076505528640382e-06
# LR statistic = 112.5/49
# p-value      = 6.750296862046878e-07
# LR statistic = 57.15/49
# p-value      = 0.19821685985912413
# LR statistic = 109.5/49
# p-value      = 1.6269643417123576e-06
# best pvalue 8.148725451538219
# best LR 343.14721080658154
# ----------------
# toy/output/tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK_p_2.npz

# %%
for k, v in sorted(simulation_list.items(), key=lambda x: x[1][4])[:10]:
    print(f"{k}: LR = {v[4]}")
# Out:
# toy/output/tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK_p_2.npz: LR = 343.14721080658154
# toy/output/tau_9.49s_theta_17_axial_3.94mK_transv_2.41mK_p_2.npz: LR = 364.9411969479575
# toy/output/tau_9.82s_theta_20_axial_3.20mK_transv_2.41mK_p_2.npz: LR = 375.62854942811674
# toy/output/tau_15.73s_theta_24_axial_2.81mK_transv_2.76mK_p_2.npz: LR = 384.7617099564047
# toy/output/tau_17.19s_theta_31_axial_2.84mK_transv_3.08mK_p_2.npz: LR = 392.4296012942739
# toy/output/tau_14.22s_theta_21_axial_3.14mK_transv_2.39mK_p_2.npz: LR = 404.44666601134685
# toy/output/tau_9.52s_theta_17_axial_3.83mK_transv_1.86mK_p_2.npz: LR = 409.0373677758015
# toy/output/tau_21.05s_theta_36_axial_1.90mK_transv_3.70mK_p_2.npz: LR = 418.85959525098156
# toy/output/tau_28.17s_theta_34_axial_3.29mK_transv_2.41mK_p_2.npz: LR = 425.8237399173298
# toy/output/tau_24.44s_theta_35_axial_1.98mK_transv_4.29mK_p_2.npz: LR = 426.48421622863833

# %%
plt.figure(0, figsize=(14,14))

print(best_for_dataset)

i = 1
for dataset in list_dataset:
    simulation = best_for_dataset
    ax         = plt.subplot(3, 2, i)
    i += 1

    Time_Simulation, counts, edges = analysis_function("../" + str(simulation[0][0]))
    Event_Distribution, counts, edges = analysis_data("../" + dataset, ZCUTS)

    ax.hist(Event_Distribution, bins=50, range=(0,330), density=True,
            color="black", alpha=.3)

    ax.hist(Time_Simulation, bins=50, range=(0,330), density=True,
            linestyle="--", histtype="step", color="red")

# ---- ultimo subplot SOLO TESTO ----
ax_text = plt.subplot(3, 2, 6)
ax_text.axis("off")   # niente assi

text = (
    f"Simulation file:\n"
    f"{simulation[0][0]}\n\n"
    f"Parameter:\n"
    f"{simulation[0][1]}"
)

ax_text.text(
    0.0, 1.0, text,
    transform=ax_text.transAxes,
    fontsize=10,
    verticalalignment="top"
)

plt.savefig("simulation_results.png", bbox_inches="tight")
# Out:
# [('toy/output/tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK_p_2.npz', 'Best LR: 343.15/245, pvalue = 8.149')]
# ../v1/ag14100/ag14100.vertex.csv
#    [26850.997-26862.199]=  11.202s |          "MBMF RampDown"[0]          |    1074       61       53       29      499      396     1214      852     1931         6
#
# ../v1/ag14100/ag14100.vertex.csv
#    [26983.913-26995.115]=  11.202s |          "MBMF RampDown"[1]          |    1148       51       53       31      545      420     1317     1208     2690       116
#
# ../v1/ag14100/ag14100.vertex.csv
#    [27116.943-27128.146]=  11.202s |          "MBMF RampDown"[2]          |    1104       56       55       42      545      447     1307     1285     2653       142
#
# ../v1/ag14106/ag14106.vertex.csv
#    [23785.519-23796.721]=  11.202s |          "MBMF RampDown"[0]          |    1670       81       83       75     1093      800     2652      958     3535         8
#
# ../v1/ag14106/ag14106.vertex.csv
#    [23918.318-23929.520]=  11.202s |          "MBMF RampDown"[1]          |    1150       60       61       41      534      426     1250     1245     2562        99
#
# ../v1/ag14106/ag14106.vertex.csv
#    [24051.306-24062.508]=  11.202s |          "MBMF RampDown"[2]          |    1162       47       57       46      517      380     1268     1177     2345       105
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26321.536-26332.738]=  11.202s |          "MBMF RampDown"[0]          |    1109       67       52       46      542      388     1216      814     2373         2
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26454.276-26465.478]=  11.202s |          "MBMF RampDown"[1]          |    1138       56       45       44      565      389     1312     1167     2476        89
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26587.290-26598.492]=  11.202s |          "MBMF RampDown"[2]          |    1071       43       65       31      577      386     1322     1206     2697       121
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24671.299-24682.501]=  11.202s |          "MBMF RampDown"[0]          |    1684       95       87       80     1135      801     2645      891     3354         3
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24804.010-24815.212]=  11.202s |          "MBMF RampDown"[1]          |    1124       46       57       37      520      403     1231     1225     2584       104
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24936.880-24948.082]=  11.202s |          "MBMF RampDown"[2]          |    1085       54       45       37      529      359     1282     1290     2478       148
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25127.404-25138.606]=  11.202s |          "MBMF RampDown"[0]          |    1141       57       58       45      525      375     1278      874     2206        16
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25260.259-25271.461]=  11.202s |          "MBMF RampDown"[1]          |    1134       61       49       43      525      375     1310     1251     2743       117
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25393.143-25404.345]=  11.202s |          "MBMF RampDown"[2]          |    1096       62       47       40      506      424     1300     1168     2368       106

# %% [markdown]
# # heatmap

# %%
import pandas as pd
import matplotlib.pyplot as plt

# simulation_list = {
#     "file1.npz": [tau1, theta1, axial1, transverse1, LR1],
#     "file2.npz": [tau2, theta2, axial2, transverse2, LR2],
#     ...
# }

df = pd.DataFrame.from_dict(simulation_list, orient='index',
                            columns=["tau", "theta", "axial", "transverse", "LR"])


# Filtra il DataFrame per tau tra 0 e 40
df = df[(df["tau"] >= 0) & (df["tau"] <= 40) & (df["LR"] <= 99999)]

# Crea figura con 2x2 subplot
fig, axes = plt.subplots(2, 2, figsize=(14, 14))

# Lista delle coppie di parametri da plottare
param_pairs = [
    ("tau", "transverse"),
    ("tau", "axial"),
    ("tau", "theta"),
    ("axial",   "transverse")
]

for i, (x_param, y_param) in enumerate(param_pairs):
    ax = axes[i // 2, i % 2]

    # estrai dati e rimuovi NaN
    mask = (
        np.isfinite(df[x_param]) &
        np.isfinite(df[y_param]) &
        np.isfinite(df["LR"])
    )

    x = df.loc[mask, x_param].values
    y = df.loc[mask, y_param].values
    z = df.loc[mask, "LR"].values

    # range fissi
    x_range = (x.min(), x.max())
    y_range = (y.min(), y.max())

    # binning
    LR_sum, xedges, yedges = np.histogram2d(
        x, y,
        bins=[16, 25],
        range=[x_range, y_range],
        weights=z
    )

    counts, _, _ = np.histogram2d(
        x, y,
        bins=[16, 25],
        range=[x_range, y_range]
    )

    # FIX: inizializza LR_mean
    LR_mean = np.full_like(LR_sum, np.nan, dtype=float)
    
    LR_mean[counts != 0] = LR_sum[counts != 0] / counts[counts != 0] #print(LR_mean)
    pcm = ax.pcolormesh(
        xedges,
        yedges,
        LR_mean.T,
        cmap="Greys_r",
        shading="auto"
    )

    ax.set_xlabel(x_param)
    ax.set_ylabel(y_param)
    ax.set_title("⟨LR⟩ (16×25 bin)")
    ax.grid(True)

    fig.colorbar(pcm, ax=ax, label="⟨LR⟩")

#axes[1, 1].axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # ===> ANALYZE SCURVE

# %%
from toy.UTILS import Zmin, Zmax, Zmid, zacceptance_min, zacceptance_max
# Out:
# /home/adriano/.local/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:373: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
Tramp1     = 11.2
wait_ramp1 = 121.5 + Tramp1

Tramp2     = 11.2 + wait_ramp1
wait_ramp2 = 121.5 + Tramp2

Tramp3     = 11.2 + wait_ramp2
wait_ramp3 = 121.5 + Tramp3

# %%
def get_annihilations(output, bias):
    "output: simulation path to load"
    
    file = np.load(output)
    R_array           = file['position']
    Time_Annihilation = file['Time']

    # mask the particles still trapped at the end of the release
    mask       = np.isfinite(Time_Annihilation)
    Z_position = R_array[mask,2]
    #print(len(Z_position))
    Time_Annihilation = Time_Annihilation[mask]  

    # get the Annihilations
    Nup   = (Z_position >= zacceptance_max - 0.001).sum()
    Ndown = (Z_position <= zacceptance_min + 0.001).sum()
    
    # Compute the asymmetry
    A,  A0,   A1,  A2 = 0,0,0,0
    dA, dA0, dA1, dA2 = 0,0,0,0
    
    if((Nup + Ndown) > 0):
        A = (Ndown - Nup) / (Nup + Ndown)
        dA = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        dResult = np.nan

    # SEGMENT 1 
    Nup   = ((Z_position >= zacceptance_max - 0.001) & (Time_Annihilation > 0) & (Time_Annihilation < Tramp1)).sum()
    Ndown = ((Z_position <= zacceptance_min + 0.001) & (Time_Annihilation > 0) & (Time_Annihilation < Tramp1)).sum()

    print(f"{bias}, segmet 1: {Nup + Ndown}")
    
    if((Nup + Ndown) > 0):
        A0 = (Ndown - Nup) / (Nup + Ndown)
        dA0 = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        A0  = np.nan
        dA0 = np.nan

    Nup   = ((Z_position >= zacceptance_max - 0.001) & (Time_Annihilation > Tramp1) & (Time_Annihilation < wait_ramp1)).sum()
    Ndown = ((Z_position <= zacceptance_min + 0.001) & (Time_Annihilation > Tramp1) & (Time_Annihilation < wait_ramp1)).sum()

    print(f"{bias}, segmet 1: {Nup + Ndown}")
    
    if((Nup + Ndown) > 0):
        A0b = (Ndown - Nup) / (Nup + Ndown)
        dA0b = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        A0b  = np.nan
        dA0b = np.nan
    
    
    # SEGMENT 2
    Nup   = ((Z_position >= zacceptance_max  - 0.001) & (Time_Annihilation > wait_ramp1) & (Time_Annihilation < Tramp2)).sum()
    Ndown = ((Z_position <= zacceptance_min  + 0.001) & (Time_Annihilation > wait_ramp1) & (Time_Annihilation < Tramp2)).sum()

    print(f"{bias}, segmet 2: {Nup + Ndown}")
    
    if((Nup + Ndown) > 0):
        A1 = (Ndown - Nup) / (Nup + Ndown)
        dA1 = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        A1  = np.nan
        dA1 = np.nan

    Nup   = ((Z_position >= zacceptance_max  - 0.001) & (Time_Annihilation > Tramp2) & (Time_Annihilation < wait_ramp2)).sum()
    Ndown = ((Z_position <= zacceptance_min  + 0.001) & (Time_Annihilation > Tramp2) & (Time_Annihilation < wait_ramp2)).sum()

    print(f"{bias}, segmet 2: {Nup + Ndown}")
    
    if((Nup + Ndown) > 0):
        A1b = (Ndown - Nup) / (Nup + Ndown)
        dA1b = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        A1b  = np.nan
        dA1b = np.nan

    # SEGMENT 3
    Nup   = ((Z_position >= zacceptance_max - 0.001) & (Time_Annihilation > wait_ramp2) & (Time_Annihilation < Tramp3)).sum()
    Ndown = ((Z_position <= zacceptance_min + 0.001) & (Time_Annihilation > wait_ramp2) & (Time_Annihilation < Tramp3)).sum()

    print(f"{bias}, segmet 3: {Nup + Ndown}")
    
    if((Nup + Ndown) > 0):
        A2 = (Ndown - Nup) / (Nup + Ndown)
        dA2 = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        A2  = np.nan
        dA2 = np.nan

    Nup   = ((Z_position >= zacceptance_max - 0.001) & (Time_Annihilation > Tramp3)).sum()
    Ndown = ((Z_position <= zacceptance_min + 0.001) & (Time_Annihilation > Tramp3)).sum()

    print(f"{bias}, segmet 3: {Nup + Ndown}")
    
    if((Nup + Ndown) > 0):
        A2b = (Ndown - Nup) / (Nup + Ndown)
        dA2b = np.sqrt(abs(1 - A**2)/(Nup + Ndown))
    else:
        A2b  = np.nan
        dA2b = np.nan
    
    return [A0,A1,A2,A, A0b, A1b, A2b], [dA0,dA1,dA2,dA,dA0b,dA1b,dA2b]

# Make Plot Nicer
def plotter_nicer():
    plt.ylabel(r"S = $\frac{N_{\downarrow} - N_{\uparrow}}{N_{\uparrow} + N_{\downarrow}}$", fontsize = 18, loc = "top")
    plt.xlabel("bias", loc = 'right', fontsize = 18)
    
    plt.grid()
    plt.minorticks_on()
    plt.grid(which='major', linestyle='-', color='black', alpha = 0.5) #Griglia maggiore: linea continua nera
    plt.grid(which='minor', linestyle=':', color='gray') #Griglia minore: linea tratteggiata grigia
    plt.ylim(-1.1,1.1)
    #plt.xlim(-3, 3)
    
    plt.axhline(0.0, linestyle = "-",  color = "red",    alpha = 1, linewidth = 0.75)
    #plt.text(-2.9, 0.005, "balance escape 0.0", color = "red")
    plt.axvline(0,   linestyle = "-",  color = "black",  linewidth = 0.75)
    #plt.axvline(-2,   linestyle = "-",  color = "black",  linewidth = 0.75)
    plt.axvline(-1,  linestyle = "-", color = "maroon", linewidth = 0.75)
    plt.text( -1. + 0.02, 0.65, "-1.0g bias", rotation = 90, color = "maroon")

# %%
files = os.listdir("../toy/output/output_scurve")

outputs = ["../toy/output/output_scurve/" + item for item in files if ".npz" in item]
print("Outputs files: \n", outputs)

simulation_dataset = {}

A0,   A1,  A2, At  = [],[],[],[]
A0b,   A1b,  A2b  = [],[],[]
dA0, dA1, dA2, dAt = [],[],[],[]
dA0b, dA1b, dA2b = [],[],[]

biases = []

for output in outputs:
    print("-"*20)
    bias = output.split("_")[2].replace(".npz","") # get the bias
    A, dA = get_annihilations(output, bias)

    A0.append(A[0])
    A1.append(A[1])
    A2.append(A[2])
    At.append(A[3])
    A0b.append(A[4])
    A1b.append(A[5])
    A2b.append(A[6])
    
    dA0.append(dA[0])
    dA1.append(dA[1])
    dA2.append(dA[2])
    dAt.append(dA[3])
    dA0b.append(dA[4])
    dA1b.append(dA[5])
    dA2b.append(dA[6])

    print(bias, f"{A[0]:.2}",  f"{dA[0]:.2f}")
    print(bias, f"{A[1]:.2f}", f"{dA[1]:.2f}")
    print(bias, f"{A[2]:.2f}", f"{dA[2]:.2f}")

    biases.append( float( bias.replace("p",".").replace("g","") ))

biases = np.array(biases)
#print(biases)

At = np.array(At)
dAt = np.array(dAt)
A0 = np.array(A0)
A1 = np.array(A1)
A2 = np.array(A2)
A0b = np.array(A0)
A1b = np.array(A1b)
A2b = np.array(A2b)
A0 = np.array(A0)
dA1 = np.array(dA1)
dA2 = np.array(dA2)
dA0b = np.array(dA0)
dA1b = np.array(dA1b)
dA2b = np.array(dA2b)

plt.figure(1, figsize = (10,8))
plotter_nicer()

idx = np.argsort(biases)

plt.xlim(-2.1,0.1)
#plt.errorbar(biases, A0, marker = "s", linestyle = "", label = "1st segment")
plt.errorbar(biases[idx], A1[idx],dA1[idx], marker = ".", linestyle = "", markersize = 8,color = "darkorange", capsize = 4, label = "2nd segment")
plt.errorbar(biases[idx], A1b[idx],dA1b[idx], marker = "^", linestyle = "dotted", markersize = 6,color = "darkorange", capsize = 4, label = "2nd segment boiloff")
plt.errorbar(biases[idx], A2[idx],dA2[idx], marker = ".", linestyle = "", markersize = 8, color = "blue", capsize = 4, label = "3rd segment")
plt.errorbar(biases[idx], A2b[idx],dA2b[idx], marker = "^", linestyle = "dotted", markersize = 6,  color = "blue",capsize = 4, label = "3rd segment boiloff")


plt.errorbar(biases[idx], At[idx],dAt[idx], marker = ".", linestyle = "", markersize = 8, capsize = 4, label = "all segment + boiloff", color = "crimson")
plt.xticks(biases[idx], rotation = 45, fontsize = 7)

plt.legend()
plt.savefig("Simulated_Scurve.png", bbox_inches = 'tight')
# Out:
# Outputs files:
#  ['../toy/output/output_scurve/output_0p05g.npz.npz', '../toy/output/output_scurve/output_0g.npz.npz', '../toy/output/output_scurve/output_-0p1g.npz.npz', '../toy/output/output_scurve/output_-1p25g.npz.npz', '../toy/output/output_scurve/output_-0p5g.npz.npz', '../toy/output/output_scurve/output_-0p05g.npz.npz', '../toy/output/output_scurve/output_0p75g.npz.npz', '../toy/output/output_scurve/output_-0p375g.npz.npz', '../toy/output/output_scurve/output_-0p3g.npz.npz', '../toy/output/output_scurve/output_0p1g.npz.npz', '../toy/output/output_scurve/output_-0p25g.npz.npz', '../toy/output/output_scurve/output_-1g.npz.npz', '../toy/output/output_scurve/output_1p25g.npz.npz', '../toy/output/output_scurve/output_0p5g.npz.npz', '../toy/output/output_scurve/output_0p25g.npz.npz', '../toy/output/output_scurve/output_-0p75g.npz.npz']
# --------------------
# 0p05g, segmet 1: 9
# 0p05g, segmet 1: 73
# 0p05g, segmet 2: 335
# 0p05g, segmet 2: 825
# 0p05g, segmet 3: 404
# 0p05g, segmet 3: 1064
# 0p05g 0.33 0.32
# 0p05g 0.81 0.05
# 0p05g 0.74 0.05
# --------------------
# 0g, segmet 1: 10
# 0g, segmet 1: 73
# 0g, segmet 2: 328
# 0g, segmet 2: 834
# 0g, segmet 3: 424
# 0g, segmet 3: 1056
# 0g -0.2 0.32
# 0g -0.04 0.06
# 0g 0.08 0.05
# --------------------
# -0p1g, segmet 1: 9
# -0p1g, segmet 1: 78
# -0p1g, segmet 2: 390
# -0p1g, segmet 2: 849
# -0p1g, segmet 3: 403
# -0p1g, segmet 3: 1072
# -0p1g -0.33 0.32
# -0p1g -0.86 0.05
# -0p1g -0.76 0.05
# --------------------
# -1p25g, segmet 1: 7
# -1p25g, segmet 1: 80
# -1p25g, segmet 2: 436
# -1p25g, segmet 2: 880
# -1p25g, segmet 3: 502
# -1p25g, segmet 3: 1034
# -1p25g -0.71 0.31
# -1p25g -0.94 0.04
# -1p25g -0.88 0.04
# --------------------
# -0p5g, segmet 1: 11
# -0p5g, segmet 1: 60
# -0p5g, segmet 2: 348
# -0p5g, segmet 2: 843
# -0p5g, segmet 3: 471
# -0p5g, segmet 3: 1077
# -0p5g -0.45 0.27
# -0p5g -0.89 0.05
# -0p5g -0.86 0.04
# --------------------
# -0p05g, segmet 1: 11
# -0p05g, segmet 1: 73
# -0p05g, segmet 2: 365
# -0p05g, segmet 2: 858
# -0p05g, segmet 3: 408
# -0p05g, segmet 3: 1008
# -0p05g -0.45 0.29
# -0p05g -0.78 0.05
# -0p05g -0.76 0.05
# --------------------
# 0p75g, segmet 1: 13
# 0p75g, segmet 1: 61
# 0p75g, segmet 2: 361
# 0p75g, segmet 2: 870
# 0p75g, segmet 3: 455
# 0p75g, segmet 3: 985
# 0p75g 0.69 0.24
# 0p75g 0.92 0.05
# 0p75g 0.84 0.04
# --------------------
# -0p375g, segmet 1: 11
# -0p375g, segmet 1: 63
# -0p375g, segmet 2: 356
# -0p375g, segmet 2: 867
# -0p375g, segmet 3: 444
# -0p375g, segmet 3: 1049
# -0p375g -1.0 0.28
# -0p375g -0.87 0.05
# -0p375g -0.76 0.04
# --------------------
# -0p3g, segmet 1: 7
# -0p3g, segmet 1: 64
# -0p3g, segmet 2: 379
# -0p3g, segmet 2: 868
# -0p3g, segmet 3: 439
# -0p3g, segmet 3: 1012
# -0p3g -0.71 0.35
# -0p3g -0.91 0.05
# -0p3g -0.80 0.04
# --------------------
# 0p1g, segmet 1: 14
# 0p1g, segmet 1: 67
# 0p1g, segmet 2: 342
# 0p1g, segmet 2: 819
# 0p1g, segmet 3: 423
# 0p1g, segmet 3: 1033
# 0p1g 0.71 0.26
# 0p1g 0.91 0.05
# 0p1g 0.73 0.05
# --------------------
# -0p25g, segmet 1: 15
# -0p25g, segmet 1: 63
# -0p25g, segmet 2: 379
# -0p25g, segmet 2: 830
# -0p25g, segmet 3: 381
# -0p25g, segmet 3: 1046
# -0p25g -0.33 0.24
# -0p25g -0.92 0.05
# -0p25g -0.77 0.05
# --------------------
# -1g, segmet 1: 9
# -1g, segmet 1: 66
# -1g, segmet 2: 375
# -1g, segmet 2: 855
# -1g, segmet 3: 501
# -1g, segmet 3: 1092
# -1g -0.33 0.29
# -1g -0.93 0.04
# -1g -0.87 0.04
# --------------------
# 1p25g, segmet 1: 10
# 1p25g, segmet 1: 78
# 1p25g, segmet 2: 388
# 1p25g, segmet 2: 808
# 1p25g, segmet 3: 424
# 1p25g, segmet 3: 1020
# 1p25g 0.6 0.25
# 1p25g 0.92 0.04
# 1p25g 0.84 0.04
# --------------------
# 0p5g, segmet 1: 20
# 0p5g, segmet 1: 71
# 0p5g, segmet 2: 380
# 0p5g, segmet 2: 827
# 0p5g, segmet 3: 435
# 0p5g, segmet 3: 1020
# 0p5g 0.9 0.20
# 0p5g 0.93 0.05
# 0p5g 0.83 0.04
# --------------------
# 0p25g, segmet 1: 8
# 0p25g, segmet 1: 72
# 0p25g, segmet 2: 343
# 0p25g, segmet 2: 812
# 0p25g, segmet 3: 439
# 0p25g, segmet 3: 1066
# 0p25g 0.75 0.33
# 0p25g 0.92 0.05
# 0p25g 0.80 0.04
# --------------------
# -0p75g, segmet 1: 21
# -0p75g, segmet 1: 82
# -0p75g, segmet 2: 355
# -0p75g, segmet 2: 908
# -0p75g, segmet 3: 459
# -0p75g, segmet 3: 1036
# -0p75g -0.52 0.19
# -0p75g -0.92 0.05
# -0p75g -0.83 0.04
