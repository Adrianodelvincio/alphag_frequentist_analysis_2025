# %% [markdown]
# ### 18 bin Analysis
# - Z regiong: [−903,−183]
# - zmin = -903       # Z cut
# - zmax = -183       # Z cut
# - z_gapmin = -183.  # Z cut
# - z_gapmax = -903.  # Z cut
#
# ### Ag Analysis Note Cuts
# - zmin = -871       # Z cut
# - zmax = -215       # Z cut
# - z_gapmin = -671.  # Z cut
# - z_gapmax = -415.  # Z cut
#
# ### Simone Cuts
# - zmin = -875.4
# - zmax = -219.3
# - z_gapmin = -675.4  # Z cut
# - z_gapmax = -419.3  # Z cut
#
# ### 2023 Nature
# - zmin = -867.350
# - zmax = -227.350
# - z_gapmin = -667.350
# - z_gapmax = -427.350

# %%
import papermill as pm
import numpy as np
######################
output_name = f"Simulation_0.ipynb"
print(f"\n>>> Executing {output_name}")
pm.execute_notebook(
    "Simulation-v2.ipynb",       # Notebook base (input)
    f"analysis_output/{output_name}.ipynb",   # Dove salvare l'output
    parameters={'L': 6,
               'Dsigma': 0.08}
)


######################
output_name = f"Simulation_1.ipynb"
print(f"\n>>> Executing {output_name}")
pm.execute_notebook(
    "Simulation-v2.ipynb",       # Notebook base (input)
    f"analysis_output/{output_name}.ipynb",   # Dove salvare l'output
    parameters={'L': 4,
               'Dsigma': 0.08}
)

######################
output_name = f"Simulation-2.ipynb"
print(f"\n>>> Executing {output_name}")
pm.execute_notebook(
    "Simulation-v2.ipynb",       # Notebook base (input)
    f"analysis_output/{output_name}.ipynb",   # Dove salvare l'output
    parameters={'L': 3,
               'Dsigma': 0.08}
)

######################
output_name = f"Simulation-3.ipynb"
print(f"\n>>> Executing {output_name}")
pm.execute_notebook(
    "Simulation-v2.ipynb",       # Notebook base (input)
    f"analysis_output/{output_name}.ipynb",   # Dove salvare l'output
    parameters={'L': 2,
               'Dsigma': 0.08}
)

######################
output_name = f"Simulation-4.ipynb"
print(f"\n>>> Executing {output_name}")
pm.execute_notebook(
    "Simulation-v2.ipynb",       # Notebook base (input)
    f"analysis_output/{output_name}.ipynb",   # Dove salvare l'output
    parameters={'L': 1,
               'Dsigma': 0.08}
)
