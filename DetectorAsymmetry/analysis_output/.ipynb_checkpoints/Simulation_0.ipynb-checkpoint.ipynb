# %%
import ROOT
from scipy import interpolate as interpolate
from scipy.stats import norm
import numpy as np
from utils import NonUniformStat, append_to_dict
import json
from matplotlib import pyplot as plt

# %%
BIAS = {}

with open("bias_dictionary.json", "r", encoding="utf-8") as f:
    BIAS = json.load(f)

tot_event, Dmu, Dsigma, nB_value = 0,0,0,0
#distribution = [169, 162, 188, 133, 121, 130, 162, 137, 195, 171, 154]

# load configuration file and read the configurations
with open("config.txt", 'r') as file:
    for line in file:
        line = line.strip()
        line = line.replace(" ","")
        if not ("#" in line):
            print(line)
        if not line:
            continue
        if 'Ntot' in line:
            key, value = line.split('=')
            tot_event = int(value)
        if 'nB_val' in line:
            key, value = line.split('=')
            nB_val = int(value)
        if 'Dmu' in line:
            key, value = line.split('=')
            Dmu = float(value)
        if 'Dsigma' in line:
            key, value = line.split('=')
            Dsigma = float(value)
        if 'real_gravity' in line:
            key, value = line.split('=')
            real_gravity = float(value)
        if 'Ntoys' in line:
            key, value = line.split('=')
            Ntoys = int(value)
# Out:
# Dmu=+0.02
# Dsigma=0.08
# K=0.85
# real_gravity=-10
# Ntot=1100
# nB_val=7
# Ntoys=1000
# pfraction=0.5

# %%
Dmu    = Dmu
Dsigma = Dsigma
L      = 4
print(Dmu)
# Out:
# 0.02

# %%
# Parameters
L = 6
Dsigma = 0.08

# %%
BIAS = {}
biasList = np.linspace( (real_gravity/10 - L/2)*10, (real_gravity/10 + L/2)*10, 7)
#print(f"bias list is {biasList}")

for bias in biasList:
    BIAS.update({f"{(bias/10):.1f}g" : int(bias)})

print(BIAS)

weights = {} # define the dictionary containing the statistics
for key, value in BIAS.items():
    weights.update( {key: int(tot_event/len(BIAS.values())) })
# Out:
# {'-4.0g': -40, '-3.0g': -30, '-2.0g': -20, '-1.0g': -10, '0.0g': 0, '1.0g': 10, '2.0g': 20}

# %% [markdown]
# # Spline approximated with LINEAR SLOPE

# %%
def scurve_model(x, L, g):
    result = 0
    if((-L/2 + g) < x and x < ( L/2 + g)):
        result = 2/L * (x - g)
    elif((-L/2 +g) >= x):
        result = -.99
    elif(x >= ( L/2 + g )):
        result = +.99
    return result

print("linear scurve evaluated at -2 : %.1f" % scurve_model(-2,2,-1))
print("linear scurve evaluated at -1.5 : %.1f" % scurve_model(-1.5,2,-1))
print("linear scurve evaluated at -1 : %.1f" % scurve_model(-1,2,-1))
print("linear scurve evaluated at -.5 : %.1f" % scurve_model(-.5,2,-1))
print("linear scurve evaluated at -2 : %.1f" % scurve_model(-2,2,-1))
print("linear scurve evaluated at 0 : %.1f"  % scurve_model(0,2,-1))
print("linear scurve evaluated at 1 : %.1f"  % scurve_model(1,2,-1))
print("linear scurve evaluated at 1 : %.1f"  % scurve_model(10,2,-1))
# Out:
# linear scurve evaluated at -2 : -1.0
# linear scurve evaluated at -1.5 : -0.5
# linear scurve evaluated at -1 : 0.0
# linear scurve evaluated at -.5 : 0.5
# linear scurve evaluated at -2 : -1.0
# linear scurve evaluated at 0 : 1.0
# linear scurve evaluated at 1 : 1.0
# linear scurve evaluated at 1 : 1.0

# %%
import csv

# ===  generate the True Asymemtry from Simulation
ASYMMETRY_TRUE = {}
for key, value in BIAS.items():
    ASYMMETRY_TRUE.update({key : float(scurve_model(value/10, L, real_gravity/10))})
    
print(ASYMMETRY_TRUE)

# Create simulation file
rows = []
for bias in np.linspace(-11, 9, 200):
    rows.append([bias, scurve_model(bias, L, real_gravity/10)])  # ogni riga = [bias, valore]
    print(bias, scurve_model(bias, L, 1) )

# 6.286432160804022 0.99
# 6.386934673366834 0.99
# 6.48743718592965 0.99
# 6.5879396984924625 0.99
# 6.688442211055278 0.99
# 6.788944723618091 0.99
# 6.8894472361809065 0.99
# 6.989949748743719 0.99
# 7.090452261306535 0.99
# 7.190954773869347 0.99
# 7.291457286432163 0.99
# 7.391959798994975 0.99
# 7.492462311557791 0.99
# 7.592964824120603 0.99
# 7.693467336683419 0.99
# 7.793969849246231 0.99
# 7.894472361809047 0.99
# 7.994974874371859 0.99
# 8.095477386934675 0.99
# 8.195979899497488 0.99
# 8.296482412060303 0.99
# 8.396984924623116 0.99
# 8.497487437185931 0.99
# 8.597989949748744 0.99
# 8.69849246231156 0.99
# 8.798994974874372 0.99
# 8.899497487437188 0.99
# 9.0 0.99

# %%
plt.figure(1)
xpoints = np.linspace(-5,5,100)
ypoints = [scurve_model(item, L, real_gravity/10) for item in xpoints]
plt.errorbar(xpoints, ypoints, marker = '.', color = 'blue')
plt.xticks([-5,-4,-3,-2,-1,0,1,2,3])
ypoints = [scurve_model(item/10, L, real_gravity/10) for item in biasList]
xpoints = np.array(biasList)/10
plt.errorbar(xpoints, ypoints, linestyle = "" ,marker = "*", color = "red")
plt.grid()

# %% [markdown]
# # Open The Workspace with the PDFs

# %%
f = ROOT.TFile("analysis_output/workspace.root")
w = f.Get("w")
w.Print("v")

w['c_pbarDn_1'].setVal(1.0); w['c_pbarDn_1'].setConstant(True)
w['c_pbarUp_1'].setVal(1.0); w['c_pbarUp_1'].setConstant(True)
# Out:
# RooWorkspace(w) w contents
#
# variables
# ---------
# (Z,biaskey,c_pbarDn_1,c_pbarDn_2,c_pbarUp_1,c_pbarUp_2,evtype)
#
# p.d.f.s
# -------
# RooHistPdf::hpdf_pbarDn_1[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarDn_2[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarUp_1[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::hpdf_pbarUp_2[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::pdf_cosm[ pdfObs=(Z) ] = 1.8628
# RooAddPdf::pdf_pbarDn[ c_pbarDn_1 * hpdf_pbarDn_1 + [%] * hpdf_pbarDn_2 ] = 0.0121951/1
# RooAddPdf::pdf_pbarUp[ c_pbarUp_1 * hpdf_pbarUp_1 + [%] * hpdf_pbarUp_2 ] = 0.844512/1
#
# datasets
# --------
# RooDataHist::rdhbin_pbarUp1(Z)
# RooDataHist::rdhbin_pbarUp2(Z)
# RooDataHist::rdhbin_pbarDn1(Z)
# RooDataHist::rdhbin_pbarDn2(Z)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::rhcosm(Z)

# %%
Z = w['Z']
zframe = Z.frame(Title = "Z Distributions, Templates")
w['pdf_pbarUp'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kRed))
w['pdf_pbarDn'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kBlue))
w['pdf_cosm'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kGreen))

c = ROOT.TCanvas("pdfs_templates", "pdfs_templates", 600, 600)
ROOT.gPad.SetLeftMargin(0.15)
zframe.GetYaxis().SetTitleOffset(1.4)
zframe.Draw()
c.Draw()
# Out:
# <div id="root_plot_1761646367777" style="width: 600px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1761646367777(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1006.55000521342,"fY1":-0.129843759674114,"fX2":-131.883332029978,"fY2":1.16859375967411,"fXtoAbsPixelk":685.86562344234,"fXtoPixelk":685.86562344234,"fXtoPixel":0.681402433947547,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-440.529475986742,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1006.55000521342,"fPixeltoXk":-1006.55000521342,"fPixeltoX":1.46756153218698,"fAbsPixeltoYk":1.16859375967411,"fPixeltoYk":-0.129843759674114,"fPixeltoY":-0.0022699956631962,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-875.35,"fUymin":0,"fUxmax":-219.35,"fUymax":1.03875,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"pdfs_templates","fTitle":"pdfs_templates","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;11 ...

# %% [markdown]
# # Create the RooDataSet

# %%
BiasCategory = ROOT.RooCategory("secondCategory", "a second category", BIAS)
BiasCategory.Print("v")

#dataset = ROOT.RooDataSet("data","data", ROOT.RooArgSet(Z,BiasCategory))
# Out:
# --- RooAbsArg ---
#   Value State: clean
#   Shape State: clean
#   Attributes:
#   Address: 0x623c614a9420
#   Clients:
#   Servers:
#   Proxies:
# --- RooAbsCategory ---
#   Value = -40 "-4.0g)
#   Possible states:
#     -1.0g	-10
#     -2.0g	-20
#     -3.0g	-30
#     -4.0g	-40
#     0.0g	0
#     1.0g	10
#     2.0g	20

# %%
simModelBase = ROOT.RooSimultaneous("model_base_simultaneous", "model for bias", BiasCategory)

# 2. Crea un mapping da categoria (es. "-1.0g") a PDF personalizzato

pdf_per_categoria = {} # senno muoiono

for category, weight in weights.items():
    print(f"Setting up PDF for category: {category}")
    
    # Calcolo degli eventi Up/Down
    Nup   = 0.5 * weight * (1 - ASYMMETRY_TRUE[category])
    Ndown = 0.5 * weight * (1 + ASYMMETRY_TRUE[category])
    
    # Costanti per RooAddPdf
    nup_const = ROOT.RooFit.RooConst(Nup)
    ndwn_const = ROOT.RooFit.RooConst(Ndown)
    
    # PDF composita per questa categoria
    model_i = ROOT.RooAddPdf(f"pdf_{category}", f"pdf_{category}",
                             ROOT.RooArgList(w['pdf_pbarUp'], w['pdf_pbarDn']),
                             ROOT.RooArgList(nup_const, ndwn_const))
    pdf_per_categoria[category] = model_i
    
    # Aggiungila alla simultanea
    simModelBase.addPdf(model_i, category)
# Out:
# Setting up PDF for category: -4.0g
# Setting up PDF for category: -3.0g
# Setting up PDF for category: -2.0g
# Setting up PDF for category: -1.0g
# Setting up PDF for category: 0.0g
# Setting up PDF for category: 1.0g
# Setting up PDF for category: 2.0g

# %%
# Generazione separata per ciascuna categoria
dataset = simModelBase.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
dataset.Print("v")
# Out:
# DataStore hmaster (hmaster)
#   Contains 14 entries
#   Observables:
#     1)               Z = -450  L(-875.35 - -219.35) B(2)  "Z"
#     2)  secondCategory = 2.0g(idx = 20)
#   "a second category"

# %%
ttable = dataset.table(BiasCategory)
ttable.Print("v")
# Out:
#   Table secondCategory : hmaster
#   +-------+-----+
#   | -4.0g | 153 |
#   | -3.0g | 137 |
#   | -2.0g | 173 |
#   | -1.0g | 176 |
#   |  0.0g | 158 |
#   |  1.0g | 164 |
#   |  2.0g | 162 |
#   +-------+-----+

# %%
c1 = ROOT.TCanvas("data_plot", "data_plot", 800, 800)

zframe1 = Z.frame( ROOT.RooFit.Bins(18), Title = "Plot of Z data")
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == -30'), ROOT.RooFit.MarkerColor(ROOT.kBlue),  ROOT.RooFit.Name("cat_-30"))
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == -20'), ROOT.RooFit.MarkerColor(ROOT.kRed),   ROOT.RooFit.Name("cat_-20"))
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == 30'), ROOT.RooFit.MarkerColor(ROOT.kGreen),  ROOT.RooFit.Name("cat_+30"))
#dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == +20'), ROOT.RooFit.MarkerColor(6),   ROOT.RooFit.Name("cat_-20"))
#w['model_base'].plotOn(zframe1)

#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "-3.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kBlue))
#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "-2.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kRed))
#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "+3.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kGreen))

zframe1.Draw()

# Crea la legenda
legend = ROOT.TLegend(0.6, 0.7, 0.88, 0.88)  # x1,y1,x2,y2 in NDC (posizione)
legend.SetBorderSize(0)
legend.SetFillStyle(0)
legend.AddEntry(zframe1.findObject("cat_-30"), "-3.0g", "lep")
legend.AddEntry(zframe1.findObject("cat_-20"), "-2.0g", "lep")
legend.AddEntry(zframe1.findObject("cat_+30"), "+3.0g", "lep")
legend.Draw()

c1.Draw()
# Out:
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 137 events out of 1123 total events
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 173 events out of 1123 total events
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 0 events out of 1123 total events
# <div id="root_plot_1761646368841" style="width: 800px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1761646368841(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-957.350006109476,"fY1":-16.9803757232289,"fX2":-137.349993890524,"fY2":152.823371387968,"fXtoAbsPixelk":929.329992082566,"fXtoPixelk":929.329992082566,"fXtoPixel":0.970731692852043,"fYtoAbsPixelk":694.799995398521,"fYtoPixelk":694.799995398521,"fYtoPixel":-4.54642499434627,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":772,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-957.350006109476,"fPixeltoXk":-957.350006109476,"fPixeltoX":1.03015076911929,"fAbsPixeltoYk":152.823371387968,"fPixeltoYk":-16.9803757232289,"fPixeltoY":-0.219953040299478,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-875.35,"fUymin":0,"fUxmax":-219.35,"fUymax":135.842995664739,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"data_plot","fTitle":"data_plot","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:2 ...

# %% [markdown]
# # Construction of the model for the Simulation

# %%
w.Import(BiasCategory) # <== Import the category inside the workspace

w.factory("S[100,50, 10000]")
w.factory("E[0.0, -1.5, 1.5]")
w.factory(f"D[{Dmu}, -0.8, 0.8]")

w.factory("SUM::model_base( Nup[30,10000] * pdf_pbarUp, Ndwn[30,1000] * pdf_pbarDn, nB[1, 200] * pdf_cosm)") # <<< Add pdf_cosm in the future
# A = (Ndwn - Nup)/(Ndwn + Nup)
w.factory(f"EDIT::model_MAGB(model_base, Nup=expr('0.5*S*(1-E)', S, E), Ndwn = expr('0.5*S*(1+E)', S, E))")

w.factory(f"Gaussian::Dconstr(D,{Dmu},{Dsigma})") # constrain on D, efficiency

w.factory("SIMCLONE::model_fit( model_MAGB, $SplitParam({S,E}, secondCategory ))") # Clone the Models

w.Print()
# Out:
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCategory::secondCategory
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (D,E,E_-1.0g,E_-2.0g,E_-3.0g,E_-4.0g,E_0.0g,E_1.0g,E_2.0g,Ndwn,Nup,S,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,Z,biaskey,c_pbarDn_1,c_pbarDn_2,c_pbarUp_1,c_pbarUp_2,evtype,nB,secondCategory)
#
# p.d.f.s
# -------
# RooGaussian::Dconstr[ x=D mean=0.02 sigma=0.08 ] = 1
# RooHistPdf::hpdf_pbarDn_1[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarDn_2[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarUp_1[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::hpdf_pbarUp_2[ pdfObs=(Z) ] = 0.844512
# RooAddPdf::model_MAGB[ model_MAGB_2 * pdf_pbarUp + model_MAGB_3 * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.0g[ model_MAGB_2_-1.0g * pdf_pbarUp + model_MAGB_3_-1.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-2.0g[ model_MAGB_2_-2.0g * pdf_pbarUp + model_MAGB_3_-2.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-3.0g[ model_MAGB_2_-3.0g * pdf_pbarUp + model_MAGB_3_-3.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-4.0g[ model_MAGB_2_-4.0g * pdf_pbarUp + model_MAGB_3_-4.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_0.0g[ model_MAGB_2_0.0g * pdf_pbarUp + model_MAGB_3_0.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_1.0g[ model_MAGB_2_1.0g * pdf_pbarUp + model_MAGB_3_1.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_2.0g[ model_MAGB_2_2.0g * pdf_pbarUp + model_MAGB_3_2.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_base[ Nup * pdf_pbarUp + Ndwn * pdf_pbarDn + nB * pdf_cosm ] = 0.786559/1
# RooSimultaneous::model_fit[ indexCat=secondCategory -1.0g=model_MAGB_-1.0g -2.0g=model_MAGB_-2.0g -3.0g=model_MAGB_-3.0g -4.0g=model_MAGB_-4.0g 0.0g=model_MAGB_0.0g 1.0g=model_MAGB_1.0g 2.0g=model_MAGB_2.0g ] = 0.16391
# RooHistPdf::pdf_cosm[ pdfObs=(Z) ] = 1.8628
# RooAddPdf::pdf_pbarDn[ c_pbarDn_1 * hpdf_pbarDn_1 + [%] * hpdf_pbarDn_2 ] = 0.0121951/1
# RooAddPdf::pdf_pbarUp[ c_pbarUp_1 * hpdf_pbarUp_1 + [%] * hpdf_pbarUp_2 ] = 0.844512/1
#
# functions
# --------
# RooFormulaVar::model_MAGB_2[ actualVars=(S,E) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.0g[ actualVars=(S_-1.0g,E_-1.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-2.0g[ actualVars=(S_-2.0g,E_-2.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-3.0g[ actualVars=(S_-3.0g,E_-3.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-4.0g[ actualVars=(S_-4.0g,E_-4.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_0.0g[ actualVars=(S_0.0g,E_0.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_1.0g[ actualVars=(S_1.0g,E_1.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_2.0g[ actualVars=(S_2.0g,E_2.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_3[ actualVars=(S,E) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.0g[ actualVars=(S_-1.0g,E_-1.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-2.0g[ actualVars=(S_-2.0g,E_-2.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-3.0g[ actualVars=(S_-3.0g,E_-3.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-4.0g[ actualVars=(S_-4.0g,E_-4.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_0.0g[ actualVars=(S_0.0g,E_0.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_1.0g[ actualVars=(S_1.0g,E_1.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_2.0g[ actualVars=(S_2.0g,E_2.0g) formula="0.5*S*(1+E)" ] = 50
#
# datasets
# --------
# RooDataHist::rdhbin_pbarUp1(Z)
# RooDataHist::rdhbin_pbarUp2(Z)
# RooDataHist::rdhbin_pbarDn1(Z)
# RooDataHist::rdhbin_pbarDn2(Z)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::rhcosm(Z)

# %%
g = ROOT.TGraph("simulation.csv","%lg,%lg")
# create RooRealVar
w.factory('c[0,-30,30]')
#create RooRealVar
w.factory('scale[0.1]')
#w['scale'].setConstant(True)
w["nB"].setVal(nB_val)

# === Definisci la curva S come TF1 + RooTFnBinding ===
def Scurve_fn(x, p):
    # 10 is an offset of the simulation
    offset = -10
    bias = x[0]
    c = p[0]
    scale = p[1]
    D = p[2]
    return (g.Eval((x[0] - c + offset) * scale) - D)/(1 - g.Eval((x[0] - c + offset) * scale)*D)

# === Print values of the Scurve for a collection of biases ===
print("-"*8)
for key,value in BIAS.items():
    val = Scurve_fn([value], [w["c"].getVal(), w['scale'].getVal(), w['D'].getVal()])
    print(f"{key}| {value} | {w['c'].getVal()} | {val}")
print("-"*8)

# === create the RooFit model from the Scurve ===
Scurve_TF1 = ROOT.TF1("Scurve",Scurve_fn, -50, 50, 3) # not possible to put in workspace

cust = ROOT.RooCustomizer(w.pdf('model_fit'), "scurve");

vcat={}
nasy={}
for bkt, bias_val in BIAS.items():
    v = ROOT.RooRealVar(f"vat_{bkt}", "", bias_val)
    # Creo una funzione parametrica RooTFnBinding che connette il TF1 alla variabile 'v'
    # Il TF1 ha 3 parametri: c, scale, D — sono usati qui come [c, scale, D]
    asy = ROOT.RooTFnBinding(f"nasy_{bkt}", "", Scurve_TF1, v, [w['c'], w['scale'], w['D']])
    # Salvo queste entità nei dizionari
    vcat[bkt] = v
    nasy[bkt] = asy

    # Ottengo la variabile originale 'E_{bkt}' nel modello
    A = w.var(f'E_{bkt}')

    # Sostituisco E_{bkt} con la funzione curva S corrispondente
    cust.replaceArg(A, asy)

scurve_all = cust.build(True)

scurvemap = {}
for bkt, bias_val in BIAS.items():
    scurvemap.update({bkt : scurve_all.getPdf(bkt) })
    S = w.var(f'S_{bkt}')

    val = ttable.get(bkt)
    err = np.sqrt(val)
    
    #S.setMin(val-10*err)
    #S.setMax(val+10*err)
    S.setVal(val)
    print(f"setting  {val}  [{val - 10*err}  {val + 10*err}]")
    #S.setError(err)

scurve_fit = ROOT.RooSimultaneous("scurve_fit","scurve_fit", scurvemap, BiasCategory)
# Out:
# --------
# -4.0g| -40 | 0.0 | -0.990390272602471
# -3.0g| -30 | 0.0 | -0.9893123637612633
# -2.0g| -20 | 0.0 | -0.6776315789473684
# -1.0g| -10 | 0.0 | -0.3509933774834437
# 0.0g| 0 | 0.0 | -0.02
# 1.0g| 10 | 0.0 | 0.31543624161073824
# 2.0g| 20 | 0.0 | 0.6554054054054054
# --------
# setting  153.0  [29.3068312314702  276.6931687685298]
# setting  137.0  [19.953000892803743  254.04699910719626]
# setting  173.0  [41.47053562034094  304.5294643796591]
# setting  176.0  [43.33500838578402  308.664991614216]
# setting  158.0  [32.30194910023465  283.69805089976535]
# setting  164.0  [35.93751525134303  292.06248474865697]
# setting  162.0  [34.72077938642144  289.27922061357856]
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.0g will be replaced by nasy_-1.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-2.0g will be replaced by nasy_-2.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-3.0g will be replaced by nasy_-3.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-4.0g will be replaced by nasy_-4.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_0.0g will be replaced by nasy_0.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_1.0g will be replaced by nasy_1.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_2.0g will be replaced by nasy_2.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooSimultaneous::model_fit cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-3.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-3.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-3.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-4.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-4.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-4.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_0.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_0.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_0.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_2.0g cloned: depends on a replaced parameter

# %%
w['D'].setConstant(True)

w['c'].setError(20)
result = scurve_fit.fitTo(dataset,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 #ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(2),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.Minos(w['c']))

c     = w.var('c')
scale = w.var('scale')
D = w.var('D')

# === 8. Risultati
print("\n=== RISULTATI DEL FIT ===")
print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
print(f"fit status: {result.status()}")
# Out:
# === RISULTATI DEL FIT ===
# c     = -1.0294 ± 0.0956; [-0.044569150563812505,+0.07914345657129093]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 4500 convergence for edm < 1 strategy 2
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 4599.76175147263348
# Edm   = 0.000178250893991410274
# Nfcn  = 319
# S_-1.0g	  = 175.042	 +/-  13.269	(limited)
# S_-2.0g	  = 172.058	 +/-  13.1557	(limited)
# S_-3.0g	  = 136.083	 +/-  11.7039	(limited)
# S_-4.0g	  = 152.206	 +/-  12.3683	(limited)
# S_0.0g	  = 157.031	 +/-  12.5721	(limited)
# S_1.0g	  = 163.046	 +/-  12.8083	(limited)
# S_2.0g	  = 161.218	 +/-  12.7282	(limited)
# c	  = -10.2942	 +/-  0.956078	(limited)
# nB	  = 1.00006	 +/-  1.18717	(limited)
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS LOWER error for parameter #7 : c using max-calls 4500, tolerance 1
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS UPPER error for parameter #7 : c using max-calls 4500, tolerance 1
# Minos: Lower error for parameter c  :  -0.445692
# Minos: Upper error for parameter c  :  0.791435
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       4685.772143 Edm =       72.84025518 NCalls =     39
# Info in <Minuit2>: MnSeedGenerator run Hesse - Initial seeding state:
#   Minimum value : 4685.772143
#   Edm           : 75.0626837
#   Internal parameters:	[     -1.345255787      -1.34796827     -1.383507007     -1.366956419     -1.362049858     -1.356307984     -1.358204968                0     -1.221747644]
#   Internal gradient  :	[        51.372419      58.17040301        99.955715      29.12791025      44.75521631      39.55509158      29.70940824      363.7661539     -24.59008872]
#   Internal covariance matrix:
# [[  0.00032946752    3.15209e-05  3.1172781e-05  1.3339752e-05  2.4631924e-05  2.1254037e-05  1.6179609e-05 -0.00015113689 -0.00074183894]
#  [    3.15209e-05  0.00034211883  3.5659842e-05   1.521003e-05  2.8119894e-05  2.4251979e-05   1.847929e-05 -0.00018732915  -0.0008458472]
#  [  3.1172781e-05  3.5659842e-05  0.00038077978  1.5088427e-05  2.7861944e-05  2.4040742e-05  1.8301535e-05 -0.00017142032 -0.00083908475]
#  [  1.3339752e-05   1.521003e-05  1.5088427e-05  0.00031790866  1.1948632e-05  1.0315378e-05   7.844622e-06 -6.6598918e-05  -0.0003603283]
#  [  6.5020711e-07  7.1128134e-07 -9.8504548e-08  0.00030438498  6.8710073e-07  6.8940648e-07  3.2570034e-07 -3.4536837e-06]
#  [  1.0847882e-06  1.1944633e-06 -1.2730518e-07  6.8710073e-07  0.00030119321   1.113445e-06  3.6374565e-07 -4.5910458e-06]
#  [  1.0814804e-06  1.1947479e-06 -1.0952181e-07  6.8940648e-07   1.113445e-06  0.00029614562  2.7305069e-07 -4.3979417e-06]
#  [  4.4670018e-07  5.3301668e-07  1.1269906e-07  3.2570034e-07  3.6374565e-07  2.7305069e-07  0.00029534209 -4.0845581e-06]
#  [ -4.1970728e-06 -4.1916734e-06 -4.3164842e-06 -3.4536837e-06 -4.5910458e-06 -4.3979417e-06 -4.0845581e-06    0.046877459]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 4500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       4600.261845 Edm =   8.164392661e-05 NCalls =     19
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       4600.261763 Edm =   2.173866098e-10 NCalls =     36
# Info in <Minuit2>: MnFunctionCross Result after new Migrad: FCN =       4600.261763 Edm =   2.173866098e-10 NCalls =     36
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |    S_-1.0g | limited |        174.98162 |  13.28957272
#     1 |    S_-2.0g | limited |      171.9859389 |   13.1799643
#     2 |    S_-3.0g | limited |      136.0665773 |  11.70210503
#     3 |    S_-4.0g | limited |      152.1632111 |  12.37380525
#     4 |     S_0.0g | limited |      156.9913079 |  12.59316445
#     5 |     S_1.0g | limited |      163.0246617 |  12.83052202
#     6 |     S_2.0g | limited |      161.2153384 |  12.71128654
#     7 |          c |  fixed  |     -9.502786373 | 0.9560790732
#     8 |         nB | limited |                1 |  1.161925122 (at lower limit)
# Info in <Minuit2>: MnMinos end of Minos scan for up interval for parameter c

# %%
scurve_fit.getParameters(dataset).Print('v')
# Out:
#   1) 0x623c618d4690 RooRealVar::          D = 0.02 C  L(-0.8 - 0.8)  "D"
#   2) 0x623c61bc9020 RooRealVar::    S_-1.0g = 175.042 +/- 13.2688  L(50 - 10000)  "S (-1.0g)"
#   3) 0x623c61be1590 RooRealVar::    S_-2.0g = 172.058 +/- 13.1556  L(50 - 10000)  "S (-2.0g)"
#   4) 0x623c61c7ba50 RooRealVar::    S_-3.0g = 136.083 +/- 11.7038  L(50 - 10000)  "S (-3.0g)"
#   5) 0x623c61c85610 RooRealVar::    S_-4.0g = 152.206 +/- 12.3681  L(50 - 10000)  "S (-4.0g)"
#   6) 0x623c61c8f1c0 RooRealVar::     S_0.0g = 157.031 +/- 12.5719  L(50 - 10000)  "S (0.0g)"
#   7) 0x623c61c98d70 RooRealVar::     S_1.0g = 163.046 +/- 12.8081  L(50 - 10000)  "S (1.0g)"
#   8) 0x623c61ca2920 RooRealVar::     S_2.0g = 161.218 +/- 12.728  L(50 - 10000)  "S (2.0g)"
#   9) 0x623c61b82d10 RooRealVar::          c = -10.2942 +/- (-0.445692,0.791435)  L(-30 - 30)  "c"
#  10) 0x623c5df2c0f0 RooRealVar:: c_pbarDn_1 = 1 C  L(0.71251 - 1)  "c_pbarDn_1"
#  11) 0x623c5a05dc60 RooRealVar:: c_pbarUp_1 = 1 C  L(-0.0202152 - 1)  "c_pbarUp_1"
#  12) 0x623c61abb710 RooRealVar::         nB = 1.00006 +/- 1.18748  L(1 - 200)  "nB"
#  13) 0x623c61bf1ef0 RooRealVar::      scale = 0.1 C  L(-INF - +INF)  "scale"
#  14) 0x623c61cc3f40 RooRealVar::  vat_-1.0g = -10 C  L(-INF - +INF)  ""
#  15) 0x623c5f574320 RooRealVar::  vat_-2.0g = -20 C  L(-INF - +INF)  ""
#  16) 0x623c62666d00 RooRealVar::  vat_-3.0g = -30 C  L(-INF - +INF)  ""
#  17) 0x623c5afd37d0 RooRealVar::  vat_-4.0g = -40 C  L(-INF - +INF)  ""
#  18) 0x623c61b82790 RooRealVar::   vat_0.0g = 0 C  L(-INF - +INF)  ""
#  19) 0x623c61bf2b40 RooRealVar::   vat_1.0g = 10 C  L(-INF - +INF)  ""
#  20) 0x623c61bf3180 RooRealVar::   vat_2.0g = 20 C  L(-INF - +INF)  ""

# %% [markdown]
# # SIMULATION, nominal case (2023 analysis), D set as constant

# %%
Ngravity = []
dNgravity = []

D.setConstant(True)

for i in range(0, Ntoys):
    c.setVal(real_gravity) # reset the value for simulation
    w["nB"].setVal(nB_val)

    for bias, stat in weights.items(): # reset the stat parameters
        w[f"S_{bias}"].setVal(stat)
        #w[f"S_{bias}"].setMin(stat - np.sqrt(stat)*10)
        #w[f"S_{bias}"].setMin(stat + np.sqrt(stat)*10)
        print("tot_events:", stat, "set value:", w[f"S_{bias}"].getVal())
        
    
    pseudo_data = scurve_fit.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
    c.setVal(-10)
    result = scurve_fit.fitTo(pseudo_data,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 #ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(1),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.PrintLevel(-1),
                 ROOT.RooFit.Minos(w['c']))
    # === 8. Risultati
    print("\n=== RISULTATI DEL FIT ===")
    print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
    print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
    print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
    print(f"fit status: {result.status()}")

    if result.status() < 1 and not np.isnan(c.getError()) and c.getError() > 0:
        Ngravity.append(c.getVal()*scale.getVal() - real_gravity*scale.getVal())
        dNgravity.append(c.getError()*scale.getVal())

# === Normalized Residuals ===
res_norm = (np.array((Ngravity)))/np.array(dNgravity)
# Out:
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9704 ± 0.0988; [-0.09780298505990363,+0.08479027147125198]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9468 ± 0.0766; [-0.07764603184261536,+0.0780795172524979]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0352 ± 0.0520; [-0.04858024637746777,+0.04025246259635925]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9381 ± 0.0832; [-0.06453862813256422,+0.08580846502594028]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1304 ± 0.0703; [-0.07061096932616265,+0.07048080097798488]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0141 ± 0.1050; [-0.09779068260917288,+0.11039436276210515]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9812 ± 0.1041; [-0.14046523191160262,+0.053736021153244364]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8469 ± 0.0690; [-0.06885678973964708,+0.06950996930499538]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0523 ± 0.0917; [-0.09472263054072501,+0.0950143778692508]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9656 ± 0.1007; [-0.12054512418330626,+0.0659808108109895]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8508 ± 0.0679; [-0.06775645251911284,+0.06863719664151179]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9652 ± 0.0912; [-0.10700015307117416,+0.07898913381042914]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9834 ± 0.1023; [-0.09787257864643956,+0.09312458285745301]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9902 ± 0.0947; [-0.12748500452250724,+0.05094890051773814]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9877 ± 0.1000; [-0.09832413560563774,+0.0633709495603553]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1302 ± 0.0833; [-0.0823997955958278,+0.0847345627544744]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0985 ± 0.0815; [-0.08007872018874865,+0.09398057021441306]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8849 ± 0.0815; [-0.08110685018732644,+0.08243976761298139]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9705 ± 0.0878; [-0.08714593955363781,+0.03440227331729554]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0212 ± 0.0958; [-0.05155318092697658,+0.11518773477860755]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9390 ± 0.0711; [-0.0901121449262041,+0.07249596439509713]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.8981 ± 0.0737; [-0.07413876532869867,+0.07463110205073696]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9949 ± 0.0907; [-0.06415372542957203,+0.08005942473554575]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8469 ± 0.0730; [-0.07098416616677358,+0.07503063492185774]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9630 ± 0.0715; [-0.0704172214687102,+0.0745348733215024]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.8921 ± 0.0784; [-0.08442611293026026,+0.07834942966490324]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0907 ± 0.0798; [-0.07776205154431415,+0.15467036178775437]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8804 ± 0.0547; [-0.05495797261434098,+0.05745615896623525]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9342 ± 0.0720; [-0.07658769205696085,+0.06619663507661497]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8711 ± 0.0766; [-0.07653136898606873,+0.07700874936387535]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0833 ± 0.0804; [-0.07857175352123845,+0.09886414107958019]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
from matplotlib import pyplot as plt

#print(res_norm)
plt.figure(9, figsize = (18,8))
plt.subplot(1,2,1)
plt.title("Extracted g and Error", fontsize = 20)
plt.grid()
plt.hist(Ngravity, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(Ngravity):.3f} std: {np.std(Ngravity):.3f}')
plt.legend(fontsize = 15, loc = "upper right")
plt.subplot(1,2,2)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(res_norm, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(res_norm):.3f} std: {np.std(res_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")

# %% [markdown]
# # Fit with D

# %%
Ngravity = []
dNgravity = []
ND = []
dND = []

D.setConstant(False)

for i in range(0, Ntoys):
    c.setVal(real_gravity) # reset the value for simulation
    w["nB"].setVal(nB_val)
    D.setVal(Dmu + np.random.normal(loc = 0, scale = Dsigma))  # D detector asymmetry, add a "manual smearing, because the simulation does not account for a generation of D"
    
    for bias, stat in weights.items(): # reset the stat parameters
        #w[f"S_{bias}"].setMin(stat - np.sqrt(stat)*10)
        #w[f"S_{bias}"].setMin(stat + np.sqrt(stat)*10)
        w[f"S_{bias}"].setVal(stat)
        print("tot_events:", stat, "set value:", w[f"S_{bias}"].getVal())

    
    pseudo_data = scurve_fit.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
    c.setVal(-10)
    result = scurve_fit.fitTo(pseudo_data,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(1),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.PrintLevel(-1),
                 ROOT.RooFit.Verbose(False),   # disattiva log verboso
                 ROOT.RooFit.Warnings(False),  # opzionale: disattiva warning
                 ROOT.RooFit.Minos(w['c']))
    # === 8. Risultati
    print("\n=== RISULTATI DEL FIT ===")
    print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
    print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
    print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
    print(f"fit status: {result.status()}")

    if result.status() < 1 and not np.isnan(c.getError()) and c.getError() > 0:
        Ngravity.append(c.getVal()*scale.getVal() - real_gravity*scale.getVal())
        dNgravity.append(c.getError()*scale.getVal())
        ND.append(D.getVal() - Dmu)
        dND.append(D.getError())

# === Normalized Residuals ===
res_norm = (np.array((Ngravity)))/np.array(dNgravity)
Dres_norm = (np.array((ND)))/np.array(dND)
# Out:
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0706 ± 0.1097; [-0.11168934706769978,+0.1268883213411584]
# scale = 0.1000 ± 0.0000
# D     = 0.0079 ± 0.0524
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.2671 ± 0.1230; [-0.12418729872533102,+0.1208872162162613]
# scale = 0.1000 ± 0.0000
# D     = 0.0753 ± 0.0570
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1136 ± 0.1095; [-0.11959829637010777,+0.09875868856659163]
# scale = 0.1000 ± 0.0000
# D     = -0.0986 ± 0.0544
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8654 ± 0.0976; [-0.0880498751859058,+0.1086866449420748]
# scale = 0.1000 ± 0.0000
# D     = 0.0906 ± 0.0523
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9794 ± 0.1772; [-0.17530744729947978,+0.06950563493694221]
# scale = 0.1000 ± 0.0000
# D     = 0.0006 ± 0.0688
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9337 ± 0.1106; [-0.10385316975664456,+0.10083540097950433]
# scale = 0.1000 ± 0.0000
# D     = 0.1214 ± 0.0579
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.7293 ± 0.1105; [-0.10879369226503238,+0.11163366505255033]
# scale = 0.1000 ± 0.0000
# D     = -0.0645 ± 0.0545
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0351 ± 0.0710; [-0.05307549149342229,+0.09203025673220966]
# scale = 0.1000 ± 0.0000
# D     = -0.0503 ± 0.0441
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9345 ± 0.1140; [-0.11317329322037531,+0.10272850222728791]
# scale = 0.1000 ± 0.0000
# D     = 0.0264 ± 0.0565
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9285 ± 0.1083; [-0.1381013952489737,+0.1133499863164472]
# scale = 0.1000 ± 0.0000
# D     = 0.0316 ± 0.0540
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1080 ± 0.1241; [-0.13208750063910182,+0.11935927761820347]
# scale = 0.1000 ± 0.0000
# D     = -0.0043 ± 0.0574
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1788 ± 0.1201; [-0.12221276587867232,+0.11846042737669656]
# scale = 0.1000 ± 0.0000
# D     = 0.0384 ± 0.0555
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8861 ± 0.0978; [-0.12247358910344122,+0.10227046779444793]
# scale = 0.1000 ± 0.0000
# D     = 0.0130 ± 0.0521
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.2445 ± 0.1301; [-0.13463902228637628,+0.12469203165043502]
# scale = 0.1000 ± 0.0000
# D     = 0.0037 ± 0.0602
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8707 ± 0.1187; [-0.1732714331028334,+0.12476940653737655]
# scale = 0.1000 ± 0.0000
# D     = 0.0088 ± 0.0560
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0351 ± 0.1717; [-0.06962476145867755,+0.13958036477880903]
# scale = 0.1000 ± 0.0000
# D     = 0.0051 ± 0.0681
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0455 ± 0.1065; [-0.11931048402166589,+0.0715886757344617]
# scale = 0.1000 ± 0.0000
# D     = -0.1073 ± 0.0533
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9334 ± 0.0942; [-0.12325463952456948,+0.09801254652764547]
# scale = 0.1000 ± 0.0000
# D     = 0.0520 ± 0.0513
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9645 ± 0.0846; [-0.038710662729653886,+0.07711285326942349]
# scale = 0.1000 ± 0.0000
# D     = 0.1863 ± 0.0499
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0349 ± 0.1002; [-0.08150247134988563,+0.14927269147276287]
# scale = 0.1000 ± 0.0000
# D     = 0.0074 ± 0.0514
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8962 ± 0.1011; [-0.11516476404936526,+0.11051652815513346]
# scale = 0.1000 ± 0.0000
# D     = 0.0594 ± 0.0535
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9644 ± 0.0825; [-0.07717411558947412,+0.08249182757874784]
# scale = 0.1000 ± 0.0000
# D     = 0.0953 ± 0.0495
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9649 ± 0.0518; [-0.2033376773863239,+0.026229482451702448]
# scale = 0.1000 ± 0.0000
# D     = 0.0408 ± 0.0432
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1989 ± 0.1311; [-0.1308253947175852,+0.13197624350807646]
# scale = 0.1000 ± 0.0000
# D     = 0.1313 ± 0.0563
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9649 ± 0.1671; [-0.09367269302082433,+0.0699743466208285]
# scale = 0.1000 ± 0.0000
# D     = 0.0628 ± 0.0662
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.2537 ± 0.1073; [-0.11402239603185599,+0.09810850175592357]
# scale = 0.1000 ± 0.0000
# D     = -0.0375 ± 0.0542
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1004 ± 0.1229; [-0.12582516986742348,+0.17805787481048138]
# scale = 0.1000 ± 0.0000
# D     = 0.0073 ± 0.0559
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8778 ± 0.1125; [-0.25436187604047905,+0.11854702562416988]
# scale = 0.1000 ± 0.0000
# D     = -0.0459 ± 0.0547
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.1149 ± 0.1262; [-0.13305339826955695,+0.17345295521045406]
# scale = 0.1000 ± 0.0000
# D     = 0.0327 ± 0.0577
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9487 ± 0.0905; [-0.10234022721964076,+0.09755072208707662]
# scale = 0.1000 ± 0.0000
# D     = 0.0965 ± 0.0509
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0407 ± 0.1316; [-0.1546796451341664,+0.15058939646954317]
# scale = 0.1000 ± 0.0000
# D     = -0.0155 ± 0.0590
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9648 ± 0.1234; [-0.17488557642006375,+0.09552114718637086]
# scale = 0.1000 ± 0.0000
# D     = 0.0433 ± 0.0592
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9221 ± 0.0683; [-0.0916228640840412,+0.08101696393268888]
# scale = 0.1000 ± 0.0000
# D     = 0.0683 ± 0.0441
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8513 ± 0.1107; [-0.10787721077568675,+0.1123890139375571]
# scale = 0.1000 ± 0.0000
# D     = -0.0094 ± 0.0541
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9131 ± 0.1030; [-0.13174298329622128,+0.10866705305044447]
# scale = 0.1000 ± 0.0000
# D     = 0.0059 ± 0.0527
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9368 ± 0.1088; [-0.11503426700908632,+0.11589814768539625]
# scale = 0.1000 ± 0.0000
# D     = 0.0072 ± 0.0554
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0330 ± 0.1788; [-0.06275795410986548,+0.19849573984322466]
# scale = 0.1000 ± 0.0000
# D     = 0.0121 ± 0.0694
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8891 ± 0.1291; [-0.17233444099247977,+0.13639709907937655]
# scale = 0.1000 ± 0.0000
# D     = 0.0324 ± 0.0595
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1025 ± 0.1111; [-0.11493987552702122,+0.15464160655865888]
# scale = 0.1000 ± 0.0000
# D     = 0.0261 ± 0.0526
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9649 ± 0.2020; [-0.18343385784310473,+0.07293820227020513]
# scale = 0.1000 ± 0.0000
# D     = 0.0523 ± 0.0768
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1130 ± 0.1082; [-0.11424331536508409,+0.13787763125072458]
# scale = 0.1000 ± 0.0000
# D     = -0.0090 ± 0.0535
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0448 ± 0.1179; [-0.11329958873281021,+0.09482819985857066]
# scale = 0.1000 ± 0.0000
# D     = -0.0458 ± 0.0542
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9981 ± 0.1865; [-0.17170695626451712,+0.08482283434740764]
# scale = 0.1000 ± 0.0000
# D     = 0.0781 ± 0.0721
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0496 ± 0.1284; [-0.14194315974187077,+0.13677317887220583]
# scale = 0.1000 ± 0.0000
# D     = 0.0414 ± 0.0573
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1526 ± 0.1234; [-0.12640754676355545,+0.12725189230992262]
# scale = 0.1000 ± 0.0000
# D     = 0.0578 ± 0.0560
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9648 ± 0.0862; [-0.1626206593698726,+0.06383076893451431]
# scale = 0.1000 ± 0.0000
# D     = 0.0008 ± 0.0502
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9657 ± 0.1875; [-0.25436758466991405,+0.04317757757589788]
# scale = 0.1000 ± 0.0000
# D     = 0.0310 ± 0.0725
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.1108 ± 0.1251; [-0.13015095628851991,+0.17912773571614937]
# scale = 0.1000 ± 0.0000
# D     = 0.0819 ± 0.0564
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9117 ± 0.0977; [-0.10319917409880341,+0.11046030037046102]
# scale = 0.1000 ± 0.0000
# D     = 0.0941 ± 0.0528
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8262 ± 0.1167; [-0.1093800624879266,+0.12453244563698951]
# scale = 0.1000 ± 0.0000
# D     = -0.0588 ± 0.0562
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0126 ± 0.1838; [-0.10933883881817733,+0.11020214037878347]
# scale = 0.1000 ± 0.0000
# D     = 0.0471 ± 0.0725
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1659 ± 0.1090; [-0.11260271264924906,+0.10580820369674732]
# scale = 0.1000 ± 0.0000
# D     = 0.0177 ± 0.0533
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9653 ± 0.1797; [-0.13583242346324084,+0.07528751643842663]
# scale = 0.1000 ± 0.0000
# D     = 0.0289 ± 0.0699
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9897 ± 0.2146; [-0.14649795344741842,+0.2603154150989179]
# scale = 0.1000 ± 0.0000
# D     = 0.0095 ± 0.0802
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9648 ± 0.0962; [-0.10495604087834348,+0.07211023331491813]
# scale = 0.1000 ± 0.0000
# D     = 0.0338 ± 0.0524
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9009 ± 0.1166; [-0.10880598248308822,+0.12865790636799734]
# scale = 0.1000 ± 0.0000
# D     = 0.0295 ± 0.0569
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9653 ± 0.1836; [-0.21568369862759662,+0.05127905387026737]
# scale = 0.1000 ± 0.0000
# D     = -0.0130 ± 0.0710
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1570 ± 0.1045; [-0.1096001915638903,+0.09983778842317464]
# scale = 0.1000 ± 0.0000
# D     = 0.0025 ± 0.0520
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1677 ± 0.1244; [-0.12664179515899796,+0.12139998067755575]
# scale = 0.1000 ± 0.0000
# D     = 0.0325 ± 0.0566
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0352 ± 0.1175; [-0.10365516405714581,+0.16196824533977283]
# scale = 0.1000 ± 0.0000
# D     = -0.0047 ± 0.0556
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1406 ± 0.0870; [-0.09577894192982372,+0.08541179690213677]
# scale = 0.1000 ± 0.0000
# D     = 0.0969 ± 0.0478
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9648 ± 0.0639; [-0.06617309125602994,+0.043391456234494724]
# scale = 0.1000 ± 0.0000
# D     = 0.1209 ± 0.0457
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8797 ± 0.1033; [-0.1776588444104838,+0.10785724186678579]
# scale = 0.1000 ± 0.0000
# D     = -0.0455 ± 0.0529
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0940 ± 0.1083; [-0.11083174304034663,+0.13300739153759558]
# scale = 0.1000 ± 0.0000
# D     = -0.0428 ± 0.0524
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9657 ± 0.1949; [-0.29057203530523923,+0.048379469634942086]
# scale = 0.1000 ± 0.0000
# D     = 0.0674 ± 0.0739
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8709 ± 0.1081; [-0.10440558196372003,+0.11607728256191824]
# scale = 0.1000 ± 0.0000
# D     = 0.0657 ± 0.0548
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1181 ± 0.1017; [-0.10501596206850035,+0.11105050419477379]
# scale = 0.1000 ± 0.0000
# D     = 0.0162 ± 0.0514
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0098 ± 0.1825; [-0.07228653615354917,+0.22926584026501862]
# scale = 0.1000 ± 0.0000
# D     = 0.0228 ± 0.0706
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0976 ± 0.1126; [-0.10876943966567026,+0.1822748811959979]
# scale = 0.1000 ± 0.0000
# D     = 0.0927 ± 0.0529
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1286 ± 0.0754; [-0.08325747333161813,+0.07277178158807869]
# scale = 0.1000 ± 0.0000
# D     = 0.0042 ± 0.0456
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9526 ± 0.0736; [-0.1061533096449146,+0.08614994940600212]
# scale = 0.1000 ± 0.0000
# D     = 0.0513 ± 0.0451
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.1704 ± 0.1229; [-0.12142768455754308,+0.12271744591106351]
# scale = 0.1000 ± 0.0000
# D     = 0.0904 ± 0.0550
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1197 ± 0.1198; [-0.11691254787406036,+0.18951415229863258]
# scale = 0.1000 ± 0.0000
# D     = 0.1165 ± 0.0524
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1396 ± 0.1212; [-0.12273689691995765,+0.14139533791490275]
# scale = 0.1000 ± 0.0000
# D     = -0.0222 ± 0.0556
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9087 ± 0.1122; [-0.08818662089898022,+0.13678583452682888]
# scale = 0.1000 ± 0.0000
# D     = 0.0737 ± 0.0569
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8360 ± 0.1019; [-0.09745645497548318,+0.10707854319504873]
# scale = 0.1000 ± 0.0000
# D     = 0.0064 ± 0.0528
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8752 ± 0.1233; [-0.23097533739544499,+0.12848717810582855]
# scale = 0.1000 ± 0.0000
# D     = -0.0452 ± 0.0564
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9378 ± 0.0959; [-0.1110329086365734,+0.10774080784657465]
# scale = 0.1000 ± 0.0000
# D     = 0.0661 ± 0.0517
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0377 ± 0.1150; [-0.12283976148478351,+0.09224609976930909]
# scale = 0.1000 ± 0.0000
# D     = -0.0897 ± 0.0553
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0761 ± 0.1236; [-0.12742727305665683,+0.11451344137828352]
# scale = 0.1000 ± 0.0000
# D     = -0.0537 ± 0.0572
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9651 ± 0.1929; [-0.19719125077377253,+0.09834010020677907]
# scale = 0.1000 ± 0.0000
# D     = 0.0851 ± 0.0735
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0619 ± 0.1076; [-0.11097954091473881,+0.11442099231658423]
# scale = 0.1000 ± 0.0000
# D     = -0.0374 ± 0.0532
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.7759 ± 0.1471; [-0.1283213210424306,+0.1660169288258624]
# scale = 0.1000 ± 0.0000
# D     = 0.0902 ± 0.0699
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8706 ± 0.1079; [-0.10162465674555624,+0.12184347498307967]
# scale = 0.1000 ± 0.0000
# D     = 0.0727 ± 0.0560
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8745 ± 0.0830; [-0.07244241710657598,+0.09268376889475308]
# scale = 0.1000 ± 0.0000
# D     = 0.0064 ± 0.0481
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1008 ± 0.1073; [-0.11153345771541215,+0.1134864791781244]
# scale = 0.1000 ± 0.0000
# D     = -0.1030 ± 0.0536
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9583 ± 0.0756; [-0.08650736897786165,+0.09039271290582916]
# scale = 0.1000 ± 0.0000
# D     = 0.1162 ± 0.0474
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1217 ± 0.1160; [-0.12099462953457625,+0.16896960918911746]
# scale = 0.1000 ± 0.0000
# D     = 0.0038 ± 0.0550
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1279 ± 0.0808; [-0.08664717885678468,+0.18394087785721092]
# scale = 0.1000 ± 0.0000
# D     = 0.0886 ± 0.0462
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9541 ± 0.1004; [-0.10924217710760986,+0.10481179992543113]
# scale = 0.1000 ± 0.0000
# D     = 0.0158 ± 0.0522
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9864 ± 0.1774; [-0.10822536402622913,+0.12603114891477044]
# scale = 0.1000 ± 0.0000
# D     = -0.0010 ± 0.0699
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.7997 ± 0.1076; [-0.10246698345426944,+0.11335765141426829]
# scale = 0.1000 ± 0.0000
# D     = -0.0383 ± 0.0539
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8703 ± 0.1262; [-0.11986796020045837,+0.13947442286777004]
# scale = 0.1000 ± 0.0000
# D     = 0.0151 ± 0.0592
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8576 ± 0.1037; [-0.09940849054423509,+0.10874417671027801]
# scale = 0.1000 ± 0.0000
# D     = 0.0118 ± 0.0535
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0724 ± 0.0793; [-0.08972214734235628,+0.13795568742410078]
# scale = 0.1000 ± 0.0000
# D     = 0.0147 ± 0.0468
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0400 ± 0.1175; [-0.13259239568017006,+0.1879959559297476]
# scale = 0.1000 ± 0.0000
# D     = -0.0652 ± 0.0555
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0372 ± 0.1045; [-0.12369319823249668,+0.28109969042410504]
# scale = 0.1000 ± 0.0000
# D     = -0.0697 ± 0.0520
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0469 ± 0.1083; [-0.11991581004448648,+0.12492201031366651]
# scale = 0.1000 ± 0.0000
# D     = -0.0071 ± 0.0532
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.7311 ± 0.0986; [-0.0956468950659648,+0.10438725806424859]
# scale = 0.1000 ± 0.0000
# D     = -0.0562 ± 0.0519
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0345 ± 0.1766; [-0.07479045029360491,+0.16968760957150492]
# scale = 0.1000 ± 0.0000
# D     = -0.0120 ± 0.0698
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0346 ± 0.1874; [-0.09242168072357655,+0.16743019847042687]
# scale = 0.1000 ± 0.0000
# D     = 0.0113 ± 0.0718
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9649 ± 0.0674; [-0.23955195625636325,+0.042176152005819235]
# scale = 0.1000 ± 0.0000
# D     = 0.0248 ± 0.0465
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.2094 ± 0.1365; [-0.13777487630770496,+0.13431062578630615]
# scale = 0.1000 ± 0.0000
# D     = 0.0617 ± 0.0597
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0347 ± 0.0944; [-0.09978375375305548,+0.1005444162824329]
# scale = 0.1000 ± 0.0000
# D     = -0.0342 ± 0.0511
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.2150 ± 0.1270; [-0.13323088970281632,+0.12078557891083885]
# scale = 0.1000 ± 0.0000
# D     = 0.0406 ± 0.0591
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0676 ± 0.1348; [-0.1346007472811336,+0.14344364783699293]
# scale = 0.1000 ± 0.0000
# D     = 0.0731 ± 0.0572
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.8445 ± 0.1168; [-0.10882777846717223,+0.12523025623669556]
# scale = 0.1000 ± 0.0000
# D     = 0.0312 ± 0.0572
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9649 ± 0.1701; [-0.0999731154008933,+0.048923451170518426]
# scale = 0.1000 ± 0.0000
# D     = 0.0621 ± 0.0680
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1242 ± 0.0775; [-0.08555963343629569,+0.08471354596820885]
# scale = 0.1000 ± 0.0000
# D     = 0.0116 ± 0.0461
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8698 ± 0.0914; [-0.08095808880532984,+0.10515668799710587]
# scale = 0.1000 ± 0.0000
# D     = 0.1002 ± 0.0505
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8673 ± 0.1016; [-0.1581518507282068,+0.10498161801190858]
# scale = 0.1000 ± 0.0000
# D     = -0.0351 ± 0.0521
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9648 ± 0.0801; [-0.05703484405676673,+0.07824588871368576]
# scale = 0.1000 ± 0.0000
# D     = 0.1212 ± 0.0494
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.7942 ± 0.1133; [-0.10958935965687458,+0.11711578054016376]
# scale = 0.1000 ± 0.0000
# D     = -0.0601 ± 0.0560
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.2494 ± 0.1340; [-0.13855730748321088,+0.1274531585637789]
# scale = 0.1000 ± 0.0000
# D     = -0.0350 ± 0.0617
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8585 ± 0.1234; [-0.2112755217820452,+0.126651260946251]
# scale = 0.1000 ± 0.0000
# D     = -0.1274 ± 0.0568
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.1965 ± 0.1172; [-0.12078634186015363,+0.11368119042957565]
# scale = 0.1000 ± 0.0000
# D     = 0.0486 ± 0.0562
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0350 ± 0.0884; [-0.09439717918338,+0.0933875687297998]
# scale = 0.1000 ± 0.0000
# D     = -0.0238 ± 0.0503
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0681 ± 0.1023; [-0.10466564465888893,+0.12677124540828727]
# scale = 0.1000 ± 0.0000
# D     = 0.0404 ± 0.0504
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1815 ± 0.0896; [-0.09707944733117371,+0.08800777954170179]
# scale = 0.1000 ± 0.0000
# D     = 0.0921 ± 0.0496
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8899 ± 0.1003; [-0.14351993529053972,+0.10910446014152764]
# scale = 0.1000 ± 0.0000
# D     = 0.0226 ± 0.0525
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9216 ± 0.0976; [-0.12090457600229261,+0.10638831244016395]
# scale = 0.1000 ± 0.0000
# D     = 0.0344 ± 0.0518
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.1427 ± 0.1137; [-0.12174340543818916,+0.10653825096972228]
# scale = 0.1000 ± 0.0000
# D     = -0.0848 ± 0.0563
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8709 ± 0.0993; [-0.19319660246314427,+0.10346400083799707]
# scale = 0.1000 ± 0.0000
# D     = -0.0568 ± 0.0509
# fit status: 0
# ...
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-1.0g,S_-2.0g,S_-3.0g,S_-4.0g,S_0.0g,S_1.0g,S_2.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-1.0g,vat_-2.0g,vat_-3.0g,vat_-4.0g,vat_0.0g,vat_1.0g,vat_2.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
#print(res_norm)
plt.figure(10, figsize = (18,16))
plt.subplot(2,2,1)
plt.title("Extracted g and Error", fontsize = 20)
plt.grid()
plt.hist(Ngravity, bins = 30, range = (-.5, .5), histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(Ngravity):.3f} std: {np.std(Ngravity):.3f}')
plt.legend(fontsize = 15,  loc = "upper right")
plt.subplot(2,2,2)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(res_norm, bins = 30, range = (-5, 5), histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(res_norm):.3f} std: {np.std(res_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")

#plt.figure(11, figsize = (18,8))
plt.subplot(2,2,3)
plt.title("Extracted D and Error", fontsize = 20)
plt.grid()
plt.hist(ND, bins = 30, range = (-.5, .5), histtype = 'step', color = 'blue', linestyle = '-', label = f'$\mu$ = {np.mean(ND):.3f} std: {np.std(ND):.3f}')
plt.legend(fontsize = 15,  loc = "upper right")
plt.subplot(2,2,4)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(Dres_norm, bins = 30, range = (-5, 5), histtype = 'step', color = 'blue', linestyle = '-', label = f'$\mu$ = {np.mean(Dres_norm):.3f} std: {np.std(Dres_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")
