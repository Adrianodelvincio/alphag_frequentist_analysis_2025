# %%
import papermill as pm
import numpy as np
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # Create Field Maps

# %%
list_bias = [-1.25, -1 , -0.75 , -0.5, -.375, -.325 , -.3, -0.25, -0.1, -0.05 ,0, +0.05, +0.1, 0.25, 0.5, 0.75, 1., 1.25]
list_stringa = ["PreGravity_20mT_well","GravityRelease_17mT_well","GravityRelease_5mT_well","GravityRelease_2p5mT_well"]

for stringa in list_stringa:
    for bias in list_bias:
        # Parameters
        pm.execute_notebook(
                "Create_Maps.ipynb",
                f"output/Create_Maps{bias}.ipynb",
                parameters={
                    'stringa'           : stringa,
                    'bias'              : bias
                }
            )
# Out:
# ...
# Executing:   0%|          | 0/19 [00:00<?, ?cell/s]

# %% [markdown]
# # Simulate the S curve from the best Simulation

# %%
# BEST PARAMETERS
# Temperature': 0.0038280371069116612, 'Temperature_transv': 0.001857277433531939, 'tau_mixing': 9.520261714449024, 'theta': 0.2974252473439869

tau      = 10.76 # s
theta   = 0.3486297826814604
t_axial  = 0.003084 # K
t_transv = 0.002390 # K

# %%
list_biases = ["-1p25g","-1g","-0p25g", "-0p375g", "-0p3g" , "-0p1g", "-0p05g" , "-0p5g", "-0p75g", "0g", "0p05g" , "0p1g", "0p25g" , "0p5g", "0p75g", "1p25g"]

for bias in list_biases:
    output_notebook =  f"Simulation_{bias}"
    output_name     = f"tau_{tau:.2f}s_theta_{int(theta*180/np.pi)}_axial_{t_axial*1e3:.2f}mK_transv_{t_transv*1e3:.2f}mK"
    print(f"\n>>> Executing {output_name}")
    
    pm.execute_notebook(
            "Simulation.ipynb",
            f"output/notebooks/{output_notebook}.ipynb",
            parameters={
                'Temperature'       : t_axial,
                'Temperature_transv': t_transv,
                'tau_mixing'        : tau,
                'theta'             : theta,
                'stringa'           : output_name,
                'bias'              : bias
            }
        )
# Out:
# >>> Executing output_-1p25g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]
# >>> Executing output_-1g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]
# >>> Executing output_-0p25g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]
# >>> Executing output_-0p375g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]
# >>> Executing output_-0p3g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]
# >>> Executing output_-0p1g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# Executing:   0%|          | 0/37 [00:00<?, ?cell/s]
# >>> Executing output_-0p05g
#
# >>> Executing tau_10.76s_theta_19_axial_3.08mK_transv_2.39mK
# ...
