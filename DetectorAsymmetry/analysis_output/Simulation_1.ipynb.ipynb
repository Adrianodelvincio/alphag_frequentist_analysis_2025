# %%
import ROOT
from scipy import interpolate as interpolate
from scipy.stats import norm
import numpy as np
from utils import NonUniformStat, append_to_dict
import json
from matplotlib import pyplot as plt

# %%
BIAS = {}

with open("bias_dictionary.json", "r", encoding="utf-8") as f:
    BIAS = json.load(f)

tot_event, Dmu, Dsigma, nB_value = 0,0,0,0
#distribution = [169, 162, 188, 133, 121, 130, 162, 137, 195, 171, 154]

# load configuration file and read the configurations
with open("config.txt", 'r') as file:
    for line in file:
        line = line.strip()
        line = line.replace(" ","")
        if not ("#" in line):
            print(line)
        if not line:
            continue
        if 'Ntot' in line:
            key, value = line.split('=')
            tot_event = int(value)
        if 'nB_val' in line:
            key, value = line.split('=')
            nB_val = int(value)
        if 'Dmu' in line:
            key, value = line.split('=')
            Dmu = float(value)
        if 'Dsigma' in line:
            key, value = line.split('=')
            Dsigma = float(value)
        if 'real_gravity' in line:
            key, value = line.split('=')
            real_gravity = float(value)
        if 'Ntoys' in line:
            key, value = line.split('=')
            Ntoys = int(value)
# Out:
# Dmu=+0.02
# Dsigma=0.08
# K=0.85
# real_gravity=-10
# Ntot=1100
# nB_val=7
# Ntoys=1000
# pfraction=0.5

# %%
Dmu    = Dmu
Dsigma = Dsigma
L      = 4
print(Dmu)
# Out:
# 0.02

# %%
# Parameters
L = 4
Dsigma = 0.08

# %%
def sample_steep_region(n=200, k=1, a=1, g = -10):
    """
    Campiona n punti nella regione ripida di tanh(kx).
    a definisce quanto 'larga' è la regione ripida (in unità di 1/k).
    """
    x_min = -a / k + g/10
    x_max = +a / k + g/10
    xs = np.linspace(x_min, x_max, n) * 10
    return xs

# %%
BIAS = {}
#biasList = np.linspace( (real_gravity/10 - L/2)*10, (real_gravity/10 + L/2)*10, 7)

biasList = sample_steep_region(7, L, a = 2, g = real_gravity) 
print(f"bias list is {biasList}")

for bias in biasList:
    BIAS.update({f"{(bias/10):.1f}g" : int(bias)})

print(BIAS)

weights = {} # define the dictionary containing the statistics
for key, value in BIAS.items():
    weights.update( {key: int(tot_event/len(BIAS.values())) })
# Out:
# bias list is [-15.         -13.33333333 -11.66666667 -10.          -8.33333333
#   -6.66666667  -5.        ]
# {'-1.5g': -15, '-1.3g': -13, '-1.2g': -11, '-1.0g': -10, '-0.8g': -8, '-0.7g': -6, '-0.5g': -5}

# %% [markdown]
# # Spline approximated with LINEAR SLOPE

# %%
# def scurve_model(x, L, g):
#     result = 0
#     if((-L/2 + g) < x and x < ( L/2 + g)):
#         result = 2/L * (x - g)
#     elif((-L/2 +g) >= x):
#         result = -.99
#     elif(x >= ( L/2 + g )):
#         result = +.99
#     return result

def scurve_model(x, L, g):
    return np.tanh(L * (x - g))

print("linear scurve evaluated at -2 : %.1f" % scurve_model(-2,2,-1))
print("linear scurve evaluated at -1.5 : %.1f" % scurve_model(-1.5,2,-1))
print("linear scurve evaluated at -1 : %.1f" % scurve_model(-1,2,-1))
print("linear scurve evaluated at -.5 : %.1f" % scurve_model(-.5,2,-1))
print("linear scurve evaluated at -2 : %.1f" % scurve_model(-2,2,-1))
print("linear scurve evaluated at 0 : %.1f"  % scurve_model(0,2,-1))
print("linear scurve evaluated at 1 : %.1f"  % scurve_model(1,2,-1))
print("linear scurve evaluated at 1 : %.1f"  % scurve_model(10,2,-1))
# Out:
# linear scurve evaluated at -2 : -1.0
# linear scurve evaluated at -1.5 : -0.8
# linear scurve evaluated at -1 : 0.0
# linear scurve evaluated at -.5 : 0.8
# linear scurve evaluated at -2 : -1.0
# linear scurve evaluated at 0 : 1.0
# linear scurve evaluated at 1 : 1.0
# linear scurve evaluated at 1 : 1.0

# %%
import csv

# ===  generate the True Asymemtry from Simulation
ASYMMETRY_TRUE = {}
for key, value in BIAS.items():
    ASYMMETRY_TRUE.update({key : float(scurve_model(value/10, L, real_gravity/10))})
    
print(ASYMMETRY_TRUE)

# Create simulation file
rows = []
for bias in np.linspace(-11, 9, 200):
    rows.append([bias, scurve_model(bias, L, real_gravity/10)])  # ogni riga = [bias, valore]
    print(bias, scurve_model(bias, L, 1) )

# save simulation file
with open("simulation.csv", "w", newline="") as f:
    writer = csv.writer(f)
    #writer.writerow(["bias", "scurve"])   # intestazioni opzionali
    writer.writerows(rows)
# Out:
# {'-1.5g': -0.9640275800758169, '-1.3g': -0.8336546070121553, '-1.2g': -0.3799489622552252, '-1.0g': 0.0, '-0.8g': 0.6640367702678489, '-0.7g': 0.9216685544064713, '-0.5g': 0.9640275800758169}
# -11.0 -1.0
# -10.899497487437186 -1.0
# -10.798994974874372 -1.0
# -10.698492462311558 -1.0
# -10.597989949748744 -1.0
# -10.49748743718593 -1.0
# -10.396984924623116 -1.0
# -10.296482412060302 -1.0
# -10.195979899497488 -1.0
# -10.095477386934673 -1.0
# -9.99497487437186 -1.0
# -9.894472361809045 -1.0
# -9.793969849246231 -1.0
# -9.693467336683417 -1.0
# -9.592964824120603 -1.0
# -9.492462311557789 -1.0
# -9.391959798994975 -1.0
# -9.291457286432161 -1.0
# -9.190954773869347 -1.0
# -9.090452261306533 -1.0
# -8.989949748743719 -1.0
# -8.889447236180905 -1.0
# -8.78894472361809 -1.0
# -8.688442211055277 -1.0
# -8.587939698492463 -1.0
# -8.487437185929648 -1.0
# -8.386934673366834 -1.0
# -8.28643216080402 -1.0
# -8.185929648241206 -1.0
# -8.085427135678392 -1.0
# -7.984924623115578 -1.0
# -7.884422110552764 -1.0
# -7.78391959798995 -1.0
# -7.683417085427136 -1.0
# -7.582914572864322 -1.0
# -7.482412060301508 -1.0
# -7.381909547738694 -1.0
# -7.28140703517588 -1.0
# -7.180904522613066 -1.0
# -7.080402010050252 -1.0
# -6.979899497487437 -1.0
# -6.879396984924623 -1.0
# -6.7788944723618085 -1.0
# -6.6783919597989945 -1.0
# -6.57788944723618 -1.0
# -6.477386934673366 -1.0
# -6.376884422110552 -1.0
# -6.276381909547738 -1.0
# -6.175879396984924 -1.0
# -6.07537688442211 -1.0
# -5.974874371859296 -1.0
# -5.874371859296482 -1.0
# -5.773869346733668 -1.0
# -5.673366834170854 -1.0
# -5.57286432160804 -1.0
# -5.472361809045226 -1.0
# -5.371859296482412 -1.0
# -5.271356783919598 -1.0
# -5.1708542713567835 -1.0
# -5.0703517587939695 -1.0
# -4.969849246231155 -1.0
# -4.869346733668341 -1.0
# -4.768844221105527 -1.0
# -4.668341708542713 -1.0
# -4.567839195979899 -1.0
# -4.467336683417085 -1.0
# 3.2713567839195985 0.9999999743239478
# 3.3718592964824126 0.9999999885092927
# 3.4723618090452266 0.9999999948576069
# 3.5728643216080407 0.9999999976986441
# 3.6733668341708547 0.9999999989700828
# 3.773869346733669 0.999999999539085
# 3.874371859296483 0.9999999997937284
# 3.974874371859297 0.9999999999076881
# 4.075376884422111 0.9999999999586879
# 4.175879396984925 0.9999999999815118
# 4.276381909547739 0.9999999999917261
# 4.376884422110553 0.9999999999962972
# 4.477386934673367 0.9999999999983429
# 4.577889447236181 0.9999999999992584
# 4.678391959798995 0.9999999999996682
# 4.778894472361809 0.9999999999998515
# 4.8793969849246235 0.9999999999999335
# 4.9798994974874375 0.9999999999999702
# 5.080402010050253 0.9999999999999867
# 5.180904522613066 0.999999999999994
# 5.2814070351758815 0.9999999999999973
# 5.381909547738694 0.9999999999999988
# 5.48241206030151 0.9999999999999994
# 5.582914572864322 0.9999999999999998
# 5.683417085427138 0.9999999999999999
# 5.78391959798995 1.0
# 5.884422110552766 1.0
# 5.984924623115578 1.0
# 6.085427135678394 1.0
# 6.185929648241206 1.0
# 6.286432160804022 1.0
# 6.386934673366834 1.0
# 6.48743718592965 1.0
# 6.5879396984924625 1.0
# 6.688442211055278 1.0
# 6.788944723618091 1.0
# 6.8894472361809065 1.0
# 6.989949748743719 1.0
# 7.090452261306535 1.0
# 7.190954773869347 1.0
# 7.291457286432163 1.0
# 7.391959798994975 1.0
# 7.492462311557791 1.0
# 7.592964824120603 1.0
# 7.693467336683419 1.0
# 7.793969849246231 1.0
# 7.894472361809047 1.0
# 7.994974874371859 1.0
# 8.095477386934675 1.0
# 8.195979899497488 1.0
# 8.296482412060303 1.0
# 8.396984924623116 1.0
# 8.497487437185931 1.0
# 8.597989949748744 1.0
# 8.69849246231156 1.0
# 8.798994974874372 1.0
# 8.899497487437188 1.0
# 9.0 1.0

# %%
plt.figure(1)
xpoints = np.linspace(-5,5,100)
ypoints = [scurve_model(item, L, real_gravity/10) for item in xpoints]
plt.errorbar(xpoints, ypoints, marker = '.', color = 'blue')
plt.xticks([-5,-4,-3,-2,-1,0,1,2,3])
ypoints = [scurve_model(item/10, L, real_gravity/10) for item in biasList]
xpoints = np.array(biasList)/10
plt.errorbar(xpoints, ypoints, linestyle = "" ,marker = "*", color = "red")
plt.grid()
plt.savefig(f"scurve_L_{L}.png")

# %% [markdown]
# # Open The Workspace with the PDFs

# %%
f = ROOT.TFile("analysis_output/workspace.root")
w = f.Get("w")
w.Print("v")

w['c_pbarDn_1'].setVal(1.0); w['c_pbarDn_1'].setConstant(True)
w['c_pbarUp_1'].setVal(1.0); w['c_pbarUp_1'].setConstant(True)
# Out:
# RooWorkspace(w) w contents
#
# variables
# ---------
# (Z,biaskey,c_pbarDn_1,c_pbarDn_2,c_pbarUp_1,c_pbarUp_2,evtype)
#
# p.d.f.s
# -------
# RooHistPdf::hpdf_pbarDn_1[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarDn_2[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarUp_1[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::hpdf_pbarUp_2[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::pdf_cosm[ pdfObs=(Z) ] = 1.8628
# RooAddPdf::pdf_pbarDn[ c_pbarDn_1 * hpdf_pbarDn_1 + [%] * hpdf_pbarDn_2 ] = 0.0121951/1
# RooAddPdf::pdf_pbarUp[ c_pbarUp_1 * hpdf_pbarUp_1 + [%] * hpdf_pbarUp_2 ] = 0.844512/1
#
# datasets
# --------
# RooDataHist::rdhbin_pbarUp1(Z)
# RooDataHist::rdhbin_pbarUp2(Z)
# RooDataHist::rdhbin_pbarDn1(Z)
# RooDataHist::rdhbin_pbarDn2(Z)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::rhcosm(Z)

# %%
Z = w['Z']
zframe = Z.frame(Title = "Z Distributions, Templates")
w['pdf_pbarUp'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kRed))
w['pdf_pbarDn'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kBlue))
w['pdf_cosm'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kGreen))

c = ROOT.TCanvas("pdfs_templates", "pdfs_templates", 600, 600)
ROOT.gPad.SetLeftMargin(0.15)
zframe.GetYaxis().SetTitleOffset(1.4)
zframe.Draw()
c.Draw()
# Out:
# <div id="root_plot_1761648632917" style="width: 600px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1761648632917(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1006.55000521342,"fY1":-0.129843759674114,"fX2":-131.883332029978,"fY2":1.16859375967411,"fXtoAbsPixelk":685.86562344234,"fXtoPixelk":685.86562344234,"fXtoPixel":0.681402433947547,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-440.529475986742,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1006.55000521342,"fPixeltoXk":-1006.55000521342,"fPixeltoX":1.46756153218698,"fAbsPixeltoYk":1.16859375967411,"fPixeltoYk":-0.129843759674114,"fPixeltoY":-0.0022699956631962,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-875.35,"fUymin":0,"fUxmax":-219.35,"fUymax":1.03875,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"pdfs_templates","fTitle":"pdfs_templates","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;11 ...

# %% [markdown]
# # Create the RooDataSet

# %%
BiasCategory = ROOT.RooCategory("secondCategory", "a second category", BIAS)
BiasCategory.Print("v")

#dataset = ROOT.RooDataSet("data","data", ROOT.RooArgSet(Z,BiasCategory))
# Out:
# --- RooAbsArg ---
#   Value State: clean
#   Shape State: clean
#   Attributes:
#   Address: 0x57c46064a680
#   Clients:
#   Servers:
#   Proxies:
# --- RooAbsCategory ---
#   Value = -15 "-1.5g)
#   Possible states:
#     -0.5g	-5
#     -0.7g	-6
#     -0.8g	-8
#     -1.0g	-10
#     -1.2g	-11
#     -1.3g	-13
#     -1.5g	-15

# %%
simModelBase = ROOT.RooSimultaneous("model_base_simultaneous", "model for bias", BiasCategory)

# 2. Crea un mapping da categoria (es. "-1.0g") a PDF personalizzato

pdf_per_categoria = {} # senno muoiono

for category, weight in weights.items():
    print(f"Setting up PDF for category: {category}")
    
    # Calcolo degli eventi Up/Down
    Nup   = 0.5 * weight * (1 - ASYMMETRY_TRUE[category])
    Ndown = 0.5 * weight * (1 + ASYMMETRY_TRUE[category])
    
    # Costanti per RooAddPdf
    nup_const = ROOT.RooFit.RooConst(Nup)
    ndwn_const = ROOT.RooFit.RooConst(Ndown)
    
    # PDF composita per questa categoria
    model_i = ROOT.RooAddPdf(f"pdf_{category}", f"pdf_{category}",
                             ROOT.RooArgList(w['pdf_pbarUp'], w['pdf_pbarDn']),
                             ROOT.RooArgList(nup_const, ndwn_const))
    pdf_per_categoria[category] = model_i
    
    # Aggiungila alla simultanea
    simModelBase.addPdf(model_i, category)
# Out:
# Setting up PDF for category: -1.5g
# Setting up PDF for category: -1.3g
# Setting up PDF for category: -1.2g
# Setting up PDF for category: -1.0g
# Setting up PDF for category: -0.8g
# Setting up PDF for category: -0.7g
# Setting up PDF for category: -0.5g

# %%
# Generazione separata per ciascuna categoria
dataset = simModelBase.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
dataset.Print("v")
# Out:
# DataStore hmaster (hmaster)
#   Contains 14 entries
#   Observables:
#     1)               Z = -450  L(-875.35 - -219.35) B(2)  "Z"
#     2)  secondCategory = -1.5g(idx = -15)
#   "a second category"

# %%
ttable = dataset.table(BiasCategory)
ttable.Print("v")
# Out:
#   Table secondCategory : hmaster
#   +-------+-----+
#   | -1.5g | 138 |
#   | -1.3g | 152 |
#   | -1.2g | 162 |
#   | -1.0g | 165 |
#   | -0.8g | 167 |
#   | -0.7g | 159 |
#   | -0.5g | 164 |
#   +-------+-----+

# %%
c1 = ROOT.TCanvas("data_plot", "data_plot", 800, 800)

zframe1 = Z.frame( ROOT.RooFit.Bins(18), Title = "Plot of Z data")
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == -30'), ROOT.RooFit.MarkerColor(ROOT.kBlue),  ROOT.RooFit.Name("cat_-30"))
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == -20'), ROOT.RooFit.MarkerColor(ROOT.kRed),   ROOT.RooFit.Name("cat_-20"))
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == 30'), ROOT.RooFit.MarkerColor(ROOT.kGreen),  ROOT.RooFit.Name("cat_+30"))
#dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == +20'), ROOT.RooFit.MarkerColor(6),   ROOT.RooFit.Name("cat_-20"))
#w['model_base'].plotOn(zframe1)

#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "-3.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kBlue))
#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "-2.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kRed))
#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "+3.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kGreen))

zframe1.Draw()

# Crea la legenda
legend = ROOT.TLegend(0.6, 0.7, 0.88, 0.88)  # x1,y1,x2,y2 in NDC (posizione)
legend.SetBorderSize(0)
legend.SetFillStyle(0)
legend.AddEntry(zframe1.findObject("cat_-30"), "-3.0g", "lep")
legend.AddEntry(zframe1.findObject("cat_-20"), "-2.0g", "lep")
legend.AddEntry(zframe1.findObject("cat_+30"), "+3.0g", "lep")
legend.Draw()

c1.Draw()
# Out:
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 0 events out of 1107 total events
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 0 events out of 1107 total events
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 0 events out of 1107 total events
# <div id="root_plot_1761648633926" style="width: 800px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1761648633926(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-957.350006109476,"fY1":-0.150658534683908,"fX2":-137.349993890524,"fY2":1.35592672235569,"fXtoAbsPixelk":929.329992082566,"fXtoPixelk":929.329992082566,"fXtoPixel":0.970731692852043,"fYtoAbsPixelk":694.799995398521,"fYtoPixelk":694.799995398521,"fYtoPixel":-512.417067930798,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":772,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-957.350006109476,"fPixeltoXk":-957.350006109476,"fPixeltoX":1.03015076911929,"fAbsPixeltoYk":1.35592672235569,"fPixeltoYk":-0.150658534683908,"fPixeltoY":-0.00195153530704612,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-875.35,"fUymin":0,"fUxmax":-219.35,"fUymax":1.20526818767178,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"data_plot","fTitle":"data_plot","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;1 ...

# %% [markdown]
# # Construction of the model for the Simulation

# %%
w.Import(BiasCategory) # <== Import the category inside the workspace

w.factory("S[100,50, 10000]")
w.factory("E[0.0, -1.5, 1.5]")
w.factory(f"D[{Dmu}, -0.8, 0.8]")

w.factory("SUM::model_base( Nup[30,10000] * pdf_pbarUp, Ndwn[30,1000] * pdf_pbarDn, nB[1, 200] * pdf_cosm)") # <<< Add pdf_cosm in the future
# A = (Ndwn - Nup)/(Ndwn + Nup)
w.factory(f"EDIT::model_MAGB(model_base, Nup=expr('0.5*S*(1-E)', S, E), Ndwn = expr('0.5*S*(1+E)', S, E))")

w.factory(f"Gaussian::Dconstr(D,{Dmu},{Dsigma})") # constrain on D, efficiency

w.factory("SIMCLONE::model_fit( model_MAGB, $SplitParam({S,E}, secondCategory ))") # Clone the Models

w.Print()
# Out:
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCategory::secondCategory
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (D,E,E_-0.5g,E_-0.7g,E_-0.8g,E_-1.0g,E_-1.2g,E_-1.3g,E_-1.5g,Ndwn,Nup,S,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,Z,biaskey,c_pbarDn_1,c_pbarDn_2,c_pbarUp_1,c_pbarUp_2,evtype,nB,secondCategory)
#
# p.d.f.s
# -------
# RooGaussian::Dconstr[ x=D mean=0.02 sigma=0.08 ] = 1
# RooHistPdf::hpdf_pbarDn_1[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarDn_2[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarUp_1[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::hpdf_pbarUp_2[ pdfObs=(Z) ] = 0.844512
# RooAddPdf::model_MAGB[ model_MAGB_2 * pdf_pbarUp + model_MAGB_3 * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-0.5g[ model_MAGB_2_-0.5g * pdf_pbarUp + model_MAGB_3_-0.5g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-0.7g[ model_MAGB_2_-0.7g * pdf_pbarUp + model_MAGB_3_-0.7g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-0.8g[ model_MAGB_2_-0.8g * pdf_pbarUp + model_MAGB_3_-0.8g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.0g[ model_MAGB_2_-1.0g * pdf_pbarUp + model_MAGB_3_-1.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.2g[ model_MAGB_2_-1.2g * pdf_pbarUp + model_MAGB_3_-1.2g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.3g[ model_MAGB_2_-1.3g * pdf_pbarUp + model_MAGB_3_-1.3g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.5g[ model_MAGB_2_-1.5g * pdf_pbarUp + model_MAGB_3_-1.5g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_base[ Nup * pdf_pbarUp + Ndwn * pdf_pbarDn + nB * pdf_cosm ] = 0.786559/1
# RooSimultaneous::model_fit[ indexCat=secondCategory -0.5g=model_MAGB_-0.5g -0.7g=model_MAGB_-0.7g -0.8g=model_MAGB_-0.8g -1.0g=model_MAGB_-1.0g -1.2g=model_MAGB_-1.2g -1.3g=model_MAGB_-1.3g -1.5g=model_MAGB_-1.5g ] = 0.16391
# RooHistPdf::pdf_cosm[ pdfObs=(Z) ] = 1.8628
# RooAddPdf::pdf_pbarDn[ c_pbarDn_1 * hpdf_pbarDn_1 + [%] * hpdf_pbarDn_2 ] = 0.0121951/1
# RooAddPdf::pdf_pbarUp[ c_pbarUp_1 * hpdf_pbarUp_1 + [%] * hpdf_pbarUp_2 ] = 0.844512/1
#
# functions
# --------
# RooFormulaVar::model_MAGB_2[ actualVars=(S,E) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-0.5g[ actualVars=(S_-0.5g,E_-0.5g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-0.7g[ actualVars=(S_-0.7g,E_-0.7g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-0.8g[ actualVars=(S_-0.8g,E_-0.8g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.0g[ actualVars=(S_-1.0g,E_-1.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.2g[ actualVars=(S_-1.2g,E_-1.2g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.3g[ actualVars=(S_-1.3g,E_-1.3g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.5g[ actualVars=(S_-1.5g,E_-1.5g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_3[ actualVars=(S,E) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-0.5g[ actualVars=(S_-0.5g,E_-0.5g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-0.7g[ actualVars=(S_-0.7g,E_-0.7g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-0.8g[ actualVars=(S_-0.8g,E_-0.8g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.0g[ actualVars=(S_-1.0g,E_-1.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.2g[ actualVars=(S_-1.2g,E_-1.2g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.3g[ actualVars=(S_-1.3g,E_-1.3g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.5g[ actualVars=(S_-1.5g,E_-1.5g) formula="0.5*S*(1+E)" ] = 50
#
# datasets
# --------
# RooDataHist::rdhbin_pbarUp1(Z)
# RooDataHist::rdhbin_pbarUp2(Z)
# RooDataHist::rdhbin_pbarDn1(Z)
# RooDataHist::rdhbin_pbarDn2(Z)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::rhcosm(Z)

# %%
g = ROOT.TGraph("simulation.csv","%lg,%lg")
# create RooRealVar
w.factory('c[0,-30,30]')
#create RooRealVar
w.factory('scale[0.1]')
#w['scale'].setConstant(True)
w["nB"].setVal(nB_val)

# === Definisci la curva S come TF1 + RooTFnBinding ===
def Scurve_fn(x, p):
    # 10 is an offset of the simulation
    offset = -10
    bias = x[0]
    c = p[0]
    scale = p[1]
    D = p[2]
    return (g.Eval((x[0] - c + offset) * scale) - D)/(1 - g.Eval((x[0] - c + offset) * scale)*D)

# === Print values of the Scurve for a collection of biases ===
print("-"*8)
for key,value in BIAS.items():
    val = Scurve_fn([value], [w["c"].getVal(), w['scale'].getVal(), w['D'].getVal()])
    print(f"{key}| {value} | {w['c'].getVal()} | {val}")
print("-"*8)

# === create the RooFit model from the Scurve ===
Scurve_TF1 = ROOT.TF1("Scurve",Scurve_fn, -50, 50, 3) # not possible to put in workspace

cust = ROOT.RooCustomizer(w.pdf('model_fit'), "scurve");

vcat={}
nasy={}
for bkt, bias_val in BIAS.items():
    v = ROOT.RooRealVar(f"vat_{bkt}", "", bias_val)
    # Creo una funzione parametrica RooTFnBinding che connette il TF1 alla variabile 'v'
    # Il TF1 ha 3 parametri: c, scale, D — sono usati qui come [c, scale, D]
    asy = ROOT.RooTFnBinding(f"nasy_{bkt}", "", Scurve_TF1, v, [w['c'], w['scale'], w['D']])
    # Salvo queste entità nei dizionari
    vcat[bkt] = v
    nasy[bkt] = asy

    # Ottengo la variabile originale 'E_{bkt}' nel modello
    A = w.var(f'E_{bkt}')

    # Sostituisco E_{bkt} con la funzione curva S corrispondente
    cust.replaceArg(A, asy)

scurve_all = cust.build(True)

scurvemap = {}
for bkt, bias_val in BIAS.items():
    scurvemap.update({bkt : scurve_all.getPdf(bkt) })
    S = w.var(f'S_{bkt}')

    val = ttable.get(bkt)
    err = np.sqrt(val)
    
    #S.setMin(val-10*err)
    #S.setMax(val+10*err)
    S.setVal(val)
    print(f"setting  {val}  [{val - 10*err}  {val + 10*err}]")
    #S.setError(err)

scurve_fit = ROOT.RooSimultaneous("scurve_fit","scurve_fit", scurvemap, BiasCategory)
# Out:
# --------
# -1.5g| -15 | 0.0 | -0.9999872856160779
# -1.3g| -13 | 0.0 | -0.9999369770228896
# -1.2g| -11 | 0.0 | -0.9996876580634125
# -1.0g| -10 | 0.0 | -0.9993047783870286
# -0.8g| -8 | 0.0 | -0.9965596746816066
# -0.7g| -6 | 0.0 | -0.9830813215429417
# -0.5g| -5 | 0.0 | -0.9627775743362759
# --------
# setting  138.0  [20.526598755292696  255.4734012447073]
# setting  152.0  [28.711719940620483  275.28828005937953]
# setting  162.0  [34.72077938642144  289.27922061357856]
# setting  165.0  [36.5476742133487  293.4523257866513]
# setting  167.0  [37.77152016679915  296.2284798332008]
# setting  159.0  [32.90479787081509  285.09520212918494]
# setting  164.0  [35.93751525134303  292.06248474865697]
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-0.5g will be replaced by nasy_-0.5g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-0.7g will be replaced by nasy_-0.7g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-0.8g will be replaced by nasy_-0.8g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.0g will be replaced by nasy_-1.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.2g will be replaced by nasy_-1.2g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.3g will be replaced by nasy_-1.3g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.5g will be replaced by nasy_-1.5g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooSimultaneous::model_fit cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-0.5g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-0.5g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-0.5g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-0.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-0.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-0.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-0.8g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-0.8g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-0.8g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.2g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.2g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.2g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.5g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.5g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.5g cloned: depends on a replaced parameter

# %%
w['D'].setConstant(True)

w['c'].setError(20)
result = scurve_fit.fitTo(dataset,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 #ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(2),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.Minos(w['c']))

c     = w.var('c')
scale = w.var('scale')
D = w.var('D')

# === 8. Risultati
print("\n=== RISULTATI DEL FIT ===")
print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
print(f"fit status: {result.status()}")
# Out:
# === RISULTATI DEL FIT ===
# c     = -0.9977 ± 0.0124; [-0.012556607972376147,+0.012284783061446891]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 4500 convergence for edm < 1 strategy 2
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 4461.58672274400851
# Edm   = 0.00016301741931759825
# Nfcn  = 1501
# S_-0.5g	  = 163.322	 +/-  12.807	(limited)
# S_-0.7g	  = 158.229	 +/-  12.6126	(limited)
# S_-0.8g	  = 165.998	 +/-  12.9228	(limited)
# S_-1.0g	  = 163.97	 +/-  12.8436	(limited)
# S_-1.2g	  = 161.175	 +/-  12.7348	(limited)
# S_-1.3g	  = 151.127	 +/-  12.3319	(limited)
# S_-1.5g	  = 137.059	 +/-  11.7451	(limited)
# c	  = -9.97719	 +/-  0.124281	(limited)
# nB	  = 1.00001	 +/-  0.871781	(limited)
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS LOWER error for parameter #7 : c using max-calls 4500, tolerance 1
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS UPPER error for parameter #7 : c using max-calls 4500, tolerance 1
# Minos: Lower error for parameter c  :  -0.125566
# Minos: Upper error for parameter c  :  0.122848
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       6013.704922 Edm =       1817.882324 NCalls =     39
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 1.34032
# Info in <Minuit2>: MnSeedGenerator run Hesse - Initial seeding state:
#   Minimum value : 6013.704922
#   Edm           : 185604.6051
#   Internal parameters:	[     -1.356307984     -1.361082125     -1.353493083     -1.355365661     -1.358204968     -1.367951771     -1.382430531                0     -1.221747644]
#   Internal gradient  :	[       461.634084      552.3758449      558.1304126      369.9576121      213.3768775      79.11233358      40.44535657      2074.338953     -1470.624198]
#   Internal covariance matrix:
# [[    0.017199928    0.015010476   0.0088716285    0.004372153   0.0023800594   0.0010623863  0.00076700129   -0.017913842   -0.085725919]
#  [    0.015010476    0.013459592   0.0078332718   0.0038605291   0.0021015579   0.0009380744  0.00067725319   -0.015812809    -0.07569499]
#  [   0.0088716285   0.0078332718   0.0048188246   0.0022822344   0.0012423942  0.00055457225   0.0004003799  -0.0093417854   -0.044749519]
#  [    0.004372153   0.0038605291   0.0022822344    0.001285036  0.00061235539  0.00027334025  0.00019734126   -0.004602906   -0.022056369]
#  [   0.0023800594   0.0021015579   0.0012423942  0.00061235539  0.00047818939  0.00014880092  0.00010742861  -0.0025055811   -0.012007043]
#  [   0.0010623863   0.0009380744  0.00055457225  0.00027334025  0.00014880092  0.00020367211  4.7953509e-05  -0.0011183905  -0.0053596511]
#  [  0.00076700129  0.00067725319   0.0004003799  0.00019734126  0.00010742861  4.7953509e-05  0.00017583158  -0.0008074318  -0.0038694646]
#  [   -0.017913842   -0.015812809  -0.0093417854   -0.004602906  -0.0025055811  -0.0011183905  -0.0008074318      0.0189033    0.090244718]
#  [   -0.085725919    -0.07569499   -0.044749519   -0.022056369   -0.012007043  -0.0053596511  -0.0038694646    0.090244718     0.43248097]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 4500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       6013.704922 Edm =       185604.6051 NCalls =    112
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       5119.139204 Edm =       19181.37259 NCalls =    150
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       4911.709724 Edm =       7.157572997 NCalls =    177
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       4883.956238 Edm =       0.207653686 NCalls =    207
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       4882.971699 Edm =      0.0550888797 NCalls =    231
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =       4882.761972 Edm =     0.03664350634 NCalls =    251
# Info in <Minuit2>: VariableMetricBuilder    6 - FCN =       4882.719834 Edm =    0.005502013672 NCalls =    271
# Info in <Minuit2>: VariableMetricBuilder    7 - FCN =       4882.708426 Edm =    0.002301371206 NCalls =    291
# Info in <Minuit2>: VariableMetricBuilder    8 - FCN =       4882.703828 Edm =   0.0006842513551 NCalls =    311
# Info in <Minuit2>: VariableMetricBuilder    9 - FCN =       4882.701248 Edm =   0.0001081099179 NCalls =    331
# Warning in <Minuit2>: MnPosDef non-positive diagonal element in covariance matrix[ 7 ] = -6.65384
# Warning in <Minuit2>: MnPosDef Added to diagonal of Error matrix a value 7.15384
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder   10 - FCN =       4882.701248 Edm =      0.0154410172 NCalls =    408
# Info in <Minuit2>: VariableMetricBuilder Tolerance not sufficient, continue minimization; Edm 0.015441 Required 0.001
# Warning in <Minuit2>: DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# Info in <Minuit2>: DavidonErrorUpdator Explanation:
#    The distance from the minimum cannot be estimated, since the minimized
#    function seems not to be strictly convex in the space probed by the fit.
#    That is expected if the starting parameters are e.g. close to a local maximum
#    of the minimized function. If this function is expected to be fully convex
#    in the probed range or Minuit is already close to the function minimum, this
#    may hint to numerical or analytical issues with the minimized function.
#    This was found by projecting the difference of gradients at two points, s0 and p1,
#    onto the direction given by the difference of s0 and p1, where:
#  * s0:  	[     -1.570766266     -1.570739809     -1.570751167     -1.570339859      -1.49935033     -1.452960874     -1.462371265     0.2581453023     0.1646833437]
#  * p1:  	[     -1.570833433     -1.570866591     -1.570852437     -1.571358165     -1.497864969      -1.45360339     -1.462780343    -0.2919137688     0.1640022462]
#  * gradient at s0:  	[     0.1425631234     0.2577749462     0.1489246345     0.4651787657     -0.659235406     0.7604513323     0.4501953812     0.1222041703     0.1204857852]
#  * gradient at p1:  	[    0.07187274269    0.09587453799    0.01487130266    -0.1477224802     -4.960143066      2.635140744     0.5971389077       317.120017       143.095087]
#    To understand whether this hints to an issue in the minimized function,
#    the minimized function can be plotted along points between s0 and p1 to
#    look for unexpected behavior.
# Info in <Minuit2>: VariableMetricBuilder   11 - FCN =       4677.981895 Edm =       100614.3325 NCalls =    446
# Warning in <Minuit2>: VariableMetricBuilder Matrix not pos.def, gdel = 174.61 > 0
# Warning in <Minuit2>: MnPosDef non-positive diagonal element in covariance matrix[ 7 ] = -0.00127144
# Warning in <Minuit2>: MnPosDef Added to diagonal of Error matrix a value 0.501271
# Warning in <Minuit2>: VariableMetricBuilder gdel = -60516
# Info in <Minuit2>: VariableMetricBuilder   12 - FCN =       4668.109744 Edm =       8353.765431 NCalls =    485
# Info in <Minuit2>: VariableMetricBuilder   13 - FCN =       4645.039523 Edm =       5481.334731 NCalls =    528
# Info in <Minuit2>: VariableMetricBuilder   14 - FCN =       4641.253682 Edm =        4183.78762 NCalls =    559
# Info in <Minuit2>: VariableMetricBuilder   15 - FCN =       4640.541906 Edm =       419.9276314 NCalls =    583
# Warning in <Minuit2>: DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# Info in <Minuit2>: DavidonErrorUpdator Explanation:
#    The distance from the minimum cannot be estimated, since the minimized
#    function seems not to be strictly convex in the space probed by the fit.
#    That is expected if the starting parameters are e.g. close to a local maximum
#    of the minimized function. If this function is expected to be fully convex
#    in the probed range or Minuit is already close to the function minimum, this
#    may hint to numerical or analytical issues with the minimized function.
#    This was found by projecting the difference of gradients at two points, s0 and p1,
#    onto the direction given by the difference of s0 and p1, where:
#  * s0:  	[     -1.583005312     -1.585133613     -1.573978529      -1.56991302     -1.479379865     -1.431771696     -1.425732025    -0.3496479639     -3.016284635]
#  * p1:  	[     -1.610215298     -1.611967286     -1.578136092     -1.569210109      -1.48251322     -1.420862233     -1.429489307     -0.349621169     -3.024059801]
#  * gradient at s0:  	[      38.95509281      38.42026771      5.885215508    -0.8530329613     -41.64102731       7.26283342      51.08192655     -226.0903864     -75.56559815]
#  * gradient at p1:  	[      113.4767503      97.80346739      13.28525179     -1.479540646      -42.7542647      46.89596548      39.30140382     -222.3522257     -85.67524285]
#    To understand whether this hints to an issue in the minimized function,
#    the minimized function can be plotted along points between s0 and p1 to
#    look for unexpected behavior.
# Info in <Minuit2>: VariableMetricBuilder   16 - FCN =       4637.365295 Edm =       2976.424362 NCalls =    608
# Info in <Minuit2>: VariableMetricBuilder   17 - FCN =       4636.210817 Edm =        3253.78074 NCalls =    635
# Info in <Minuit2>: VariableMetricBuilder   18 - FCN =       4635.652133 Edm =       41.19103187 NCalls =    658
# Warning in <Minuit2>: DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# Info in <Minuit2>: DavidonErrorUpdator Explanation:
#    The distance from the minimum cannot be estimated, since the minimized
#    function seems not to be strictly convex in the space probed by the fit.
#    That is expected if the starting parameters are e.g. close to a local maximum
#    of the minimized function. If this function is expected to be fully convex
#    in the probed range or Minuit is already close to the function minimum, this
#    may hint to numerical or analytical issues with the minimized function.
#    This was found by projecting the difference of gradients at two points, s0 and p1,
#    onto the direction given by the difference of s0 and p1, where:
#  * s0:  	[     -1.575146686      -1.65904849     -1.594211861     -1.563353804     -1.448125932      -1.39464337     -1.400137294    -0.3489235723     -3.002476264]
#  * p1:  	[      -1.56180097     -1.665851094     -1.643211779     -1.549132004      -1.43424511     -1.378715659      -1.38406361    -0.3477517812     -2.960206981]
#  * gradient at s0:  	[      14.26590406      132.9715552      42.69662475     -7.599951293      8.011641014      147.9690633      152.3771772      -233.751955     -108.9644994]
#  * gradient at p1:  	[     -31.13597679      139.2080165      95.45047251      -25.2233756      30.31338586        212.08909       218.756157     -227.2174748     -117.3114287]
#    To understand whether this hints to an issue in the minimized function,
#    the minimized function can be plotted along points between s0 and p1 to
#    look for unexpected behavior.
# Info in <Minuit2>: VariableMetricBuilder   19 - FCN =       4631.738989 Edm =       399.6821257 NCalls =    684
# Info in <Minuit2>: VariableMetricBuilder   20 - FCN =       4627.605773 Edm =       9.806950621 NCalls =    710
# Warning in <Minuit2>: DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# Info in <Minuit2>: DavidonErrorUpdator Explanation:
#    The distance from the minimum cannot be estimated, since the minimized
#    function seems not to be strictly convex in the space probed by the fit.
#    That is expected if the starting parameters are e.g. close to a local maximum
#    of the minimized function. If this function is expected to be fully convex
#    in the probed range or Minuit is already close to the function minimum, this
#    may hint to numerical or analytical issues with the minimized function.
#    This was found by projecting the difference of gradients at two points, s0 and p1,
#    onto the direction given by the difference of s0 and p1, where:
#  * s0:  	[     -1.538352394      -1.68050144     -1.661447507     -1.554915509     -1.420919421      -1.35410026     -1.361699123    -0.3451803267     -2.864508049]
#  * p1:  	[     -1.530995856     -1.682689769     -1.697646919     -1.645018825     -1.412759448      -1.34827234     -1.355185736    -0.3442852495     -2.845832548]
#  * gradient at s0:  	[     -120.0786614      147.5884557      117.5571572     -26.29407735      39.49489168      316.7931972      314.9365982      -204.619804     -108.2604137]
#  * gradient at p1:  	[      -145.992431      149.3200816      63.59515581       81.6314041      61.77940095       344.269994      346.5853119     -199.2319184     -133.2478235]
#    To understand whether this hints to an issue in the minimized function,
#    the minimized function can be plotted along points between s0 and p1 to
#    look for unexpected behavior.
# Info in <Minuit2>: VariableMetricBuilder   21 - FCN =       4621.282261 Edm =       1248.511001 NCalls =    734
# Warning in <Minuit2>: VariableMetricBuilder Matrix not pos.def, gdel = 0.121369 > 0
# Warning in <Minuit2>: MnPosDef non-positive diagonal element in covariance matrix[ 0 ] = -7.14264e-05
# Warning in <Minuit2>: MnPosDef non-positive diagonal element in covariance matrix[ 2 ] = -0.00159858
# Warning in <Minuit2>: MnPosDef non-positive diagonal element in covariance matrix[ 3 ] = -0.00112751
# Warning in <Minuit2>: MnPosDef Added to diagonal of Error matrix a value 0.501599
# Warning in <Minuit2>: VariableMetricBuilder gdel = -177679
# Info in <Minuit2>: VariableMetricBuilder   22 - FCN =       4602.267282 Edm =       265988.7874 NCalls =    778
# Info in <Minuit2>: VariableMetricBuilder   23 - FCN =       4582.043156 Edm =       25209.35809 NCalls =    815
# Info in <Minuit2>: VariableMetricBuilder   24 - FCN =       4572.116512 Edm =       5793.249748 NCalls =    843
# Info in <Minuit2>: VariableMetricBuilder   25 - FCN =       4546.813296 Edm =       15488.17703 NCalls =    876
# Info in <Minuit2>: VariableMetricBuilder   26 - FCN =       4522.435635 Edm =       2855.088788 NCalls =    909
# Info in <Minuit2>: VariableMetricBuilder   27 - FCN =       4520.243746 Edm =       1403.172408 NCalls =    931
# Warning in <Minuit2>: DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line (details in info log)
# Info in <Minuit2>: DavidonErrorUpdator Explanation:
#    The distance from the minimum cannot be estimated, since the minimized
#    function seems not to be strictly convex in the space probed by the fit.
#    That is expected if the starting parameters are e.g. close to a local maximum
#    of the minimized function. If this function is expected to be fully convex
#    in the probed range or Minuit is already close to the function minimum, this
#    may hint to numerical or analytical issues with the minimized function.
#    This was found by projecting the difference of gradients at two points, s0 and p1,
#    onto the direction given by the difference of s0 and p1, where:
#  * s0:  	[     -1.339899265     -1.772031241     -1.772141337      -1.77459556     -1.386473281     -1.414241149     -1.560243506    -0.3440704397     -2.127277117]
#  * p1:  	[     -1.338244816     -1.755378725     -1.764936476     -1.776122627     -1.379047641     -1.375751455     -1.609754223      -0.34664747     -2.100334312]
#  * gradient at s0:  	[      166.8036232     -19.83499123      3.961143134     -23.57412887     -78.05377187     -180.8527092     -69.49054296     -258.5627684     -24.96115236]
#  * gradient at p1:  	[      173.5018004      85.73226468      53.70671042     -24.70464755     -44.06832239      24.83044973      235.7849666     -344.4206807     -28.92158793]
#    To understand whether this hints to an issue in the minimized function,
#    the minimized function can be plotted along points between s0 and p1 to
#    look for unexpected behavior.
# Info in <Minuit2>: VariableMetricBuilder   28 - FCN =       4513.336311 Edm =       4000.598029 NCalls =    954
# Info in <Minuit2>: VariableMetricBuilder   29 - FCN =       4513.255115 Edm =       96.11192058 NCalls =    976
# Info in <Minuit2>: VariableMetricBuilder   30 - FCN =       4510.603883 Edm =       304.2860559 NCalls =    998
# Info in <Minuit2>: VariableMetricBuilder   31 - FCN =       4510.528697 Edm =       14.73718656 NCalls =   1019
# Warning in <Minuit2>: VariableMetricBuilder Matrix not pos.def., try to make pos.def.
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 4.83706
# Info in <Minuit2>: VariableMetricBuilder   32 - FCN =       4508.045509 Edm =       35.73643665 NCalls =   1041
# Info in <Minuit2>: VariableMetricBuilder   33 - FCN =       4505.585206 Edm =      0.7136400099 NCalls =   1061
# Info in <Minuit2>: VariableMetricBuilder   34 - FCN =       4505.551089 Edm =      0.1019212028 NCalls =   1081
# Info in <Minuit2>: VariableMetricBuilder   35 - FCN =       4505.506919 Edm =     0.06536590015 NCalls =   1101
# Info in <Minuit2>: VariableMetricBuilder   36 - FCN =       4505.496153 Edm =    0.004682252602 NCalls =   1121
# Info in <Minuit2>: VariableMetricBuilder   37 - FCN =       4505.495082 Edm =    0.001518769827 NCalls =   1141
# Info in <Minuit2>: VariableMetricBuilder   38 - FCN =       4505.493851 Edm =    0.006665449839 NCalls =   1161
# Info in <Minuit2>: VariableMetricBuilder   39 - FCN =       4505.378542 Edm =         1.0713569 NCalls =   1184
# Info in <Minuit2>: VariableMetricBuilder   40 - FCN =       4503.741917 Edm =      0.3620000165 NCalls =   1211
# Info in <Minuit2>: VariableMetricBuilder   41 - FCN =       4502.286853 Edm =     0.04677800046 NCalls =   1233
# Info in <Minuit2>: VariableMetricBuilder   42 - FCN =       4502.249152 Edm =    0.002464140592 NCalls =   1253
# Info in <Minuit2>: VariableMetricBuilder   43 - FCN =       4502.248448 Edm =    0.001928591324 NCalls =   1273
# Info in <Minuit2>: VariableMetricBuilder   44 - FCN =       4502.245094 Edm =    0.002653716059 NCalls =   1293
# Info in <Minuit2>: VariableMetricBuilder   45 - FCN =       4501.879613 Edm =      0.3570649499 NCalls =   1318
# Info in <Minuit2>: VariableMetricBuilder   46 - FCN =       4472.640712 Edm =       11.67540211 NCalls =   1346
# Info in <Minuit2>: VariableMetricBuilder   47 - FCN =       4461.807017 Edm =      0.2997586737 NCalls =   1368
# Info in <Minuit2>: VariableMetricBuilder   48 - FCN =       4461.637073 Edm =     0.02265214464 NCalls =   1388
# Info in <Minuit2>: VariableMetricBuilder   49 - FCN =       4461.600581 Edm =    0.009427242745 NCalls =   1408
# Info in <Minuit2>: VariableMetricBuilder   50 - FCN =       4461.586723 Edm =   0.0001837725796 NCalls =   1428
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuil
# Info in <Minuit2>: MnFunctionCross Result after 2nd Migrad FCN =       4462.086815 Edm =   1.942475876e-08 NCalls =     37
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |    S_-0.5g | limited |       163.297982 |  12.80521379
#     1 |    S_-0.7g | limited |      158.1676847 |  12.60584372
#     2 |    S_-0.8g | limited |      166.0148214 |  12.92346686
#     3 |    S_-1.0g | limited |      163.9879145 |  12.84450516
#     4 |    S_-1.2g | limited |      161.0119029 |  12.71873684
#     5 |    S_-1.3g | limited |      151.0148282 |   12.3234174
#     6 |    S_-1.5g | limited |      137.0276724 |  11.74292785
#     7 |          c |  fixed  |     -9.854327959 | 0.1242811625
#     8 |         nB | limited |                1 | 0.9443020085 (at lower limit)
# Info in <Minuit2>: MnMinos end of Minos scan for up interval for parameter c

# %%
scurve_fit.getParameters(dataset).Print('v')
# Out:
#   1) 0x57c4609b24b0 RooRealVar::          D = 0.02 C  L(-0.8 - 0.8)  "D"
#   2) 0x57c460e07350 RooRealVar::    S_-0.5g = 163.322 +/- 12.807  L(50 - 10000)  "S (-0.5g)"
#   3) 0x57c460d90000 RooRealVar::    S_-0.7g = 158.229 +/- 12.6125  L(50 - 10000)  "S (-0.7g)"
#   4) 0x57c460d99bb0 RooRealVar::    S_-0.8g = 165.998 +/- 12.9227  L(50 - 10000)  "S (-0.8g)"
#   5) 0x57c460da3770 RooRealVar::    S_-1.0g = 163.97 +/- 12.8436  L(50 - 10000)  "S (-1.0g)"
#   6) 0x57c461024fd0 RooRealVar::    S_-1.2g = 161.175 +/- 12.7347  L(50 - 10000)  "S (-1.2g)"
#   7) 0x57c46102eb90 RooRealVar::    S_-1.3g = 151.127 +/- 12.3319  L(50 - 10000)  "S (-1.3g)"
#   8) 0x57c461038750 RooRealVar::    S_-1.5g = 137.059 +/- 11.7451  L(50 - 10000)  "S (-1.5g)"
#   9) 0x57c460e42670 RooRealVar::          c = -9.97719 +/- (-0.125566,0.122848)  L(-30 - 30)  "c"
#  10) 0x57c45d0e93d0 RooRealVar:: c_pbarDn_1 = 1 C  L(0.71251 - 1)  "c_pbarDn_1"
#  11) 0x57c45921bbd0 RooRealVar:: c_pbarUp_1 = 1 C  L(-0.0202152 - 1)  "c_pbarUp_1"
#  12) 0x57c460c70d30 RooRealVar::         nB = 1.00001 +/- 0.871914  L(1 - 200)  "nB"
#  13) 0x57c460e42bf0 RooRealVar::      scale = 0.1 C  L(-INF - +INF)  "scale"
#  14) 0x57c45f86e920 RooRealVar::  vat_-0.5g = -5 C  L(-INF - +INF)  ""
#  15) 0x57c460e88d30 RooRealVar::  vat_-0.7g = -6 C  L(-INF - +INF)  ""
#  16) 0x57c45e5d80f0 RooRealVar::  vat_-0.8g = -8 C  L(-INF - +INF)  ""
#  17) 0x57c45a197db0 RooRealVar::  vat_-1.0g = -10 C  L(-INF - +INF)  ""
#  18) 0x57c4614c24e0 RooRealVar::  vat_-1.2g = -11 C  L(-INF - +INF)  ""
#  19) 0x57c46186c010 RooRealVar::  vat_-1.3g = -13 C  L(-INF - +INF)  ""
#  20) 0x57c4614c2e80 RooRealVar::  vat_-1.5g = -15 C  L(-INF - +INF)  ""

# %% [markdown]
# # SIMULATION, nominal case (2023 analysis), D set as constant

# %%
Ngravity = []
dNgravity = []

D.setConstant(True)

for i in range(0, Ntoys):
    c.setVal(real_gravity) # reset the value for simulation
    w["nB"].setVal(nB_val)

    for bias, stat in weights.items(): # reset the stat parameters
        w[f"S_{bias}"].setVal(stat)
        print("tot_events:", stat, "set value:", w[f"S_{bias}"].getVal

# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0177 ± 0.0129; [-0.012844240216416988,+0.012887565295829387]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9850 ± 0.0134; [-0.013418420071830068,+0.013465782907242822]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9802 ± 0.0133; [-0.013274689083681996,+0.01340164824027178]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0224 ± 0.0120; [-0.011958991247286156,+0.012022328599129557]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0301 ± 0.0123; [-0.012258099006243445,+0.01234369764435402]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9818 ± 0.0128; [-0.012733652250656747,+0.012891184894642332]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0084 ± 0.0125; [-0.012568709114520777,+0.012523136753791587]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0124 ± 0.0128; [-0.012758374239973579,+0.012782342593316938]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9959 ± 0.0130; [-0.013040048880593106,+0.0130264390022251]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0002 ± 0.0117; [-0.011617261340466468,+0.011747278103871946]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0156 ± 0.0130; [-0.013091155872185557,+0.012916122284672505]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0006 ± 0.0129; [-0.012863684644641674,+0.013007422890704348]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0025 ± 0.0128; [-0.012747990616569766,+0.012790854992948839]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9931 ± 0.0125; [-0.012511196717917922,+0.012484308629123133]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0090 ± 0.0125; [-0.012661038590153155,+0.012426195362914484]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9891 ± 0.0127; [-0.012651726302108241,+0.012676870644765562]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9972 ± 0.0134; [-0.013240652452442676,+0.013486040717165743]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0031 ± 0.0119; [-0.011934204597948023,+0.01190654162231225]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9950 ± 0.0135; [-0.013450941798392955,+0.013526667478588154]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0086 ± 0.0126; [-0.012503223906691303,+0.01263570024097753]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9988 ± 0.0126; [-0.012577542750033003,+0.012628386089003489]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0012 ± 0.0129; [-0.012863013744703411,+0.01291312646729885]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9896 ± 0.0121; [-0.01206442730441082,+0.012053118920166316]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0016 ± 0.0119; [-0.011880080470743242,+0.011936581730734053]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0127 ± 0.0135; [-0.013509177220564767,+0.013549740520761864]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0089 ± 0.0123; [-0.01234566622435701,+0.012176127312939562]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0252 ± 0.0118; [-0.011873302114319993,+0.011673415742726862]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9990 ± 0.0126; [-0.012692483021164583,+0.012553290809526938]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0050 ± 0.0125; [-0.01239829268857219,+0.012501336106897187]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0202 ± 0.0123; [-0.012236886261381726,+0.01231955289929539]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9897 ± 0.0132; [-0.013215095583125898,+0.01322192870860643]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9713 ± 0.0124; [-0.012352403173609455,+0.012374052353780534]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0075 ± 0.0120; [-0.012116249862899733,+0.01197144230179771]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0116 ± 0.0136; [-0.013606444323824194,+0.013523895645716634]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9953 ± 0.0138; [-0.013709956718585735,+0.013836057480744866]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# ...
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
from matplotlib import pyplot as plt

#print(res_norm)
plt.figure(9, figsize = (18,8))
plt.subplot(1,2,1)
plt.title("Extracted g and Error", fontsize = 20)
plt.grid()
plt.hist(Ngravity, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(Ngravity):.3f} std: {np.std(Ngravity):.3f}')
plt.legend(fontsize = 15, loc = "upper right")
plt.subplot(1,2,2)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(res_norm, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(res_norm):.3f} std: {np.std(res_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")
plt.savefig(f"residuals_L_{L}.png", bbox_inches = 'tight')

# %% [markdown]
# # Fit with D

# %%
Ngravity = []
dNgravity = []
ND = []
dND = []

D.setConstant(False)

for i in range(0, Ntoys):
    c.setVal(real_gravity) # reset the value for simulation
    w["nB"].setVal(nB_val)
    D.setVal(Dmu + np.random.normal(loc = 0, scale = Dsigma))  # D detector asymmetry, add a "manual smearing, because the simulation does not account for a generation of D"
    
    for bias, stat in weights.items(): # reset the stat parameters
        w[f"S_{bias}"].setVal(stat)
        print("tot_events:", stat, "set value:", w[f"S_{bias}"].getVal())

    
    pseudo_data = scurve_fit.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
    c.setVal(-10)
    result = scurve_fit.fitTo(pseudo_data,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(2),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.PrintLevel(-1),
                 #ROOT.RooFit.Verbose(False),   # disattiva log verboso
                 #ROOT.RooFit.Warnings(False),  # opzionale: disattiva warning
                 ROOT.RooFit.Minos(w['c']))
    # === 8. Risultati
    print("\n=== RISULTATI DEL FIT ===")
    print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
    print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
    print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
    print(f"fit status: {result.status()}")

    if result.status() < 1 and not np.isnan(c.getError()) and c.getError() > 0:
        Ngravity.append(c.getVal()*scale.getVal() - real_gravity*scale.getVal())
        dNgravity.append(c.getError()*scale.getVal())
        ND.append(D.getVal() - Dmu)
        dND.append(D.getError())

# === Normalized Residuals ===
res_norm = (np.array((Ngravity)))/np.array(dNgravity)
Dres_norm = (np.array((ND)))/np.array(dND)
# Out:
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0097 ± 0.0250; [-0.025386269645936245,+0.024505867439865422]
# scale = 0.1000 ± 0.0000
# D     = 0.0217 ± 0.0816
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9714 ± 0.0242; [-0.0240842054269772,+0.02411012152958867]
# scale = 0.1000 ± 0.0000
# D     = 0.0184 ± 0.0805
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0113 ± 0.0251; [-0.024255114149807636,+0.025618015329827076]
# scale = 0.1000 ± 0.0000
# D     = 0.0271 ± 0.0826
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0040 ± 0.0244; [-0.024386091537795612,+0.024199173520007822]
# scale = 0.1000 ± 0.0000
# D     = 0.0189 ± 0.0803
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0291 ± 0.0259; [-0.02423229247050302,+0.02607166281387362]
# scale = 0.1000 ± 0.0000
# D     = 0.0288 ± 0.0830
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9793 ± 0.0234; [-0.023507243483383837,+0.023024932022238546]
# scale = 0.1000 ± 0.0000
# D     = 0.0234 ± 0.0786
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0616 ± 0.0219; [-0.022114371227268073,+0.04014900052293079]
# scale = 0.1000 ± 0.0000
# D     = 0.0469 ± 0.0735
# fit status: 80
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0009 ± 0.0253; [-0.025575723071167553,+0.024626609741549267]
# scale = 0.1000 ± 0.0000
# D     = 0.0176 ± 0.0818
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0179 ± 0.0239; [-0.02377167496459353,+0.023897566360273046]
# scale = 0.1000 ± 0.0000
# D     = 0.0170 ± 0.0786
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0150 ± 0.0240; [-0.023374179612647608,+0.02437373692266115]
# scale = 0.1000 ± 0.0000
# D     = 0.0222 ± 0.0801
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0606 ± 0.0246; [-0.02516207296024589,+0.018885051569221767]
# scale = 0.1000 ± 0.0000
# D     = 0.0050 ± 0.0817
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9994 ± 0.0232; [-0.023067673432946866,+0.0231067626279653]
# scale = 0.1000 ± 0.0000
# D     = 0.0199 ± 0.0776
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0104 ± 0.0236; [-0.02338079361850831,+0.023634547536468455]
# scale = 0.1000 ± 0.0000
# D     = 0.0174 ± 0.0787
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9719 ± 0.0249; [-0.024663829097273063,+0.02528660061155868]
# scale = 0.1000 ± 0.0000
# D     = 0.0150 ± 0.0829
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9804 ± 0.0216; [-0.021668173588995462,+0.02137751702596918]
# scale = 0.1000 ± 0.0000
# D     = 0.0334 ± 0.0743
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9645 ± 0.0229; [-0.02310716728680176,+0.02991965236164322]
# scale = 0.1000 ± 0.0000
# D     = 0.0356 ± 0.0750
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0054 ± 0.0223; [-0.022294708268373813,+0.022072516536403644]
# scale = 0.1000 ± 0.0000
# D     = 0.0172 ± 0.0759
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9950 ± 0.0226; [-0.022575556897411166,+0.022470989893615786]
# scale = 0.1000 ± 0.0000
# D     = 0.0214 ± 0.0759
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0172 ± 0.0264; [-0.02606295404709083,+0.02650058955750441]
# scale = 0.1000 ± 0.0000
# D     = 0.0281 ± 0.0858
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0027 ± 0.0249; [-0.025056043749933234,+0.0246403959684122]
# scale = 0.1000 ± 0.0000
# D     = 0.0174 ± 0.0807
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0281 ± 0.0228; [-0.022169435888533123,+0.022867198987970277]
# scale = 0.1000 ± 0.0000
# D     = 0.0146 ± 0.0768
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0786 ± 0.0231; [-0.023105970475412997,+0.022863372899514105]
# scale = 0.1000 ± 0.0000
# D     = 0.0277 ± 0.0762
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0159 ± 0.0243; [-0.024446029558077086,+0.023999434956260605]
# scale = 0.1000 ± 0.0000
# D     = 0.0172 ± 0.0793
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9803 ± 0.0250; [-0.02482819085832412,+0.02495788206283079]
# scale = 0.1000 ± 0.0000
# D     = 0.0177 ± 0.0800
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9506 ± 0.0217; [-0.02124297950761691,+0.014979531554337323]
# scale = 0.1000 ± 0.0000
# D     = 0.0018 ± 0.0836
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9804 ± 0.0247; [-0.0250423174049912,+0.024111891584200684]
# scale = 0.1000 ± 0.0000
# D     = 0.0140 ± 0.0813
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9639 ± 0.0259; [-0.026478298205720785,+0.01948953666701436]
# scale = 0.1000 ± 0.0000
# D     = -0.0002 ± 0.0843
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0062 ± 0.0249; [-0.024840592190379734,+0.024681364347856314]
# scale = 0.1000 ± 0.0000
# D     = 0.0171 ± 0.0825
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9707 ± 0.0253; [-0.025773312258559694,+0.023492366198905018]
# scale = 0.1000 ± 0.0000
# D     = 0.0091 ± 0.0834
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0040 ± 0.0231; [-0.023273849557432384,+0.022849489540192017]
# scale = 0.1000 ± 0.0000
# D     = 0.0198 ± 0.0774
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0081 ± 0.0239; [-0.023901078569205272,+0.023754325637743923]
# scale = 0.1000 ± 0.0000
# D     = 0.0170 ± 0.0787
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9971 ± 0.0248; [-0.02504398789919159,+0.02431493877757363]
# scale = 0.1000 ± 0.0000
# D     = 0.0184 ± 0.0816
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0122 ± 0.0252; [-0.025041337624001417,+0.02509072637809628]
# scale = 0.1000 ± 0.0000
# D     = 0.0253 ± 0.0814
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9998 ± 0.0262; [-0.026136648654178682,+0.02594361850068543]
# scale = 0.1000 ± 0.0000
# D     = 0.0188 ± 0.0845
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9394 ± 0.0242; [-0.022328618444220235,+0.02466231002975237]
# scale = 0.1000 ± 0.0000
# D     = 0.0233 ± 0.0790
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9628 ± 0.0227; [-0.023125262472729655,+0.022563770290255823]
# scale = 0.1000 ± 0.0000
# D     = 0.0250 ± 0.0764
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0448 ± 0.0258; [-0.01877266084368601,+0.025774976825314717]
# scale = 0.1000 ± 0.0000
# D     = 0.0362 ± 0.0841
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0147 ± 0.0256; [-0.024856370387575308,+0.026260918509696158]
# scale = 0.1000 ± 0.0000
# D     = 0.0253 ± 0.0833
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0187 ± 0.0231; [-0.02299668100139039,+0.023038168536121752]
# scale = 0.1000 ± 0.0000
# D     = 0.0119 ± 0.0786
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9724 ± 0.0239; [-0.024119886836491505,+0.022888294390670673]
# scale = 0.1000 ± 0.0000
# D     = 0.0196 ± 0.0787
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9824 ± 0.0249; [-0.024629564656317646,+0.02484790243689347]
# scale = 0.1000 ± 0.0000
# D     = 0.0181 ± 0.0816
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9874 ± 0.0214; [-0.021450531508656875,+0.021160239254469106]
# scale = 0.1000 ± 0.0000
# D     = 0.0300 ± 0.0735
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9997 ± 0.0235; [-0.02325929145915255,+0.02354206721214002]
# scale = 0.1000 ± 0.0000
# D     = 0.0206 ± 0.0778
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0115 ± 0.0231; [-0.02297939312923744,+0.02295368985597559]
# scale = 0.1000 ± 0.0000
# D     = 0.0185 ± 0.0772
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0142 ± 0.0230; [-0.02268334468075331,+0.02303384349828357]
# scale = 0.1000 ± 0.0000
# D     = 0.0174 ± 0.0767
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9850 ± 0.0236; [-0.023519587060842714,+0.023595869950419665]
# scale = 0.1000 ± 0.0000
# D     = 0.0228 ± 0.0780
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0050 ± 0.0252; [-0.025144236410330808,+0.02494545184888157]
# scale = 0.1000 ± 0.0000
# D     = 0.0199 ± 0.0811
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9855 ± 0.0228; [-0.022637989867350536,+0.022801655565150555]
# scale = 0.1000 ± 0.0000
# D     = 0.0244 ± 0.0764
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0273 ± 0.0245; [-0.023270440150577148,+0.02480029871872537]
# scale = 0.1000 ± 0.0000
# D     = 0.0239 ± 0.0802
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9886 ± 0.0230; [-0.02289099634360096,+0.022975747598612813]
# scale = 0.1000 ± 0.0000
# D     = 0.0261 ± 0.0774
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9702 ± 0.0229; [-0.02312919651439383,+0.030104979211314626]
# scale = 0.1000 ± 0.0000
# D     = 0.0339 ± 0.0770
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0329 ± 0.0252; [-0.024629673023074873,+0.025181297761586043]
# scale = 0.1000 ± 0.0000
# D     = 0.0241 ± 0.0817
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9934 ± 0.0248; [-0.02451654405772513,+0.024679148707588323]
# scale = 0.1000 ± 0.0000
# D     = 0.0192 ± 0.0829
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0274 ± 0.0262; [-0.024522047081554414,+0.026228924871484482]
# scale = 0.1000 ± 0.0000
# D     = 0.0330 ± 0.0850
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9748 ± 0.0234; [-0.02306955156522955,+0.023544684351689403]
# scale = 0.1000 ± 0.0000
# D     = 0.0247 ± 0.0780
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9987 ± 0.0233; [-0.023201095330371402,+0.023162798964657713]
# scale = 0.1000 ± 0.0000
# D     = 0.0191 ± 0.0793
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0345 ± 0.0224; [-0.026709904160652817,+0.022675372628536694]
# scale = 0.1000 ± 0.0000
# D     = 0.0074 ± 0.0755
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0312 ± 0.0229; [-0.024200687623509763,+0.023221662569313142]
# scale = 0.1000 ± 0.0000
# D     = 0.0141 ± 0.0773
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0205 ± 0.0248; [-0.024710986013006583,+0.02462608715558283]
# scale = 0.1000 ± 0.0000
# D     = 0.0209 ± 0.0813
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9714 ± 0.0226; [-0.022760120279978282,+0.021926491403611095]
# scale = 0.1000 ± 0.0000
# D     = 0.0300 ± 0.0759
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9797 ± 0.0235; [-0.02376607969001174,+0.022965322060322056]
# scale = 0.1000 ± 0.0000
# D     = 0.0245 ± 0.0778
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0357 ± 0.0232; [-0.01910485636513397,+0.023596219735024918]
# scale = 0.1000 ± 0.0000
# D     = 0.0232 ± 0.0771
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9628 ± 0.0223; [-0.022683551704228963,+0.02860460499848938]
# scale = 0.1000 ± 0.0000
# D     = 0.0318 ± 0.0762
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0156 ± 0.0245; [-0.024613413057835848,+0.02411166772675027]
# scale = 0.1000 ± 0.0000
# D     = 0.0212 ± 0.0805
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9955 ± 0.0272; [-0.026979299363835703,+0.02711417125583987]
# scale = 0.1000 ± 0.0000
# D     = 0.0168 ± 0.0870
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9754 ± 0.0233; [-0.023467741811251552,+0.0229238042467988]
# scale = 0.1000 ± 0.0000
# D     = 0.0275 ± 0.0769
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9882 ± 0.0252; [-0.025192873289248435,+0.02505420111671268]
# scale = 0.1000 ± 0.0000
# D     = 0.0186 ± 0.0826
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9862 ± 0.0261; [-0.026187798538857738,+0.025796147882175675]
# scale = 0.1000 ± 0.0000
# D     = 0.0128 ± 0.0834
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9979 ± 0.0261; [-0.026081083600538204,+0.025944252732099327]
# scale = 0.1000 ± 0.0000
# D     = 0.0184 ± 0.0850
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9330 ± 0.0256; [-0.021697750417568773,+0.026236014904837613]
# scale = 0.1000 ± 0.0000
# D     = 0.0357 ± 0.0838
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0265 ± 0.0240; [-0.0230373600873022,+0.024182247812862965]
# scale = 0.1000 ± 0.0000
# D     = 0.0257 ± 0.0802
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9652 ± 0.0220; [-0.022579484413821092,+0.023946315639921466]
# scale = 0.1000 ± 0.0000
# D     = 0.0296 ± 0.0755
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0010 ± 0.0267; [-0.026476299435306057,+0.026532356710489348]
# scale = 0.1000 ± 0.0000
# D     = 0.0203 ± 0.0871
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0232 ± 0.0246; [-0.02428553682913771,+0.024611918146058107]
# scale = 0.1000 ± 0.0000
# D     = 0.0232 ± 0.0822
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9998 ± 0.0251; [-0.02502043794943172,+0.024859733383566965]
# scale = 0.1000 ± 0.0000
# D     = 0.0190 ± 0.0820
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0192 ± 0.0235; [-0.02351775944084511,+0.023364255503104114]
# scale = 0.1000 ± 0.0000
# D     = 0.0160 ± 0.0789
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0090 ± 0.0232; [-0.023087794355790052,+0.02312549088255359]
# scale = 0.1000 ± 0.0000
# D     = 0.0176 ± 0.0780
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0149 ± 0.0254; [-0.025376123372225768,+0.025269012544225714]
# scale = 0.1000 ± 0.0000
# D     = 0.0232 ± 0.0832
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9960 ± 0.0246; [-0.02443722360089783,+0.024570045788508115]
# scale = 0.1000 ± 0.0000
# D     = 0.0226 ± 0.0814
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9747 ± 0.0222; [-0.021913277743948995,+0.022306461233633803]
# scale = 0.1000 ± 0.0000
# D     = 0.0355 ± 0.0751
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0441 ± 0.0240; [-0.025139164457365887,+0.024352606687825552]
# scale = 0.1000 ± 0.0000
# D     = 0.0207 ± 0.0795
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9484 ± 0.0271; [-0.01134956347338723,+0.026464208134693187]
# scale = 0.1000 ± 0.0000
# D     = 0.0555 ± 0.0886
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0061 ± 0.0251; [-0.02484016744307242,+0.02508264464882189]
# scale = 0.1000 ± 0.0000
# D     = 0.0227 ± 0.0823
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0264 ± 0.0242; [-0.023581028533079498,+0.024191752455482603]
# scale = 0.1000 ± 0.0000
# D     = 0.0201 ± 0.0788
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9762 ± 0.0230; [-0.023229934588269885,+0.022609980369168954]
# scale = 0.1000 ± 0.0000
# D     = 0.0251 ± 0.0773
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9915 ± 0.0267; [-0.026866059773454076,+0.026250751148142844]
# scale = 0.1000 ± 0.0000
# D     = 0.0157 ± 0.0856
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0040 ± 0.0222; [-0.022040679610455166,+0.02207304138854321]
# scale = 0.1000 ± 0.0000
# D     = 0.0219 ± 0.0756
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9730 ± 0.0254; [-0.0253934287062852,+0.02481730692352467]
# scale = 0.1000 ± 0.0000
# D     = 0.0119 ± 0.0836
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9722 ± 0.0225; [-0.022954107871069815,+0.021768334314584827]
# scale = 0.1000 ± 0.0000
# D     = 0.0260 ± 0.0762
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0229 ± 0.0239; [-0.02359627381421755,+0.023993002734979806]
# scale = 0.1000 ± 0.0000
# D     = 0.0165 ± 0.0796
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9980 ± 0.0236; [-0.023589307908294183,+0.023373599668110964]
# scale = 0.1000 ± 0.0000
# D     = 0.0189 ± 0.0789
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9823 ± 0.0249; [-0.024854322659342627,+0.024700639143002558]
# scale = 0.1000 ± 0.0000
# D     = 0.0197 ± 0.0815
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0003 ± 0.0233; [-0.02325172854013864,+0.023168351621554787]
# scale = 0.1000 ± 0.0000
# D     = 0.0215 ± 0.0775
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9920 ± 0.0227; [-0.022723682962388105,+0.022555571770560875]
# scale = 0.1000 ± 0.0000
# D     = 0.0247 ± 0.0759
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9895 ± 0.0237; [-0.023680686978237837,+0.023455253872969407]
# scale = 0.1000 ± 0.0000
# D     = 0.0216 ± 0.0776
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9781 ± 0.0237; [-0.02392608738099646,+0.023362771814514138]
# scale = 0.1000 ± 0.0000
# D     = 0.0223 ± 0.0788
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0420 ± 0.0238; [-0.020370215345840686,+0.02418893219810648]
# scale = 0.1000 ± 0.0000
# D     = 0.0265 ± 0.0799
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9831 ± 0.0245; [-0.024384201257020663,+0.024387084808462363]
# scale = 0.1000 ± 0.0000
# D     = 0.0185 ± 0.0804
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0352 ± 0.0240; [-0.028338387432315027,+0.024471886763372697]
# scale = 0.1000 ± 0.0000
# D     = 0.0179 ± 0.0803
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0039 ± 0.0243; [-0.024512676947226704,+0.023859654811593464]
# scale = 0.1000 ± 0.0000
# D     = 0.0183 ± 0.0808
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0174 ± 0.0246; [-0.024543742346694847,+0.024453216391866223]
# scale = 0.1000 ± 0.0000
# D     = 0.0206 ± 0.0793
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0092 ± 0.0288; [-0.028743065176187473,+0.028360251232692996]
# scale = 0.1000 ± 0.0000
# D     = 0.0273 ± 0.0914
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0116 ± 0.0238; [-0.023592358299054143,+0.023869556784694875]
# scale = 0.1000 ± 0.0000
# D     = 0.0204 ± 0.0792
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9933 ± 0.0235; [-0.0234043957084003,+0.023514253505202844]
# scale = 0.1000 ± 0.0000
# D     = 0.0208 ± 0.0780
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9955 ± 0.0233; [-0.023270317965105314,+0.02321011068891208]
# scale = 0.1000 ± 0.0000
# D     = 0.0238 ± 0.0771
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9822 ± 0.0268; [-0.02707686813789196,+0.026156902968000967]
# scale = 0.1000 ± 0.0000
# D     = 0.0119 ± 0.0871
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9705 ± 0.0227; [-0.02303683304669303,+0.023993592419705088]
# scale = 0.1000 ± 0.0000
# D     = 0.0298 ± 0.0768
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9869 ± 0.0235; [-0.023476855606970836,+0.023389990465563712]
# scale = 0.1000 ± 0.0000
# D     = 0.0261 ± 0.0776
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9752 ± 0.0237; [-0.024035838309407396,+0.023190854617631124]
# scale = 0.1000 ± 0.0000
# D     = 0.0172 ± 0.0791
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0397 ± 0.0238; [-0.01922116838627645,+0.02417294109263212]
# scale = 0.1000 ± 0.0000
# D     = 0.0206 ± 0.0767
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0171 ± 0.0232; [-0.02278371289871107,+0.023408979249924453]
# scale = 0.1000 ± 0.0000
# D     = 0.0179 ± 0.0777
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0094 ± 0.0243; [-0.02432805426857541,+0.02402832641713132]
# scale = 0.1000 ± 0.0000
# D     = 0.0182 ± 0.0798
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0081 ± 0.0244; [-0.024367024007859544,+0.02411358842805657]
# scale = 0.1000 ± 0.0000
# D     = 0.0169 ± 0.0810
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9981 ± 0.0259; [-0.025897907321372007,+0.025729237214901775]
# scale = 0.1000 ± 0.0000
# D     = 0.0204 ± 0.0835
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0200 ± 0.0233; [-0.02316076965118802,+0.023318776449898822]
# scale = 0.1000 ± 0.0000
# D     = 0.0134 ± 0.0782
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0062 ± 0.0213; [-0.021311083513354402,+0.021311083513354402]
# scale = 0.1000 ± 0.0000
# D     = 0.0163 ± 0.0734
# fit status: -1
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0267 ± 0.0243; [-0.02417859710215972,+0.024032789488880175]
# scale = 0.1000 ± 0.0000
# D     = 0.0197 ± 0.0797
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0064 ± 0.0225; [-0.0222803461988353,+0.022641422100786505]
# scale = 0.1000 ± 0.0000
# D     = 0.0232 ± 0.0755
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9628 ± 0.0241; [-0.02371212905381411,+0.028641209772572708]
# scale = 0.1000 ± 0.0000
# D     = 0.0240 ± 0.0797
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0080 ± 0.0245; [-0.02431831870886218,+0.024572059208193456]
# scale = 0.1000 ± 0.0000
# D     = 0.0218 ± 0.0811
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9876 ± 0.0225; [-0.02275161887701782,+0.022107407407132983]
# scale = 0.1000 ± 0.0000
# D     = 0.0278 ± 0.0767
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0106 ± 0.0223; [-0.0222713584330205,+0.02227769066892399]
# scale = 0.1000 ± 0.0000
# D     = 0.0155 ± 0.0757
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# ...
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.5g,S_-0.7g,S_-0.8g,S_-1.0g,S_-1.2g,S_-1.3g,S_-1.5g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.5g,vat_-0.7g,vat_-0.8g,vat_-1.0g,vat_-1.2g,vat_-1.3g,vat_-1.5g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
#print(res_norm)
plt.figure(10, figsize = (18,16))
plt.subplot(2,2,1)
plt.title("Extracted g and Error", fontsize = 20)
plt.grid()
plt.hist(Ngravity, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(Ngravity):.3f} std: {np.std(Ngravity):.3f}')
plt.legend(fontsize = 15,  loc = "upper right")
plt.subplot(2,2,2)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(res_norm, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(res_norm):.3f} std: {np.std(res_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")

#plt.figure(11, figsize = (18,8))
plt.subplot(2,2,3)
plt.title("Extracted D and Error", fontsize = 20)
plt.grid()
plt.hist(ND, bins = 30, histtype = 'step', color = 'blue', linestyle = '-', label = f'$\mu$ = {np.mean(ND):.3f} std: {np.std(ND):.3f}')
plt.legend(fontsize = 15,  loc = "upper right")
plt.subplot(2,2,4)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(Dres_norm, bins = 30, range = (-5, 5), histtype = 'step', color = 'blue', linestyle = '-', label = f'$\mu$ = {np.mean(Dres_norm):.3f} std: {np.std(Dres_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")

plt.savefig(f"residuals_D_L_{L}.png", bbox_inches = 'tight')
