# %%
import ROOT
from scipy import interpolate as interpolate
from scipy.stats import norm
import numpy as np
from utils import NonUniformStat, append_to_dict
import json
from matplotlib import pyplot as plt

# %%
BIAS = {}

with open("bias_dictionary.json", "r", encoding="utf-8") as f:
    BIAS = json.load(f)

tot_event, Dmu, Dsigma, nB_value = 0,0,0,0
#distribution = [169, 162, 188, 133, 121, 130, 162, 137, 195, 171, 154]

# load configuration file and read the configurations
with open("config.txt", 'r') as file:
    for line in file:
        line = line.strip()
        line = line.replace(" ","")
        if not ("#" in line):
            print(line)
        if not line:
            continue
        if 'Ntot' in line:
            key, value = line.split('=')
            tot_event = int(value)
        if 'nB_val' in line:
            key, value = line.split('=')
            nB_val = int(value)
        if 'Dmu' in line:
            key, value = line.split('=')
            Dmu = float(value)
        if 'Dsigma' in line:
            key, value = line.split('=')
            Dsigma = float(value)
        if 'real_gravity' in line:
            key, value = line.split('=')
            real_gravity = float(value)
        if 'Ntoys' in line:
            key, value = line.split('=')
            Ntoys = int(value)
# Out:
# Dmu=+0.02
# Dsigma=0.08
# K=0.85
# real_gravity=-10
# Ntot=1100
# nB_val=7
# Ntoys=1000
# pfraction=0.5

# %%
Dmu    = Dmu
Dsigma = Dsigma
L      = 4
print(Dmu)
# Out:
# 0.02

# %%
# Parameters
L = 2
Dsigma = 0.08

# %%
BIAS = {}
biasList = np.linspace( (real_gravity/10 - L/2)*10, (real_gravity/10 + L/2)*10, 7)
#print(f"bias list is {biasList}")

for bias in biasList:
    BIAS.update({f"{(bias/10):.1f}g" : int(bias)})

print(BIAS)

weights = {} # define the dictionary containing the statistics
for key, value in BIAS.items():
    weights.update( {key: int(tot_event/len(BIAS.values())) })
# Out:
# {'-2.0g': -20, '-1.7g': -16, '-1.3g': -13, '-1.0g': -10, '-0.7g': -6, '-0.3g': -3, '0.0g': 0}

# %% [markdown]
# # Spline approximated with LINEAR SLOPE

# %%
def scurve_model(x, L, g):
    result = 0
    if((-L/2 + g) < x and x < ( L/2 + g)):
        result = 2/L * (x - g)
    elif((-L/2 +g) >= x):
        result = -.99
    elif(x >= ( L/2 + g )):
        result = +.99
    return result

print("linear scurve evaluated at -2 : %.1f" % scurve_model(-2,2,-1))
print("linear scurve evaluated at -1.5 : %.1f" % scurve_model(-1.5,2,-1))
print("linear scurve evaluated at -1 : %.1f" % scurve_model(-1,2,-1))
print("linear scurve evaluated at -.5 : %.1f" % scurve_model(-.5,2,-1))
print("linear scurve evaluated at -2 : %.1f" % scurve_model(-2,2,-1))
print("linear scurve evaluated at 0 : %.1f"  % scurve_model(0,2,-1))
print("linear scurve evaluated at 1 : %.1f"  % scurve_model(1,2,-1))
print("linear scurve evaluated at 1 : %.1f"  % scurve_model(10,2,-1))
# Out:
# linear scurve evaluated at -2 : -1.0
# linear scurve evaluated at -1.5 : -0.5
# linear scurve evaluated at -1 : 0.0
# linear scurve evaluated at -.5 : 0.5
# linear scurve evaluated at -2 : -1.0
# linear scurve evaluated at 0 : 1.0
# linear scurve evaluated at 1 : 1.0
# linear scurve evaluated at 1 : 1.0

# %%
import csv

# ===  generate the True Asymemtry from Simulation
ASYMMETRY_TRUE = {}
for key, value in BIAS.items():
    ASYMMETRY_TRUE.update({key : float(scurve_model(value/10, L, real_gravity/10))})
    
print(ASYMMETRY_TRUE)

# Create simulation file
rows = []
for bias in np.linspace(-11, 9, 200):
    rows.append([bias, scurve_model(bias, L, real_gravity/10)])  # ogni riga = [bias, valore]
# 7.492462311557791 0.99
# 7.592964824120603 0.99
# 7.693467336683419 0.99
# 7.793969849246231 0.99
# 7.894472361809047 0.99
# 7.994974874371859 0.99
# 8.095477386934675 0.99
# 8.195979899497488 0.99
# 8.296482412060303 0.99
# 8.396984924623116 0.99
# 8.497487437185931 0.99
# 8.597989949748744 0.99
# 8.69849246231156 0.99
# 8.798994974874372 0.99
# 8.899497487437188 0.99
# 9.0 0.99

# %%
plt.figure(1)
xpoints = np.linspace(-5,5,100)
ypoints = [scurve_model(item, L, real_gravity/10) for item in xpoints]
plt.errorbar(xpoints, ypoints, marker = '.', color = 'blue')
plt.xticks([-5,-4,-3,-2,-1,0,1,2,3])
ypoints = [scurve_model(item/10, L, real_gravity/10) for item in biasList]
xpoints = np.array(biasList)/10
plt.errorbar(xpoints, ypoints, linestyle = "" ,marker = "*", color = "red")
plt.grid()

# %% [markdown]
# # Open The Workspace with the PDFs

# %%
f = ROOT.TFile("analysis_output/workspace.root")
w = f.Get("w")
w.Print("v")

w['c_pbarDn_1'].setVal(1.0); w['c_pbarDn_1'].setConstant(True)
w['c_pbarUp_1'].setVal(1.0); w['c_pbarUp_1'].setConstant(True)
# Out:
# RooWorkspace(w) w contents
#
# variables
# ---------
# (Z,biaskey,c_pbarDn_1,c_pbarDn_2,c_pbarUp_1,c_pbarUp_2,evtype)
#
# p.d.f.s
# -------
# RooHistPdf::hpdf_pbarDn_1[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarDn_2[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarUp_1[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::hpdf_pbarUp_2[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::pdf_cosm[ pdfObs=(Z) ] = 1.8628
# RooAddPdf::pdf_pbarDn[ c_pbarDn_1 * hpdf_pbarDn_1 + [%] * hpdf_pbarDn_2 ] = 0.0121951/1
# RooAddPdf::pdf_pbarUp[ c_pbarUp_1 * hpdf_pbarUp_1 + [%] * hpdf_pbarUp_2 ] = 0.844512/1
#
# datasets
# --------
# RooDataHist::rdhbin_pbarUp1(Z)
# RooDataHist::rdhbin_pbarUp2(Z)
# RooDataHist::rdhbin_pbarDn1(Z)
# RooDataHist::rdhbin_pbarDn2(Z)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::rhcosm(Z)

# %%
Z = w['Z']
zframe = Z.frame(Title = "Z Distributions, Templates")
w['pdf_pbarUp'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kRed))
w['pdf_pbarDn'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kBlue))
w['pdf_cosm'].plotOn(zframe, ROOT.RooFit.LineColor(ROOT.kGreen))

c = ROOT.TCanvas("pdfs_templates", "pdfs_templates", 600, 600)
ROOT.gPad.SetLeftMargin(0.15)
zframe.GetYaxis().SetTitleOffset(1.4)
zframe.Draw()
c.Draw()
# Out:
# <div id="root_plot_1761646105867" style="width: 600px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1761646105867(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1006.55000521342,"fY1":-0.129843759674114,"fX2":-131.883332029978,"fY2":1.16859375967411,"fXtoAbsPixelk":685.86562344234,"fXtoPixelk":685.86562344234,"fXtoPixel":0.681402433947547,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-440.529475986742,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":596,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1006.55000521342,"fPixeltoXk":-1006.55000521342,"fPixeltoX":1.46756153218698,"fAbsPixeltoYk":1.16859375967411,"fPixeltoYk":-0.129843759674114,"fPixeltoY":-0.0022699956631962,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-875.35,"fUymin":0,"fUxmax":-219.35,"fUymax":1.03875,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"pdfs_templates","fTitle":"pdfs_templates","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":596,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;11 ...

# %% [markdown]
# # Create the RooDataSet

# %%
BiasCategory = ROOT.RooCategory("secondCategory", "a second category", BIAS)
BiasCategory.Print("v")

#dataset = ROOT.RooDataSet("data","data", ROOT.RooArgSet(Z,BiasCategory))
# Out:
# --- RooAbsArg ---
#   Value State: clean
#   Shape State: clean
#   Attributes:
#   Address: 0x5b04675b8a90
#   Clients:
#   Servers:
#   Proxies:
# --- RooAbsCategory ---
#   Value = -20 "-2.0g)
#   Possible states:
#     -0.3g	-3
#     -0.7g	-6
#     -1.0g	-10
#     -1.3g	-13
#     -1.7g	-16
#     -2.0g	-20
#     0.0g	0

# %%
simModelBase = ROOT.RooSimultaneous("model_base_simultaneous", "model for bias", BiasCategory)

# 2. Crea un mapping da categoria (es. "-1.0g") a PDF personalizzato

pdf_per_categoria = {} # senno muoiono

for category, weight in weights.items():
    print(f"Setting up PDF for category: {category}")
    
    # Calcolo degli eventi Up/Down
    Nup   = 0.5 * weight * (1 - ASYMMETRY_TRUE[category])
    Ndown = 0.5 * weight * (1 + ASYMMETRY_TRUE[category])
    
    # Costanti per RooAddPdf
    nup_const = ROOT.RooFit.RooConst(Nup)
    ndwn_const = ROOT.RooFit.RooConst(Ndown)
    
    # PDF composita per questa categoria
    model_i = ROOT.RooAddPdf(f"pdf_{category}", f"pdf_{category}",
                             ROOT.RooArgList(w['pdf_pbarUp'], w['pdf_pbarDn']),
                             ROOT.RooArgList(nup_const, ndwn_const))
    pdf_per_categoria[category] = model_i
    
    # Aggiungila alla simultanea
    simModelBase.addPdf(model_i, category)
# Out:
# Setting up PDF for category: -2.0g
# Setting up PDF for category: -1.7g
# Setting up PDF for category: -1.3g
# Setting up PDF for category: -1.0g
# Setting up PDF for category: -0.7g
# Setting up PDF for category: -0.3g
# Setting up PDF for category: 0.0g

# %%
# Generazione separata per ciascuna categoria
dataset = simModelBase.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
dataset.Print("v")
# Out:
# DataStore hmaster (hmaster)
#   Contains 14 entries
#   Observables:
#     1)               Z = -450  L(-875.35 - -219.35) B(2)  "Z"
#     2)  secondCategory = 0.0g(idx = 0)
#   "a second category"

# %%
ttable = dataset.table(BiasCategory)
ttable.Print("v")
# Out:
#   Table secondCategory : hmaster
#   +-------+-----+
#   | -2.0g | 153 |
#   | -1.7g | 137 |
#   | -1.3g | 173 |
#   | -1.0g | 176 |
#   | -0.7g | 158 |
#   | -0.3g | 157 |
#   |  0.0g | 164 |
#   +-------+-----+

# %%
c1 = ROOT.TCanvas("data_plot", "data_plot", 800, 800)

zframe1 = Z.frame( ROOT.RooFit.Bins(18), Title = "Plot of Z data")
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == -30'), ROOT.RooFit.MarkerColor(ROOT.kBlue),  ROOT.RooFit.Name("cat_-30"))
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == -20'), ROOT.RooFit.MarkerColor(ROOT.kRed),   ROOT.RooFit.Name("cat_-20"))
dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == 30'), ROOT.RooFit.MarkerColor(ROOT.kGreen),  ROOT.RooFit.Name("cat_+30"))
#dataset.plotOn(zframe1, ROOT.RooFit.Cut('secondCategory == +20'), ROOT.RooFit.MarkerColor(6),   ROOT.RooFit.Name("cat_-20"))
#w['model_base'].plotOn(zframe1)

#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "-3.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kBlue))
#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "-2.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kRed))
#simModelBase.plotOn(zframe1, ROOT.RooFit.Slice(BiasCategory, "+3.0g") , ROOT.RooFit.ProjWData(ROOT.RooArgSet(BiasCategory), dataset) , ROOT.RooFit.LineColor(ROOT.kGreen))

zframe1.Draw()

# Crea la legenda
legend = ROOT.TLegend(0.6, 0.7, 0.88, 0.88)  # x1,y1,x2,y2 in NDC (posizione)
legend.SetBorderSize(0)
legend.SetFillStyle(0)
legend.AddEntry(zframe1.findObject("cat_-30"), "-3.0g", "lep")
legend.AddEntry(zframe1.findObject("cat_-20"), "-2.0g", "lep")
legend.AddEntry(zframe1.findObject("cat_+30"), "+3.0g", "lep")
legend.Draw()

c1.Draw()
# Out:
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 0 events out of 1118 total events
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 153 events out of 1118 total events
# [#1] INFO:Plotting -- RooTreeData::plotOn: plotting 0 events out of 1118 total events
# <div id="root_plot_1761646106867" style="width: 800px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1761646106867(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-957.350006109476,"fY1":-21.4985381730236,"fX2":-137.349993890524,"fY2":193.486830743085,"fXtoAbsPixelk":929.329992082566,"fXtoPixelk":929.329992082566,"fXtoPixel":0.970731692852043,"fYtoAbsPixelk":694.799995398521,"fYtoPixelk":694.799995398521,"fYtoPixel":-3.59094204360135,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":772,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":-957.350006109476,"fPixeltoXk":-957.350006109476,"fPixeltoX":1.03015076911929,"fAbsPixeltoYk":193.486830743085,"fPixeltoYk":-21.4985381730236,"fPixeltoY":-0.278478457145218,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-875.35,"fUymin":0,"fUxmax":-219.35,"fUymax":171.988292570061,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"data_plot","fTitle":"data_plot","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":20,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:2 ...

# %% [markdown]
# # Construction of the model for the Simulation

# %%
w.Import(BiasCategory) # <== Import the category inside the workspace

w.factory("S[100,50, 10000]")
w.factory("E[0.0, -1.5, 1.5]")
w.factory(f"D[{Dmu}, -0.8, 0.8]")

w.factory("SUM::model_base( Nup[30,10000] * pdf_pbarUp, Ndwn[30,1000] * pdf_pbarDn, nB[1, 200] * pdf_cosm)") # <<< Add pdf_cosm in the future
# A = (Ndwn - Nup)/(Ndwn + Nup)
w.factory(f"EDIT::model_MAGB(model_base, Nup=expr('0.5*S*(1-E)', S, E), Ndwn = expr('0.5*S*(1+E)', S, E))")

w.factory(f"Gaussian::Dconstr(D,{Dmu},{Dsigma})") # constrain on D, efficiency

w.factory("SIMCLONE::model_fit( model_MAGB, $SplitParam({S,E}, secondCategory ))") # Clone the Models

w.Print()
# Out:
# [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooCategory::secondCategory
#
# RooWorkspace(w) w contents
#
# variables
# ---------
# (D,E,E_-0.3g,E_-0.7g,E_-1.0g,E_-1.3g,E_-1.7g,E_-2.0g,E_0.0g,Ndwn,Nup,S,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,Z,biaskey,c_pbarDn_1,c_pbarDn_2,c_pbarUp_1,c_pbarUp_2,evtype,nB,secondCategory)
#
# p.d.f.s
# -------
# RooGaussian::Dconstr[ x=D mean=0.02 sigma=0.08 ] = 1
# RooHistPdf::hpdf_pbarDn_1[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarDn_2[ pdfObs=(Z) ] = 0.0121951
# RooHistPdf::hpdf_pbarUp_1[ pdfObs=(Z) ] = 0.844512
# RooHistPdf::hpdf_pbarUp_2[ pdfObs=(Z) ] = 0.844512
# RooAddPdf::model_MAGB[ model_MAGB_2 * pdf_pbarUp + model_MAGB_3 * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-0.3g[ model_MAGB_2_-0.3g * pdf_pbarUp + model_MAGB_3_-0.3g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-0.7g[ model_MAGB_2_-0.7g * pdf_pbarUp + model_MAGB_3_-0.7g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.0g[ model_MAGB_2_-1.0g * pdf_pbarUp + model_MAGB_3_-1.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.3g[ model_MAGB_2_-1.3g * pdf_pbarUp + model_MAGB_3_-1.3g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-1.7g[ model_MAGB_2_-1.7g * pdf_pbarUp + model_MAGB_3_-1.7g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_-2.0g[ model_MAGB_2_-2.0g * pdf_pbarUp + model_MAGB_3_-2.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_MAGB_0.0g[ model_MAGB_2_0.0g * pdf_pbarUp + model_MAGB_3_0.0g * pdf_pbarDn + nB * pdf_cosm ] = 1.14737/1
# RooAddPdf::model_base[ Nup * pdf_pbarUp + Ndwn * pdf_pbarDn + nB * pdf_cosm ] = 0.786559/1
# RooSimultaneous::model_fit[ indexCat=secondCategory -0.3g=model_MAGB_-0.3g -0.7g=model_MAGB_-0.7g -1.0g=model_MAGB_-1.0g -1.3g=model_MAGB_-1.3g -1.7g=model_MAGB_-1.7g -2.0g=model_MAGB_-2.0g 0.0g=model_MAGB_0.0g ] = 0.16391
# RooHistPdf::pdf_cosm[ pdfObs=(Z) ] = 1.8628
# RooAddPdf::pdf_pbarDn[ c_pbarDn_1 * hpdf_pbarDn_1 + [%] * hpdf_pbarDn_2 ] = 0.0121951/1
# RooAddPdf::pdf_pbarUp[ c_pbarUp_1 * hpdf_pbarUp_1 + [%] * hpdf_pbarUp_2 ] = 0.844512/1
#
# functions
# --------
# RooFormulaVar::model_MAGB_2[ actualVars=(S,E) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-0.3g[ actualVars=(S_-0.3g,E_-0.3g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-0.7g[ actualVars=(S_-0.7g,E_-0.7g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.0g[ actualVars=(S_-1.0g,E_-1.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.3g[ actualVars=(S_-1.3g,E_-1.3g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-1.7g[ actualVars=(S_-1.7g,E_-1.7g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_-2.0g[ actualVars=(S_-2.0g,E_-2.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_2_0.0g[ actualVars=(S_0.0g,E_0.0g) formula="0.5*S*(1-E)" ] = 50
# RooFormulaVar::model_MAGB_3[ actualVars=(S,E) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-0.3g[ actualVars=(S_-0.3g,E_-0.3g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-0.7g[ actualVars=(S_-0.7g,E_-0.7g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.0g[ actualVars=(S_-1.0g,E_-1.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.3g[ actualVars=(S_-1.3g,E_-1.3g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-1.7g[ actualVars=(S_-1.7g,E_-1.7g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_-2.0g[ actualVars=(S_-2.0g,E_-2.0g) formula="0.5*S*(1+E)" ] = 50
# RooFormulaVar::model_MAGB_3_0.0g[ actualVars=(S_0.0g,E_0.0g) formula="0.5*S*(1+E)" ] = 50
#
# datasets
# --------
# RooDataHist::rdhbin_pbarUp1(Z)
# RooDataHist::rdhbin_pbarUp2(Z)
# RooDataHist::rdhbin_pbarDn1(Z)
# RooDataHist::rdhbin_pbarDn2(Z)
#
# embedded datasets (in pdfs and functions)
# -----------------------------------------
# RooDataHist::rhcosm(Z)

# %%
g = ROOT.TGraph("simulation.csv","%lg,%lg")
# create RooRealVar
w.factory('c[0,-30,30]')
#create RooRealVar
w.factory('scale[0.1]')
#w['scale'].setConstant(True)
w["nB"].setVal(nB_val)

# === Definisci la curva S come TF1 + RooTFnBinding ===
def Scurve_fn(x, p):
    # 10 is an offset of the simulation
    offset = -10
    bias = x[0]
    c = p[0]
    scale = p[1]
    D = p[2]
    return (g.Eval((x[0] - c + offset) * scale) - D)/(1 - g.Eval((x[0] - c + offset) * scale)*D)

# === Print values of the Scurve for a collection of biases ===
print("-"*8)
for key,value in BIAS.items():
    val = Scurve_fn([value], [w["c"].getVal(), w['scale'].getVal(), w['D'].getVal()])
    print(f"{key}| {value} | {w['c'].getVal()} | {val}")
print("-"*8)

# === create the RooFit model from the Scurve ===
Scurve_TF1 = ROOT.TF1("Scurve",Scurve_fn, -50, 50, 3) # not possible to put in workspace

cust = ROOT.RooCustomizer(w.pdf('model_fit'), "scurve");

vcat={}
nasy={}
for bkt, bias_val in BIAS.items():
    v = ROOT.RooRealVar(f"vat_{bkt}", "", bias_val)
    # Creo una funzione parametrica RooTFnBinding che connette il TF1 alla variabile 'v'
    # Il TF1 ha 3 parametri: c, scale, D — sono usati qui come [c, scale, D]
    asy = ROOT.RooTFnBinding(f"nasy_{bkt}", "", Scurve_TF1, v, [w['c'], w['scale'], w['D']])
    # Salvo queste entità nei dizionari
    vcat[bkt] = v
    nasy[bkt] = asy

    # Ottengo la variabile originale 'E_{bkt}' nel modello
    A = w.var(f'E_{bkt}')

    # Sostituisco E_{bkt} con la funzione curva S corrispondente
    cust.replaceArg(A, asy)

scurve_all = cust.build(True)

scurvemap = {}
for bkt, bias_val in BIAS.items():
    scurvemap.update({bkt : scurve_all.getPdf(bkt) })
    S = w.var(f'S_{bkt}')

    val = ttable.get(bkt)
    err = np.sqrt(val)
    
    #S.setMin(val-10*err)
    #S.setMax(val+10*err)
    S.setVal(val)
    print(f"setting  {val}  [{val - 10*err}  {val + 10*err}]")
    #S.setError(err)

scurve_fit = ROOT.RooSimultaneous("scurve_fit","scurve_fit", scurvemap, BiasCategory)
# Out:
# --------
# -2.0g| -20 | 0.0 | -0.990390272602471
# -1.7g| -16 | 0.0 | -0.990390272602471
# -1.3g| -13 | 0.0 | -0.990390272602471
# -1.0g| -10 | 0.0 | -0.9717612997021784
# -0.7g| -6 | 0.0 | -0.6126482213438736
# -0.3g| -3 | 0.0 | -0.3180914512922466
# 0.0g| 0 | 0.0 | -0.02
# --------
# setting  153.0  [29.3068312314702  276.6931687685298]
# setting  137.0  [19.953000892803743  254.04699910719626]
# setting  173.0  [41.47053562034094  304.5294643796591]
# setting  176.0  [43.33500838578402  308.664991614216]
# setting  158.0  [32.30194910023465  283.69805089976535]
# setting  157.0  [31.700359138583323  282.29964086141666]
# setting  164.0  [35.93751525134303  292.06248474865697]
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-0.3g will be replaced by nasy_-0.3g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-0.7g will be replaced by nasy_-0.7g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.0g will be replaced by nasy_-1.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.3g will be replaced by nasy_-1.3g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-1.7g will be replaced by nasy_-1.7g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_-2.0g will be replaced by nasy_-2.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit): tree node E_0.0g will be replaced by nasy_0.0g
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooSimultaneous::model_fit cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-0.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-0.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-0.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-0.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-0.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-0.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.3g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-1.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-1.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-1.7g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_-2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_-2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_-2.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooAddPdf::model_MAGB_0.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_2_0.0g cloned: depends on a replaced parameter
# [#1] INFO:ObjectHandling -- RooCustomizer::build(model_fit) Branch node RooFormulaVar::model_MAGB_3_0.0g cloned: depends on a replaced parameter

# %%
w['D'].setConstant(True)

w['c'].setError(20)
result = scurve_fit.fitTo(dataset,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 #ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(2),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.Minos(w['c']))

c     = w.var('c')
scale = w.var('scale')
D = w.var('D')

# === 8. Risultati
print("\n=== RISULTATI DEL FIT ===")
print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
print(f"fit status: {result.status()}")
# Out:
# === RISULTATI DEL FIT ===
# c     = -1.0451 ± 0.0313; [-0.01276648406244428,+0.026732074211497783]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 4500 convergence for edm < 1 strategy 2
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 4569.55935369248527
# Edm   = 0.000503979916072593861
# Nfcn  = 992
# S_-0.3g	  = 155.951	 +/-  12.524	(limited)
# S_-0.7g	  = 157.017	 +/-  12.5724	(limited)
# S_-1.0g	  = 175.009	 +/-  13.2669	(limited)
# S_-1.3g	  = 171.861	 +/-  13.1453	(limited)
# S_-1.7g	  = 136.029	 +/-  11.7012	(limited)
# S_-2.0g	  = 152.435	 +/-  12.3738	(limited)
# S_0.0g	  = 163.542	 +/-  12.8103	(limited)
# c	  = -10.4508	 +/-  0.0486028	(limited)
# nB	  = 1	 +/-  0.560736	(limited)
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS LOWER error for parameter #7 : c using max-calls 4500, tolerance 1
# ******************************************************************************************************
# Minuit2Minimizer::GetMinosError - Run MINOS UPPER error for parameter #7 : c using max-calls 4500, tolerance 1
# Minos: Lower error for parameter c  :  -0.127665
# Minos: Upper error for parameter c  :  0.267321
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =       5155.311371 Edm =       909.8892123 NCalls =     37
# Warning in <Minuit2>: MnPosDef Matrix forced pos-def by adding to diagonal 1.4657
# Info in <Minuit2>: MnSeedGenerator run Hesse - Initial seeding state:
#   Minimum value : 5155.311371
#   Edm           : 48210.98935
#   Internal parameters:	[     -1.363022033     -1.362049858     -1.345255787      -1.34796827     -1.383507007     -1.366956419     -1.356307984                0     -1.221747644]
#   Internal gradient  :	[      62.25868445      80.69799875      302.5169321      239.7032022      121.7584887      29.12791265      47.14243208      2584.834196     -428.7691315]
#   Internal covariance matrix:
# [[   0.0010097845    0.001151281   0.0034582987   0.0016199995  0.00085075844  0.00032821312  0.00064627826  -0.0030940324   -0.044970455]
#  [    0.001151281    0.001640268   0.0045282028   0.0021211334   0.0011139338  0.00042974323  0.00084620307  -0.0040515943   -0.058881707]
#  [   0.0034582987   0.0045282028    0.013753789   0.0063714393   0.0033460231   0.0012908584   0.0025418702   -0.012176514    -0.17686828]
#  [   0.0016199995   0.0021211334   0.0063714393   0.0031236572   0.0015674718  0.00060471314   0.0011907197  -0.0056994395   -0.082855387]
#  [  0.00085075844   0.0011139338   0.0033460231   0.0015674718  0.00096521447  0.00031757097  0.00062531798   -0.002993116    -0.04351231]
#  [  0.00032821312  0.00042974323   0.0012908584  0.00060471314  0.00031757097  0.00024881976  0.00024124071  -0.0011547108   -0.016786564]
#  [  0.00064627826  0.00084620307   0.0025418702   0.0011907197  0.00062531798  0.00024124071  0.00060061455  -0.0022740595   -0.033053841]
#  [  -0.0030940324  -0.0040515943   -0.012176514  -0.0056994395   -0.002993116  -0.0011547108  -0.0022740595      0.0109256     0.15821387]
#  [   -0.044970455   -0.058881707    -0.17686828   -0.082855387    -0.04351231   -0.016786564   -0.033053841     0.15821387      2.3000282]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 4500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       5155.311371 Edm =       48210.98935 NCalls =    110
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =         5051.2293 Edm =       13674.63608 NCalls =    149
# Info in <Minuit2>: VariableMetricBuilder    2 - FCN =       5020.093873 Edm =       247.4258593 NCalls =    176
# Info in <Minuit2>: VariableMetricBuilder    3 - FCN =       4973.832969 Edm =       28.06646959 NCalls =    201
# Info in <Minuit2>: VariableMetricBuilder    4 - FCN =       4901.798251 Edm =      0.8693718228 NCalls =    237
# Info in <Minuit2>: VariableMetricBuilder    5 - FCN =       4895.181199 Edm =       5.170885665 NCalls =    273
# Info in <Minuit2>: VariableMetricBuilder    6 - FCN =        4885.31507 Edm =       3.288203528 NCalls =    307
# Info in <Minuit2>: VariableMetricBuilder    7 - FCN =       4866.010875 Edm =       14.18870595 NCalls =    338
# Info in <Minuit2>: VariableMetricBuilder    8 - FCN =       4773.182555 Edm =       34.33169792 NCalls =    371
# Info in <Minuit2>: VariableMetricBuilder    9 - FCN =       4767.077542 Edm =       11.54964213 NCalls =    393
# Info in <Minuit2>: VariableMetricBuilder   10 - FCN =       4762.137404 Edm =       22.21632252 NCalls =    415
# Info in <Minuit2>: VariableMetricBuilder   11 - FCN =       4715.680681 Edm =       9.050557759 NCalls =    450
# Info in <Minuit2>: VariableMetricBuilder   12 - FCN =       4687.096165 Edm =       10.34807906 NCalls =    485
# Info in <Minuit2>: VariableMetricBuilder   13 - FCN =       4678.212503 Edm =       4.393461315 NCalls =    509
# Info in <Minuit2>: VariableMetricBuilder   14 - FCN =       4668.352149 Edm =       3.006563444 NCalls =    534
# Info in <Minuit2>: VariableMetricBuilder   15 - FCN =       4659.051193 Edm =       4.737840042 NCalls =    565
# Info in <Minuit2>: VariableMetricBuilder   16 - FCN =       4654.236499 Edm =       8.557957815 NCalls =    592
# Info in <Minuit2>: VariableMetricBuilder   17 - FCN =       4645.743498 Edm =       5.579655952 NCalls =    623
# Info in <Minuit2>: VariableMetricBuilder   18 - FCN =       4641.109159 Edm =       5.671675447 NCalls =    645
# Info in <Minuit2>: VariableMetricBuilder   19 - FCN =       4613.970493 Edm =        16.6585345 NCalls =    672
# Info in <Minuit2>: VariableMetricBuilder   20 - FCN =       4603.872701 Edm =       24.01432616 NCalls =    694
# Info in <Minuit2>: VariableMetricBuilder   21 - FCN =       4585.084694 Edm =       11.71494049 NCalls =    714
# Info in <Minuit2>: VariableMetricBuilder   22 - FCN =       4575.294841 Edm =       3.984817433 NCalls =    739
# Info in <Minuit2>: VariableMetricBuilder   23 - FCN =       4572.091759 Edm =       1.542118562 NCalls =    761
# Info in <Minuit2>: VariableMetricBuilder   24 - FCN =       4570.265578 Edm =      0.5699115672 NCalls =    783
# Info in <Minuit2>: VariableMetricBuilder   25 - FCN =       4569.670659 Edm =     0.09035646866 NCalls =    813
#  [  8.6198316e-08 -6.5242319e-08  0.00028660864  1.1611843e-07  4.9293516e-08 -1.0058614e-07 -7.7504802e-08 -2.0506221e-06]
#  [  -4.521188e-07  4.0334897e-07  1.1611843e-07  0.00028798017 -2.2040531e-07  5.6166943e-07  4.3582214e-07 -2.0551929e-06]
#  [ -1.7146293e-07  1.6450954e-07  4.9293516e-08 -2.2040531e-07  0.00032263849  2.2011634e-07  1.7099334e-07 -2.2717264e-06]
#  [  4.2527847e-07 -3.6181902e-07 -1.0058614e-07  5.6166943e-07  2.2011634e-07    0.000303069 -4.0110205e-07 -1.5273748e-06]
#  [   3.300297e-07 -2.7850819e-07 -7.7504802e-08  4.3582214e-07  1.7099334e-07 -4.0110205e-07  0.00029357202 -1.1630979e-06]
#  [ -2.0241084e-06 -2.2502586e-06 -2.0506221e-06 -2.0551929e-06 -2.2717264e-06 -1.5273748e-06 -1.1630979e-06    0.023104187]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.0005 with call limit = 4500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =       4570.060708 Edm =   0.0001653733101 NCalls =     19
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =       4570.060542 Edm =   9.449251158e-11 NCalls =     36
# Info in <Minuit2>: MnFunctionCross Result after Migrad (3rd): FCN =       4570.060542 Edm =   9.449251158e-11 NCalls =     36
#   Pos |    Name    |  type   |      Value       |    Error +/-
#     0 |    S_-0.3g | limited |      156.0837871 |   12.5245579
#     1 |    S_-0.7g | limited |       156.972436 |  12.56476414
#     2 |    S_-1.0g | limited |      174.9899747 |  13.26549201
#     3 |    S_-1.3g | limited |      172.0008614 |  13.13923058
#     4 |    S_-1.7g | limited |      136.0699738 |  11.70259661
#     5 |    S_-2.0g | limited |      152.3005175 |  12.35523994
#     6 |     S_0.0g | limited |      163.4525402 |  12.79853332
#     7 |          c |  fixed  |     -10.18310005 | 0.3127990778
#     8 |         nB | limited |                1 | 0.5737316911 (at lower limit)
# Info in <Minuit2>: MnMinos end of Minos scan for up interval for parameter c

# %%
scurve_fit.getParameters(dataset).Print('v')
# Out:
#   1) 0x5b0468267c30 RooRealVar::          D = 0.02 C  L(-0.8 - 0.8)  "D"
#   2) 0x5b04685b9620 RooRealVar::    S_-0.3g = 155.951 +/- 12.524  L(50 - 10000)  "S (-0.3g)"
#   3) 0x5b04685d1b90 RooRealVar::    S_-0.7g = 157.017 +/- 12.5724  L(50 - 10000)  "S (-0.7g)"
#   4) 0x5b04687e7fc0 RooRealVar::    S_-1.0g = 175.009 +/- 13.2669  L(50 - 10000)  "S (-1.0g)"
#   5) 0x5b04687f1ae0 RooRealVar::    S_-1.3g = 171.861 +/- 13.1453  L(50 - 10000)  "S (-1.3g)"
#   6) 0x5b04687fb6a0 RooRealVar::    S_-1.7g = 136.029 +/- 11.7012  L(50 - 10000)  "S (-1.7g)"
#   7) 0x5b0468805260 RooRealVar::    S_-2.0g = 152.435 +/- 12.3738  L(50 - 10000)  "S (-2.0g)"
#   8) 0x5b046880ee10 RooRealVar::     S_0.0g = 163.542 +/- 12.8103  L(50 - 10000)  "S (0.0g)"
#   9) 0x5b04685f3ca0 RooRealVar::          c = -10.4508 +/- (-0.127665,0.267321)  L(-30 - 30)  "c"
#  10) 0x5b04648b00b0 RooRealVar:: c_pbarDn_1 = 1 C  L(0.71251 - 1)  "c_pbarDn_1"
#  11) 0x5b04609c1e70 RooRealVar:: c_pbarUp_1 = 1 C  L(-0.0202152 - 1)  "c_pbarUp_1"
#  12) 0x5b0468476640 RooRealVar::         nB = 1 +/- 0.560747  L(1 - 200)  "nB"
#  13) 0x5b04685f4220 RooRealVar::      scale = 0.1 C  L(-INF - +INF)  "scale"
#  14) 0x5b0465ef76c0 RooRealVar::  vat_-0.3g = -3 C  L(-INF - +INF)  ""
#  15) 0x5b04619382d0 RooRealVar::  vat_-0.7g = -6 C  L(-INF - +INF)  ""
#  16) 0x5b0468c7ee30 RooRealVar::  vat_-1.0g = -10 C  L(-INF - +INF)  ""
#  17) 0x5b0468e32810 RooRealVar::  vat_-1.3g = -13 C  L(-INF - +INF)  ""
#  18) 0x5b0468f672b0 RooRealVar::  vat_-1.7g = -16 C  L(-INF - +INF)  ""
#  19) 0x5b04684faf70 RooRealVar::  vat_-2.0g = -20 C  L(-INF - +INF)  ""
#  20) 0x5b046861ea40 RooRealVar::   vat_0.0g = 0 C  L(-INF - +INF)  ""

# %% [markdown]
# # SIMULATION, nominal case (2023 analysis), D set as constant

# %%
Ngravity = []
dNgravity = []

D.setConstant(True)

for i in range(0, Ntoys):
    c.setVal(real_gravity) # reset the value for simulation
    w["nB"].setVal(nB_val)

    for bias, stat in weights.items(): # reset the stat parameters
        w[f"S_{bias}"].setVal(stat)
        #w[f"S_{bias}"].setMin(stat - np.sqrt(stat)*10)
        #w[f"S_{bias}"].setMin(stat + np.sqrt(stat)*10)
        print("tot_events:", stat, "set value:", w[f"S_{bias}"].getVal())
        
    
    pseudo_data = scurve_fit.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
    c.setVal(-10)
    result = scurve_fit.fitTo(pseudo_data,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 #ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(2),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.PrintLevel(-1),
                 #ROOT.RooFit.Verbose(False),   # disattiva log verboso
                 #ROOT.RooFit.Warnings(False),  # opzionale: disattiva warning
                 ROOT.RooFit.Minos(w['c']))
    # === 8. Risultati
    print("\n=== RISULTATI DEL FIT ===")
    print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
    print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
    print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
    print(f"fit status: {result.status()}")

    if result.status() < 1 and not np.isnan(c.getError()) and c.getError() > 0:
        Ngravity.append(c.getVal()*scale.getVal() - real_gravity*scale.getVal())
        dNgravity.append(c.getError()*scale.getVal())

# === Normalized Residuals ===
res_norm = (np.array((Ngravity)))/np.array(dNgravity)
# Out:
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0668 ± 0.0255; [-0.02573554174094705,+0.025226817084828185]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9978 ± 0.0293; [-0.029204591109184937,+0.02949820042575574]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0364 ± 0.0306; [-0.023419393695975926,+0.030399717484995117]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0031 ± 0.0306; [-0.030506931849865516,+0.030880487098021044]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0088 ± 0.0299; [-0.029814401567286233,+0.030053250306040898]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9960 ± 0.0323; [-0.032232711269490406,+0.03250301530798327]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0641 ± 0.0238; [-0.02373308451476946,+0.023143625121844185]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0101 ± 0.0292; [-0.029539298101286082,+0.02883259014014764]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9610 ± 0.0299; [-0.029808173256845386,+0.030805403633620616]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0127 ± 0.0292; [-0.028903611221445538,+0.029520947017192496]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9940 ± 0.0290; [-0.028976091164835172,+0.029010374433512405]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9922 ± 0.0306; [-0.030215415273126756,+0.03103175570302266]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9789 ± 0.0312; [-0.030732226801774072,+0.03315009712551192]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0274 ± 0.0299; [-0.026789717118628105,+0.029916054860960647]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9873 ± 0.0309; [-0.03060729102570342,+0.03132284981629643]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0265 ± 0.0298; [-0.03082675202891648,+0.03002057028747991]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0448 ± 0.0302; [-0.01966804660168888,+0.02968390905070445]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0063 ± 0.0297; [-0.029854556372252802,+0.02971623890628172]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0087 ± 0.0298; [-0.029731669619302643,+0.030247788879639848]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0033 ± 0.0304; [-0.030537977194926902,+0.030351569574721432]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9989 ± 0.0301; [-0.030062318744607703,+0.030227240867984256]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9894 ± 0.0295; [-0.02963276219097549,+0.029501485241973675]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0196 ± 0.0298; [-0.02914433500586727,+0.03000078394040689]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0309 ± 0.0297; [-0.030092646688726066,+0.029036997546852218]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0373 ± 0.0329; [-0.03141400105618814,+0.032622456407125806]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0492 ± 0.0218; [-0.020904380190904893,+0.03567481302450234]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0484 ± 0.0254; [-0.029412473697510235,+0.022728274912993472]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.

# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0020 ± 0.0287; [-0.02837186085928859,+0.029024575246261106]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0100 ± 0.0281; [-0.027808099865762295,+0.028317298761801713]
# scale = 0.1000 ± 0.0000
# D     = 0.0200 ± 0.0000
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# ...
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
from matplotlib import pyplot as plt

#print(res_norm)
plt.figure(9, figsize = (18,8))
plt.subplot(1,2,1)
plt.title("Extracted g and Error", fontsize = 20)
plt.grid()
plt.hist(Ngravity, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(Ngravity):.3f} std: {np.std(Ngravity):.3f}')
plt.legend(fontsize = 15, loc = "upper right")
plt.subplot(1,2,2)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(res_norm, bins = 30, histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(res_norm):.3f} std: {np.std(res_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")

# %% [markdown]
# # Fit with D

# %%
Ngravity = []
dNgravity = []
ND = []
dND = []

D.setConstant(False)

for i in range(0, Ntoys):
    c.setVal(real_gravity) # reset the value for simulation
    w["nB"].setVal(nB_val)
    D.setVal(Dmu + np.random.normal(loc = 0, scale = Dsigma))  # D detector asymmetry, add a "manual smearing, because the simulation does not account for a generation of D"
    
    for bias, stat in weights.items(): # reset the stat parameters
        #w[f"S_{bias}"].setMin(stat - np.sqrt(stat)*10)
        #w[f"S_{bias}"].setMin(stat + np.sqrt(stat)*10)
        w[f"S_{bias}"].setVal(stat)
        print("tot_events:", stat, "set value:", w[f"S_{bias}"].getVal())

    
    pseudo_data = scurve_fit.generate(ROOT.RooArgSet(Z, BiasCategory), ROOT.RooFit.Extended())
    c.setVal(-10)
    result = scurve_fit.fitTo(pseudo_data,
                 ROOT.RooFit.Minimizer("Minuit2","minimize"),
                 ROOT.RooFit.ExternalConstraints(w['Dconstr']),
                 ROOT.RooFit.Strategy(2),
                 ROOT.RooFit.Save(),
                 ROOT.RooFit.PrintLevel(-1),
                 ROOT.RooFit.Verbose(False),   # disattiva log verboso
                 ROOT.RooFit.Warnings(False),  # opzionale: disattiva warning
                 ROOT.RooFit.Minos(w['c']))
    # === 8. Risultati
    print("\n=== RISULTATI DEL FIT ===")
    print(f"c     = {c.getVal()*scale.getVal():.4f} ± {c.getError()*scale.getVal():.4f}; [{c.getErrorLo()*scale.getVal()},+{c.getErrorHi()*scale.getVal()}]")
    print(f"scale = {scale.getVal():.4f} ± {scale.getError():.4f}")
    print(f"D     = {D.getVal():.4f} ± {D.getError():.4f}")
    print(f"fit status: {result.status()}")

    if result.status() < 1 and not np.isnan(c.getError()) and c.getError() > 0:
        Ngravity.append(c.getVal()*scale.getVal() - real_gravity*scale.getVal())
        dNgravity.append(c.getError()*scale.getVal())
        ND.append(D.getVal() - Dmu)
        dND.append(D.getError())

# === Normalized Residuals ===
res_norm = (np.array((Ngravity)))/np.array(dNgravity)
Dres_norm = (np.array((ND)))/np.array(dND)
# Out:
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9550 ± 0.0450; [-0.05097799273169182,+0.03611847614418359]
# scale = 0.1000 ± 0.0000
# D     = 0.0669 ± 0.0629
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9979 ± 0.0550; [-0.058649611126339596,+0.0476656811940206]
# scale = 0.1000 ± 0.0000
# D     = 0.1002 ± 0.0671
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0510 ± 0.0286; [-0.034777948678647426,+0.03943114170687187]
# scale = 0.1000 ± 0.0000
# D     = -0.0096 ± 0.0492
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0470 ± 0.0369; [-0.042804175828538356,+0.03788884598500649]
# scale = 0.1000 ± 0.0000
# D     = -0.0125 ± 0.0546
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0018 ± 0.0519; [-0.049536253711148975,+0.050095698833299854]
# scale = 0.1000 ± 0.0000
# D     = 0.0398 ± 0.0654
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0258 ± 0.0481; [-0.042072723198731656,+0.048833995855944584]
# scale = 0.1000 ± 0.0000
# D     = 0.0203 ± 0.0629
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9898 ± 0.0487; [-0.04683537934771456,+0.044611445344891656]
# scale = 0.1000 ± 0.0000
# D     = 0.0643 ± 0.0628
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0399 ± 0.0521; [-0.040569371538325544,+0.053345281993734894]
# scale = 0.1000 ± 0.0000
# D     = 0.0627 ± 0.0660
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0729 ± 0.0432; [-0.04369636919020408,+0.04058137984835779]
# scale = 0.1000 ± 0.0000
# D     = 0.0057 ± 0.0597
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0451 ± 0.0485; [-0.02778087663992502,+0.04069847084738601]
# scale = 0.1000 ± 0.0000
# D     = -0.0347 ± 0.0633
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9550 ± 0.0486; [-0.04502817546268045,+0.024639615734463702]
# scale = 0.1000 ± 0.0000
# D     = 0.0548 ± 0.0630
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0125 ± 0.0578; [-0.05185979610802202,+0.05638515987883487]
# scale = 0.1000 ± 0.0000
# D     = -0.0632 ± 0.0679
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0455 ± 0.0334; [-0.04543569926863439,+0.03342880565782219]
# scale = 0.1000 ± 0.0000
# D     = -0.0542 ± 0.0514
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9702 ± 0.0540; [-0.053375914958319705,+0.05578308619255125]
# scale = 0.1000 ± 0.0000
# D     = 0.0109 ± 0.0663
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9781 ± 0.0544; [-0.05183438291199069,+0.04612914159954471]
# scale = 0.1000 ± 0.0000
# D     = 0.0285 ± 0.0665
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0205 ± 0.0491; [-0.04028027995566405,+0.04963471472395056]
# scale = 0.1000 ± 0.0000
# D     = 0.1108 ± 0.0657
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0376 ± 0.0558; [-0.0455144484035424,+0.05594098876113879]
# scale = 0.1000 ± 0.0000
# D     = -0.0097 ± 0.0677
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0310 ± 0.0509; [-0.03781067233714417,+0.05105327683684148]
# scale = 0.1000 ± 0.0000
# D     = -0.0298 ± 0.0642
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9974 ± 0.0574; [-0.0539804742746621,+0.06449833781658428]
# scale = 0.1000 ± 0.0000
# D     = -0.0113 ± 0.0693
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9840 ± 0.0488; [-0.04715462848249898,+0.043705570229529714]
# scale = 0.1000 ± 0.0000
# D     = 0.0166 ± 0.0629
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9672 ± 0.0493; [-0.048655263258905034,+0.03708582919079897]
# scale = 0.1000 ± 0.0000
# D     = -0.0401 ± 0.0637
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9723 ± 0.0531; [-0.05378848919119392,+0.06212589454519185]
# scale = 0.1000 ± 0.0000
# D     = -0.0711 ± 0.0664
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9870 ± 0.0503; [-0.049472466734383914,+0.04688391258578647]
# scale = 0.1000 ± 0.0000
# D     = 0.0003 ± 0.0639
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0154 ± 0.0480; [-0.04006012839609159,+0.0482402324916214]
# scale = 0.1000 ± 0.0000
# D     = -0.0715 ± 0.0622
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9116 ± 0.0408; [-0.03766573843194683,+0.04353072045170629]
# scale = 0.1000 ± 0.0000
# D     = 0.0596 ± 0.0595
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0439 ± 0.0464; [-0.02389438886823968,+0.04569613274313189]
# scale = 0.1000 ± 0.0000
# D     = -0.0187 ± 0.0617
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0453 ± 0.0257; [-0.020994368782674622,+0.03350630994381879]
# scale = 0.1000 ± 0.0000
# D     = -0.0401 ± 0.0462
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0230 ± 0.0489; [-0.04348067446829871,+0.049151308013447546]
# scale = 0.1000 ± 0.0000
# D     = 0.0494 ± 0.0636
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0060 ± 0.0523; [-0.046013098923451234,+0.05240696719800103]
# scale = 0.1000 ± 0.0000
# D     = -0.0448 ± 0.0651
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0406 ± 0.0508; [-0.03228027486218945,+0.05037325326026684]
# scale = 0.1000 ± 0.0000
# D     = -0.0026 ± 0.0638
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0713 ± 0.0384; [-0.039986833635276414,+0.03432706394491602]
# scale = 0.1000 ± 0.0000
# D     = -0.1368 ± 0.0571
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9433 ± 0.0372; [-0.049366905287419,+0.039837979312993085]
# scale = 0.1000 ± 0.0000
# D     = 0.0413 ± 0.0556
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0744 ± 0.0382; [-0.03907156864474498,+0.03789765516814952]
# scale = 0.1000 ± 0.0000
# D     = -0.0466 ± 0.0562
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0108 ± 0.0578; [-0.04287096975383,+0.060917255561845976]
# scale = 0.1000 ± 0.0000
# D     = -0.0444 ± 0.0690
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0071 ± 0.0544; [-0.05272698111315935,+0.0539673763183725]
# scale = 0.1000 ± 0.0000
# D     = -0.0294 ± 0.0663
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9706 ± 0.0542; [-0.05137132128762215,+0.042349803502422484]
# scale = 0.1000 ± 0.0000
# D     = 0.0894 ± 0.0669
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0147 ± 0.0453; [-0.0400308195528431,+0.04572555824150747]
# scale = 0.1000 ± 0.0000
# D     = 0.0322 ± 0.0613
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0230 ± 0.0459; [-0.045930008410524,+0.045930008410524]
# scale = 0.1000 ± 0.0000
# D     = 0.0127 ± 0.0612
# fit status: -1
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9529 ± 0.0278; [-0.03762244580128704,+0.03932879366732555]
# scale = 0.1000 ± 0.0000
# D     = 0.0231 ± 0.0478
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0173 ± 0.0526; [-0.04717474111003534,+0.05314399066101826]
# scale = 0.1000 ± 0.0000
# D     = 0.0366 ± 0.0660
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9967 ± 0.0470; [-0.04763903413709125,+0.04860534825491477]
# scale = 0.1000 ± 0.0000
# D     = -0.0167 ± 0.0620
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9788 ± 0.0512; [-0.04852019483479683,+0.03458043321681316]
# scale = 0.1000 ± 0.0000
# D     = 0.0900 ± 0.0656
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0685 ± 0.0481; [-0.05333986346098744,+0.04729375061333309]
# scale = 0.1000 ± 0.0000
# D     = -0.0641 ± 0.0664
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9935 ± 0.0469; [-0.04716223913770667,+0.044582707176702076]
# scale = 0.1000 ± 0.0000
# D     = -0.0092 ± 0.0611
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0509 ± 0.0356; [-0.03652016213749925,+0.05703860854808151]
# scale = 0.1000 ± 0.0000
# D     = 0.0484 ± 0.0530
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9839 ± 0.0478; [-0.04718023449476571,+0.0463524245181621]
# scale = 0.1000 ± 0.0000
# D     = -0.0087 ± 0.0622
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0178 ± 0.0522; [-0.056275563370233816,+0.052971594412776185]
# scale = 0.1000 ± 0.0000
# D     = 0.0755 ± 0.0652
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9798 ± 0.0535; [-0.05052441979040209,+0.04009627469865567]
# scale = 0.1000 ± 0.0000
# D     = 0.0812 ± 0.0667
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0458 ± 0.0329; [-0.03319124935582618,+0.04523376913421986]
# scale = 0.1000 ± 0.0000
# D     = -0.0073 ± 0.0519
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0455 ± 0.0332; [-0.04132527089726277,+0.02398513548854747]
# scale = 0.1000 ± 0.0000
# D     = -0.1314 ± 0.0532
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9473 ± 0.0306; [-0.038421240959634465,+0.03245794572571295]
# scale = 0.1000 ± 0.0000
# D     = -0.0085 ± 0.0508
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9761 ± 0.0556; [-0.05403678418693612,+0.04936425571177375]
# scale = 0.1000 ± 0.0000
# D     = 0.0281 ± 0.0669
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9428 ± 0.0365; [-0.03228141412148782,+0.03849806245229921]
# scale = 0.1000 ± 0.0000
# D     = -0.0230 ± 0.0537
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0942 ± 0.0415; [-0.04102224375236941,+0.04096825862385405]
# scale = 0.1000 ± 0.0000
# D     = 0.0647 ± 0.0574
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9480 ± 0.0308; [-0.050772648801516655,+0.023694905979031244]
# scale = 0.1000 ± 0.0000
# D     = -0.0535 ± 0.0505
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0002 ± 0.0502; [-0.0500206558121255,+0.04805117272610806]
# scale = 0.1000 ± 0.0000
# D     = 0.0874 ± 0.0638
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9381 ± 0.0363; [-0.05348602982317222,+0.03829665613929414]
# scale = 0.1000 ± 0.0000
# D     = -0.0528 ± 0.0535
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0354 ± 0.0442; [-0.03270304490923156,+0.045367387031838624]
# scale = 0.1000 ± 0.0000
# D     = 0.0287 ± 0.0597
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0950 ± 0.0423; [-0.043196450034778566,+0.040784502476390094]
# scale = 0.1000 ± 0.0000
# D     = 0.0189 ± 0.0593
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0253 ± 0.0489; [-0.044515691892387965,+0.049415699206538016]
# scale = 0.1000 ± 0.0000
# D     = 0.0380 ± 0.0631
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9787 ± 0.0520; [-0.050365020002822405,+0.05952270180503077]
# scale = 0.1000 ± 0.0000
# D     = 0.0337 ± 0.0648
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0153 ± 0.0535; [-0.05340084486636815,+0.05414450921083456]
# scale = 0.1000 ± 0.0000
# D     = 0.0605 ± 0.0668
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9929 ± 0.0463; [-0.04515904223432345,+0.04368679580204086]
# scale = 0.1000 ± 0.0000
# D     = -0.0109 ± 0.0614
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0098 ± 0.0452; [-0.044079562962792196,+0.046806074269784295]
# scale = 0.1000 ± 0.0000
# D     = 0.0934 ± 0.0605
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0991 ± 0.0382; [-0.03809237417557979,+0.038006229137661385]
# scale = 0.1000 ± 0.0000
# D     = 0.1161 ± 0.0552
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0089 ± 0.0483; [-0.04528483766311072,+0.04834737078150496]
# scale = 0.1000 ± 0.0000
# D     = 0.0379 ± 0.0628
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0052 ± 0.0538; [-0.052703319432545526,+0.05263299228657067]
# scale = 0.1000 ± 0.0000
# D     = 0.0560 ± 0.0663
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0707 ± 0.0411; [-0.04273685260708728,+0.039783462667075]
# scale = 0.1000 ± 0.0000
# D     = -0.0584 ± 0.0587
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9117 ± 0.0377; [-0.0344914585264228,+0.04082655820649717]
# scale = 0.1000 ± 0.0000
# D     = 0.0756 ± 0.0570
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0270 ± 0.0484; [-0.049779995215697315,+0.05035761051342246]
# scale = 0.1000 ± 0.0000
# D     = 0.0675 ± 0.0633
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0321 ± 0.0484; [-0.03480853661070344,+0.048743923033367935]
# scale = 0.1000 ± 0.0000
# D     = -0.0104 ± 0.0629
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9232 ± 0.0382; [-0.03674155714058152,+0.041813861117805995]
# scale = 0.1000 ± 0.0000
# D     = 0.0520 ± 0.0578
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0032 ± 0.0526; [-0.0535185625396321,+0.05070784341502086]
# scale = 0.1000 ± 0.0000
# D     = 0.0442 ± 0.0659
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0870 ± 0.0534; [-0.05389924625927294,+0.055639938894228816]
# scale = 0.1000 ± 0.0000
# D     = 0.0347 ± 0.0679
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9587 ± 0.0555; [-0.05288216312905313,+0.020600489935912375]
# scale = 0.1000 ± 0.0000
# D     = 0.0736 ± 0.0675
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0219 ± 0.0531; [-0.05117018779327018,+0.05242530578301762]
# scale = 0.1000 ± 0.0000
# D     = 0.1016 ± 0.0664
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0609 ± 0.0416; [-0.04166645196090367,+0.07042450029358031]
# scale = 0.1000 ± 0.0000
# D     = 0.0770 ± 0.0570
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0107 ± 0.0470; [-0.044695597127627676,+0.04822483959264636]
# scale = 0.1000 ± 0.0000
# D     = -0.0255 ± 0.0615
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0135 ± 0.0494; [-0.047989378442900195,+0.05171249719162946]
# scale = 0.1000 ± 0.0000
# D     = 0.0425 ± 0.0640
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9123 ± 0.0485; [-0.053703601384455874,+0.05253483979723601]
# scale = 0.1000 ± 0.0000
# D     = -0.0172 ± 0.0655
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0184 ± 0.0493; [-0.04036051895489491,+0.049676310334490104]
# scale = 0.1000 ± 0.0000
# D     = 0.0357 ± 0.0635
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9358 ± 0.0402; [-0.03930712161957778,+0.041342571363303465]
# scale = 0.1000 ± 0.0000
# D     = -0.1203 ± 0.0553
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9529 ± 0.0391; [-0.05308774959199795,+0.057237238725811705]
# scale = 0.1000 ± 0.0000
# D     = -0.0089 ± 0.0557
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0109 ± 0.0532; [-0.0422824534399106,+0.05278092914141752]
# scale = 0.1000 ± 0.0000
# D     = -0.0217 ± 0.0664
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0038 ± 0.0476; [-0.04612509905159101,+0.04750286620903253]
# scale = 0.1000 ± 0.0000
# D     = -0.0016 ± 0.0621
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9890 ± 0.0482; [-0.04906490031577991,+0.04922817555168916]
# scale = 0.1000 ± 0.0000
# D     = -0.0440 ± 0.0622
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0469 ± 0.0272; [-0.03661408995345137,+0.04832768402580054]
# scale = 0.1000 ± 0.0000
# D     = 0.0106 ± 0.0476
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0134 ± 0.0501; [-0.04998489511054768,+0.05014729960063472]
# scale = 0.1000 ± 0.0000
# D     = 0.0133 ± 0.0639
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0021 ± 0.0455; [-0.04434726034597189,+0.046316013048494156]
# scale = 0.1000 ± 0.0000
# D     = 0.0255 ± 0.0608
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0180 ± 0.0530; [-0.03938488123793689,+0.0519430936860926]
# scale = 0.1000 ± 0.0000
# D     = -0.0593 ± 0.0659
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9539 ± 0.0358; [-0.041116101067609746,+0.03523400955793844]
# scale = 0.1000 ± 0.0000
# D     = 0.0119 ± 0.0554
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0338 ± 0.0468; [-0.04087478161153862,+0.049329824267464864]
# scale = 0.1000 ± 0.0000
# D     = 0.1103 ± 0.0624
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0443 ± 0.0542; [-0.033095211349194575,+0.0546382408513864]
# scale = 0.1000 ± 0.0000
# D     = 0.0053 ± 0.0672
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0301 ± 0.0523; [-0.06380919749518743,+0.05179104586318291]
# scale = 0.1000 ± 0.0000
# D     = -0.0012 ± 0.0651
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0050 ± 0.0490; [-0.04612671650145964,+0.04932860507062905]
# scale = 0.1000 ± 0.0000
# D     = -0.0147 ± 0.0630
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9921 ± 0.0486; [-0.0483150430631816,+0.04677872975512655]
# scale = 0.1000 ± 0.0000
# D     = 0.0323 ± 0.0624
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9375 ± 0.0425; [-0.06293522581326257,+0.046175696438282676]
# scale = 0.1000 ± 0.0000
# D     = -0.0343 ± 0.0594
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0190 ± 0.0501; [-0.0450448649592675,+0.04987824053893803]
# scale = 0.1000 ± 0.0000
# D     = -0.0217 ± 0.0633
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.8790 ± 0.0530; [-0.04939952045299925,+0.055823844117392954]
# scale = 0.1000 ± 0.0000
# D     = -0.0528 ± 0.0695
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0365 ± 0.0457; [-0.03801398737137292,+0.04627194954726787]
# scale = 0.1000 ± 0.0000
# D     = 0.0438 ± 0.0608
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9560 ± 0.0532; [-0.04935061413674277,+0.03682796016061105]
# scale = 0.1000 ± 0.0000
# D     = 0.0422 ± 0.0661
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.1244 ± 0.0413; [-0.04033331022917755,+0.04158505589995644]
# scale = 0.1000 ± 0.0000
# D     = 0.1586 ± 0.0585
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0451 ± 0.0558; [-0.04661686978330921,+0.05470639677221193]
# scale = 0.1000 ± 0.0000
# D     = 0.0625 ± 0.0676
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0142 ± 0.0457; [-0.04234992280457045,+0.046851237287232124]
# scale = 0.1000 ± 0.0000
# D     = 0.0311 ± 0.0602
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0455 ± 0.0362; [-0.046150840347300826,+0.03315794859295056]
# scale = 0.1000 ± 0.0000
# D     = -0.0618 ± 0.0547
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9549 ± 0.0515; [-0.04670840247250806,+0.025203575151177382]
# scale = 0.1000 ± 0.0000
# D     = 0.1044 ± 0.0640
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9712 ± 0.0506; [-0.049023609527742346,+0.036472436437945975]
# scale = 0.1000 ± 0.0000
# D     = 0.0324 ± 0.0642
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9547 ± 0.0322; [-0.028646529696776064,+0.029961732741579452]
# scale = 0.1000 ± 0.0000
# D     = 0.0937 ± 0.0532
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9768 ± 0.0497; [-0.04917853491537147,+0.046827499371233004]
# scale = 0.1000 ± 0.0000
# D     = -0.0357 ± 0.0635
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0004 ± 0.0476; [-0.04615918458077647,+0.047474363822292615]
# scale = 0.1000 ± 0.0000
# D     = -0.0146 ± 0.0615
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -0.9592 ± 0.0527; [-0.050669430229293905,+0.038461988374443]
# scale = 0.1000 ± 0.0000
# D     = 0.0525 ± 0.0653
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9814 ± 0.0571; [-0.05566904500949005,+0.08024343142078114]
# scale = 0.1000 ± 0.0000
# D     = -0.0030 ± 0.0678
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0604 ± 0.0397; [-0.04180528370043083,+0.048259013417057704]
# scale = 0.1000 ± 0.0000
# D     = 0.0145 ± 0.0566
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0086 ± 0.0568; [-0.08877124189216526,+0.05650080787781724]
# scale = 0.1000 ± 0.0000
# D     = 0.0858 ± 0.0681
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9333 ± 0.0382; [-0.03427661284010319,+0.039142261151829644]
# scale = 0.1000 ± 0.0000
# D     = 0.0308 ± 0.0568
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0321 ± 0.0566; [-0.05912378283130459,+0.05741558636619233]
# scale = 0.1000 ± 0.0000
# D     = 0.0485 ± 0.0684
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9946 ± 0.0511; [-0.048511367412341896,+0.04563395450848294]
# scale = 0.1000 ± 0.0000
# D     = 0.0995 ± 0.0646
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9877 ± 0.0462; [-0.0460655732951348,+0.04510919533816702]
# scale = 0.1000 ± 0.0000
# D     = -0.0207 ± 0.0613
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9908 ± 0.0499; [-0.048057555454139395,+0.0444400954566766]
# scale = 0.1000 ± 0.0000
# D     = 0.0625 ± 0.0641
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9895 ± 0.0484; [-0.04866570035586908,+0.05518618314125484]
# scale = 0.1000 ± 0.0000
# D     = -0.0781 ± 0.0624
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -0.9797 ± 0.0514; [-0.05057026350156821,+0.04618272961835913]
# scale = 0.1000 ± 0.0000
# D     = -0.0276 ± 0.0652
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
#
# === RISULTATI DEL FIT ===
# c     = -1.0458 ± 0.0377; [-0.047425397814140374,+0.02916953300767261]
# scale = 0.1000 ± 0.0000
# D     = -0.0944 ± 0.0557
# fit status: 0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# tot_events: 157 set value: 157.0
# === RISULTATI DEL FIT ===
# c     = -1.0031 ± 0.0507; [-0.04702053445962642,+0.051012134386256375]
# ...
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:Minimization -- p.d.f. provides expected number of events, including extended term in likelihood.
# [#1] INFO:Minimization --  Including the following constraint terms in minimization: (Dconstr)
# [#1] INFO:Minimization -- The global observables are not defined , normalize constraints with respect to the parameters (D,S_-0.3g,S_-0.7g,S_-1.0g,S_-1.3g,S_-1.7g,S_-2.0g,S_0.0g,c,c_pbarDn_1,c_pbarUp_1,nB,scale,vat_-0.3g,vat_-0.7g,vat_-1.0g,vat_-1.3g,vat_-1.7g,vat_-2.0g,vat_0.0g)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(scurve_fit) fixing normalization set for coefficient determination to observables in data
# [#1] INFO:Fitting -- RooAddition::defaultErrorLevel(nll_scurve_fit_hmaster) Summation contains a RooNLLVar, using its error level
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization

# %%
#print(res_norm)
plt.figure(10, figsize = (18,16))
plt.subplot(2,2,1)
plt.title("Extracted g and Error", fontsize = 20)
plt.grid()
plt.hist(Ngravity, bins = 30, range = (-.5, .5), histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(Ngravity):.3f} std: {np.std(Ngravity):.3f}')
plt.legend(fontsize = 15,  loc = "upper right")
plt.subplot(2,2,2)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(res_norm, bins = 30, range = (-5, 5), histtype = 'step', color = 'red', linestyle = '-', label = f'$\mu$ = {np.mean(res_norm):.3f} std: {np.std(res_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")

#plt.figure(11, figsize = (18,8))
plt.subplot(2,2,3)
plt.title("Extracted D and Error", fontsize = 20)
plt.grid()
plt.hist(ND, bins = 30, range = (-.5, .5), histtype = 'step', color = 'blue', linestyle = '-', label = f'$\mu$ = {np.mean(ND):.3f} std: {np.std(ND):.3f}')
plt.legend(fontsize = 15,  loc = "upper right")
plt.subplot(2,2,4)
plt.title("Normalized residuals", fontsize = 20)
plt.grid()
plt.hist(Dres_norm, bins = 30, range = (-5, 5), histtype = 'step', color = 'blue', linestyle = '-', label = f'$\mu$ = {np.mean(Dres_norm):.3f} std: {np.std(Dres_norm):.3f}')
plt.legend(fontsize = 15, loc = "upper right")
