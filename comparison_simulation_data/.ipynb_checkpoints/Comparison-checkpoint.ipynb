# %%
from matplotlib import pyplot as plt
import numpy as np
import os
import sys
sys.path.append(os.path.abspath(".."))
from scipy.optimize import curve_fit
from scipy import stats
import pandas as pd

# %% [markdown]
# # Load simulation outputs

# %%
files = os.listdir("../toy/output/")
#print(files)

outputs = ["toy/output/" + item for item in files if ".npz" in item]
print(outputs)
# Out:
# ['toy/output/tau_160s_theta_22_axial_10.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_20s_theta_22_axial_15.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_80s_theta_45_axial_5.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_40s_theta_45_axial_20.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_10.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_90_axial_5.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_160s_theta_90_axial_5.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_120s_theta_90_axial_5.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_80s_theta_180_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_160s_theta_180_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_160s_theta_90_axial_15.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_15.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_120s_theta_45_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_40s_theta_90_axial_15.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_40s_theta_180_axial_15.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_20.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_80s_theta_90_axial_10.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_40s_theta_45_axial_15.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_20s_theta_90_axial_5.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_40s_theta_90_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_20s_theta_180_axial_20.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_40s_theta_45_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_160s_theta_22_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_160s_theta_180_axial_5.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_40s_theta_180_axial_15.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_160s_theta_22_axial_15.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_160s_theta_90_axial_5.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_20s_theta_90_axial_20.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_80s_theta_22_axial_10.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_120s_theta_90_axial_20.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_80s_theta_22_axial_20.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_160s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_20s_theta_45_axial_20.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_120s_theta_90_axial_10.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_90_axial_10.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_160s_theta_45_axial_10.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_80s_theta_22_axial_10.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_20s_theta_90_axial_10.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_20.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_10.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_80s_theta_22_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_120s_theta_180_axial_15.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_160s_theta_22_axial_20.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_80s_theta_22_axial_10.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_80s_theta_90_axial_10.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_80s_theta_45_axial_5.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_40s_theta_180_axial_5.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_40s_theta_22_axial_15.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_40s_theta_180_axial_10.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_20s_theta_22_axial_10.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_40s_theta_45_axial_20.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_80s_theta_180_axial_20.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_20s_theta_90_axial_10.0mK_transv_5.0mK_p_2.npz', 'toy/output/tau_80s_theta_22_axial_5.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_160s_theta_90_axial_20.0mK_transv_20.0mK_p_2.npz', 'toy/output/tau_40s_theta_180_axial_10.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_120s_theta_45_axial_5.0mK_transv_15.0mK_p_2.npz', 'toy/output/tau_120s_theta_180_axial_15.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_20s_theta_45_axial_10.0mK_transv_10.0mK_p_2.npz', 'toy/output/tau_80s_theta_45_axia ...

# %%
from v1.Utils import ReadTheCsv,ReadTheSpill,append_to_dict

# %% [markdown]
# ## Z cuts

# %%
mirG_center = -415
mirA_center = -671
zmin = mirA_center - 200
zgap_min = mirA_center
zmax = mirG_center + 200
zgap_max = mirG_center
CutsType = "CutsType2"

class Zcuts:
    def __init__(self,a,b, cuts):
        self.mirG_center = a
        self.mirA_center = b
        self.zmin = b - 200
        self.zmax = a + 200
        self.zgap_min = b
        self.zgap_max = a
        self.CutsType = cuts

ZCUTS = Zcuts(-415,-671, CutsType)

# %% [markdown]
# # Define the analysis functions for data and simulation

# %%
def analysis_function(output):
    file = np.load(output)
    R_array           = file['position']
    Time_Annihilation = file['Time']
    Time_Annihilation = Time_Annihilation[np.isfinite(Time_Annihilation)]
    counts, edges = np.histogram(Time_Annihilation, bins = 50, range = (0,398.1), density = False)
    return Time_Annihilation, counts, edges

def analysis_data(file, Zcuts):
    # read the file
    dataset = ReadTheCsv(file, "-1", Zcuts.zmin, Zcuts.zmax, ZCUTS.CutsType)
    # Three Segment Ramp Down
    start_mbmf_rampdown0, stop_mbmf_rampdown0 = ReadTheSpill(file,"\"MBMF RampDown\"[0]")
    start_mbmf_rampdown1, stop_mbmf_rampdown1 = ReadTheSpill(file,"\"MBMF RampDown\"[1]")
    start_mbmf_rampdown2, stop_mbmf_rampdown2 = ReadTheSpill(file,"\"MBMF RampDown\"[2]")

    # print(f"{start_mbmf_rampdown0[0] - start_mbmf_rampdown0[0]}; {stop_mbmf_rampdown0[0] - start_mbmf_rampdown0[0]} ")
    # print(f"{start_mbmf_rampdown1[0] - start_mbmf_rampdown0[0]}; {stop_mbmf_rampdown1[0] - start_mbmf_rampdown1[0]} ")
    # print(f"{start_mbmf_rampdown2[0] - start_mbmf_rampdown0[0]}; {stop_mbmf_rampdown2[0] - start_mbmf_rampdown2[0]} ")
    mask      = ((dataset[CutsType] == 1) & 
                (dataset["Z"] > ZCUTS.zmin) & 
                (dataset["Z"] < ZCUTS.zmax))
    mask_time = ((dataset["run time"] > start_mbmf_rampdown0[0]) & 
                 (dataset["run time"] < start_mbmf_rampdown0[0] + 398.1))

    Event_Distribution = dataset["run time"][mask & mask_time].to_numpy() - start_mbmf_rampdown0[0]
    X_distribution = dataset["X"][mask & mask_time].to_numpy()
    Y_distribution = dataset["Y"][mask & mask_time].to_numpy()
    Z_distribution = dataset["Z"][mask & mask_time].to_numpy()

    counts, edges = np.histogram(Event_Distribution, bins = 50, range = (0,398.1), density = False)
    
    return Event_Distribution, counts, edges

# %% [markdown]
# # Main Loop for Kolmogorov Test and visualization

# %%
# !ls
# Out:
# Comparison.ipynb

# %%
list_dataset = ["v1/ag14100/ag14100.vertex.csv",
                "v1/ag14106/ag14106.vertex.csv",
                "v1/ag14268/ag14268.vertex.csv",
                "v1/ag14286/ag14286.vertex.csv",
                "v1/ag14308/ag14308.vertex.csv"]

best_for_dataset = []

for dataset in list_dataset:
    best_sim    = ""
    best_LR     = 1e6
    best_pvalue = 0.0

    # read the dataset
    Event_Distribution, counts_obs, edges_obs = analysis_data("../" + dataset, ZCUTS)
    
    for file in outputs:
        Time_Simulation, counts_sim, edges_sim =  analysis_function("../" + file)

        obs = Event_Distribution # time cut of the simulation :(
        sim = Time_Simulation
        
        stat, pvalue = stats.ks_2samp(obs, sim)
        print(f"KS statistic = {stat}")
        print(f"p-value      = {pvalue}")

        counts_sim = counts_sim * counts_obs.sum() / counts_sim.sum()
        
        LR, pvalue_lr = stats.power_divergence(counts_obs, counts_sim, lambda_="log-likelihood")
        print(f"LR statistic = {LR:.4}/{(len(counts_obs) - 1)}")
        print(f"p-value      = {pvalue_lr}")

        # if(pvalue > best_pvalue):
        #     best_sim = file
        #     best_pvalue = pvalue
        #     stringa = f"Best KS: {stat:.4}, pvalue = {pvalue:.4}" 

        if(LR < best_LR):
            best_sim = file
            best_pvalue = pvalue_lr
            best_LR = LR

            stringa = f"Best LR: {LR:.5}, pvalue = {pvalue_lr:.4}"
        print(f"best pvalue {best_pvalue}")
        print(f"best LR {best_LR}")
        print("-"*16)
    
    best_for_dataset.append((best_sim, stringa))
# Out:
# ../v1/ag14100/ag14100.vertex.csv
#    [26850.997-26862.199]=  11.202s |          "MBMF RampDown"[0]          |    1074       61       53       29      499      396     1214      852     1931         6
#
# ../v1/ag14100/ag14100.vertex.csv
#    [26983.913-26995.115]=  11.202s |          "MBMF RampDown"[1]          |    1148       51       53       31      545      420     1317     1208     2690       116
#
# ../v1/ag14100/ag14100.vertex.csv
#    [27116.943-27128.146]=  11.202s |          "MBMF RampDown"[2]          |    1104       56       55       42      545      447     1307     1285     2653       142
#
# 0.0; 11.202000000001135
# 132.91600000000108; 11.202000000001135
# 265.9459999999999; 11.203000000001339
# KS statistic = 0.4745730994152047
# p-value      = 5.840380765870828e-82
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 0.0
# best LR 1000000.0
# ----------------
# KS statistic = 0.6720107776327872
# p-value      = 2.3193733063215838e-195
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 0.0
# best LR 1000000.0
# ----------------
# KS statistic = 0.38379544662180387
# p-value      = 9.0279697396003e-58
# LR statistic = 814.4/49
# p-value      = 2.5971523125857203e-139
# best pvalue 2.5971523125857203e-139
# best LR 814.3837814015792
# ----------------
# KS statistic = 0.6649459600134717
# p-value      = 1.2510849821517715e-189
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.5971523125857203e-139
# best LR 814.3837814015792
# ----------------
# KS statistic = 0.5824797419557863
# p-value      = 9.750260873142417e-138
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.5971523125857203e-139
# best LR 814.3837814015792
# ----------------
# KS statistic = 0.5009588268471518
# p-value      = 5.214037548584306e-105
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.5971523125857203e-139
# best LR 814.3837814015792
# ----------------
# KS statistic = 0.35927510177091726
# p-value      = 2.0182961296800376e-49
# LR statistic = 810.1/49
# p-value      = 1.919963907385065e-138
# best pvalue 1.919963907385065e-138
# best LR 810.1377804547533
# ----------------
# KS statistic = 0.29567912714648814
# p-value      = 2.3748500927773146e-33
# LR statistic = 561.4/49
# p-value      = 3.6451309727416966e-88
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.5834770873672476
# p-value      = 1.29413848860166e-138
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6083992730718372
# p-value      = 1.2042239654033914e-145
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6334035087719299
# p-value      = 2.0207998474458894e-163
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6213386450113639
# p-value      = 2.716109921163411e-160
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6304011777695988
# p-value      = 2.7157053305635368e-160
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.5048199053898015
# p-value      = 1.6852208464505996e-104
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6603725809368782
# p-value      = 3.7489164053467945e-188
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6112351586035797
# p-value      = 1.1462772052272606e-152
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.4822851793055725
# p-value      = 5.151065518212488e-91
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6305669181589553
# p-value      = 1.1376778995448351e-169
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.3303335499241932
# p-value      = 1.8280051012390178e-44
# LR statistic = 707.3/49
# p-value      = 1.7030607381693147e-117
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# /home/adriano/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:8025: RuntimeWarning: divide by zero encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# KS statistic = 0.6209663104399946
# p-value      = 6.642906938694223e-164
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.7788024946555715
# p-value      = 2.3949471916293888e-276
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.594421384692014
# p-value      = 2.4060369498228476e-148
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6514705150888562
# p-value      = 1.4870762916506943e-168
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6186816967002725
# p-value      = 4.073694977440852e-156
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.31447183359241987
# p-value      = 1.916724815226141e-34
# LR statistic = 860.2/49
# p-value      = 1.0734813095590704e-148
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.7008037155971625
# p-value      = 2.2595479687474233e-214
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6536470917813496
# p-value      = 4.295561483599594e-171
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.3955188358493132
# p-value      = 2.1587829120801475e-60
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.5706103169079022
# p-value      = 4.6523094755623887e-138
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.6062785625981025
# p-value      = 8.177448038394672e-146
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0.645381409324416
# p-value      = 4.191848482892039e-173
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6451309727416966e-88
# best LR 561.4150861211647
# ----------------
# KS statistic = 0
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6249412119591672
# p-value      = 1.1340783894050346e-156
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5266702511101818
# p-value      = 1.3773519038891262e-110
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.56068148711128
# p-value      = 1.3305013323138097e-122
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5040759352317141
# p-value      = 7.180197272192213e-107
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.3215147523158313
# p-value      = 3.055431280497387e-39
# LR statistic = 654.5/49
# p-value      = 7.981001772946679e-107
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6359697739995277
# p-value      = 7.887160935156201e-162
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.4055109525225493
# p-value      = 2.5296124976957695e-62
# LR statistic = 908.6/49
# p-value      = 1.1600031097654834e-158
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5143968104314175
# p-value      = 4.408319363406779e-109
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6074895065668582
# p-value      = 5.780898403365734e-152
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.3857475979440599
# p-value      = 1.7646764282650986e-60
# LR statistic = 959.9/49
# p-value      = 3.026086686260161e-169
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6256101508383505
# p-value      = 2.2896917821611484e-153
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5742817187897279
# p-value      = 1.2059407551838167e-135
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.28870816868067883
# p-value      = 4.729553163500285e-33
# LR statistic = 567.3/49
# p-value      = 2.411536955822535e-89
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.80042231959035
# p-value      = 2.559807787056285e-295
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5515477395411605
# p-value      = 1.7965985146289941e-118
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6671029906372148
# p-value      = 6.235080121153985e-192
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.7461550742376669
# p-value      = 1.0317218563101132e-249
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6608799485625058
# p-value      = 4.3661106510856237e-187
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.3505397648810596
# p-value      = 3.498015096518493e-50
# LR statistic = 799.9/49
# p-value      = 2.346024741955678e-136
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.7105856256598223
# p-value      = 3.572090186981499e-223
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.363722524702561
# p-value      = 2.9852003304897234e-51
# LR statistic = 826.2/49
# p-value      = 9.824553890720635e-142
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6374399605299436
# p-value      = 4.913300052604975e-159
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6440048011835475
# p-value      = 7.749429996509058e-166
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.606109391124871
# p-value      = 1.1105280737531785e-146
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.3650365328255203
# p-value      = 1.6541747826333808e-51
# LR statistic = 746.3/49
# p-value      = 2.067959167703004e-125
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5776210285163079
# p-value      = 7.110915370699341e-134
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.5528703765312988
# p-value      = 4.7843321391614656e-116
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6224409032230758
# p-value      = 3.421919282418916e-153
# LR statistic = nan/49
# p-value      = nan
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.587754677322012
# p-value      = 1.5783811785471697e-136
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6211847967427683
# p-value      = 5.8313433874487026e-152
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.7398419985053912
# p-value      = 1.458900715801722e-244
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6697328907855223
# p-value      = 9.856016024780029e-197
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.3707749921596842
# p-value      = 1.2990137431282166e-55
# LR statistic = 834.9/49
# p-value      = 1.615242849291226e-143
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6218224723882474
# p-value      = 8.193528323950614e-160
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6744578533167653
# p-value      = 4.443363844954074e-183
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.4023276011811707
# p-value      = 2.7517978916261948e-64
# LR statistic = 925.9/49
# p-value      = 3.161218952724379e-162
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6395644283121598
# p-value      = 1.6970012866363365e-166
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.35447851096590954
# p-value      = 1.3989126046243645e-44
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.6220667703012807
# p-value      = 2.888483205789533e-149
# /home/adriano/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:8025: RuntimeWarning: invalid value encountered in divide
#   terms = 2.0 * special.xlogy(f_obs, f_obs / f_exp)
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 3.6886380895034545e-67
# best LR 454.8304737456264
# ----------------
# KS statistic = 0.22974039186409914
# p-value      = 1.304941992357957e-19
# LR statistic = 426.1/49
# p-value      = 1.4029969594416777e-61
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.46049615014724415
# p-value      = 6.831870558786896e-88
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.4336409011678059
# p-value      = 8.708329565504776e-78
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6224960394296779
# p-value      = 2.516579307713805e-159
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6340730002973536
# p-value      = 5.864065126084483e-170
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.28423131287935477
# p-value      = 9.591395774175762e-31
# LR statistic = 571.9/49
# p-value      = 2.9125796705004035e-90
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.3032154028482058
# p-value      = 3.708433936121325e-36
# LR statistic = 591.0/49
# p-value      = 4.6491496289474223e-94
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.667348307073416
# p-value      = 6.596564369322539e-190
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6130478449473257
# p-value      = 1.6760388568884394e-147
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6023391812865497
# p-value      = 1.124334535892193e-144
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6519572547002686
# p-value      = 1.7282263569615953e-178
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.3138401559454191
# p-value      = 1.3989443395129678e-39
# LR statistic = 629.2/49
# p-value      = 9.86971365515452e-102
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.3874332243241127
# p-value      = 2.101377814309602e-61
# LR statistic = 1.023e+03/49
# p-value      = 3.185167805081928e-182
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6454831107619796
# p-value      = 3.0737047889172773e-163
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6769616739617808
# p-value      = 2.767039870897968e-200
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6228335991493886
# p-value      = 7.274285945608699e-150
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.5884118842303498
# p-value      = 1.2305700328421673e-144
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.43556646365481927
# p-value      = 7.978138453867959e-78
# LR statistic = 1.265e+03/49
# p-value      = 9.139674033394822e-233
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6311455457594918
# p-value      = 1.1801017273611587e-171
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.7742158426368952
# p-value      = 3.9942139007790255e-272
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6078681552365763
# p-value      = 7.37146005832548e-151
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.734887673269956
# p-value      = 2.1382423155275565e-241
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.5417028364396785
# p-value      = 2.0340828717958297e-122
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.647610405323654
# p-value      = 4.517151692334305e-171
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6277317944721749
# p-value      = 2.1887244959103489e-156
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6248237415969831
# p-value      = 3.4650278477147974e-166
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6686324244345804
# p-value      = 3.2227751944766315e-179
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6433707218866839
# p-value      = 7.972506193579558e-173
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6261408274275133
# p-value      = 6.167438066767163e-158
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6405194238026026
# p-value      = 5.955423882029261e-166
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.4021784552996303
# p-value      = 1.802385300461449e-65
# LR statistic = 1.019e+03/49
# p-value      = 2.1063036801618876e-181
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.3827897059133996
# p-value      = 1.4095645493643803e-55
# LR statistic = 798.8/49
# p-value      = 4.057075726474026e-136
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.31778739908898207
# p-value      = 6.869240771875072e-37
# LR statistic = 695.6/49
# p-value      = 3.9941440892933894e-115
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.5652972764867144
# p-value      = 1.9616441612007134e-128
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.2542667347981605
# p-value      = 9.172849208980383e-26
# LR statistic = 466.7/49
# p-value      = 1.8157979246776823e-69
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.6109640410123441
# p-value      = 4.58002602681601e-148
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.4029969594416777e-61
# best LR 426.079096192509
# ----------------
# KS statistic = 0.2382203486061432
# p-value      = 2.1522682584876385e-21
# LR statistic = 405.9/49
# p-value      = 1.1085241965691653e-57
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.3362820196029981
# p-value      = 2.030047770915659e-41
# LR statistic = 734.6/49
# p-value      = 4.9914435640473333e-123
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.5676455631833206
# p-value      = 1.237477347238643e-125
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.6221013789085259
# p-value      = 1.650951509128198e-151
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.31687712871923396
# p-value      = 2.0246181001435974e-35
# LR statistic = 828.0/49
# p-value      = 4.1870814027417185e-142
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.635275536773808
# p-value      = 1.906548520869622e-159
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.5839177858675606
# p-value      = 2.214359360006863e-135
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.6592811617057626
# p-value      = 1.2341810683175226e-170
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.3888619620677037
# p-value      = 6.483134235156022e-58
# LR statistic = 831.0/49
# p-value      = 1.0144227471383826e-142
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0.5961340476940855
# p-value      = 4.591735136335928e-140
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 1.1085241965691653e-57
# best LR 405.85642225386937
# ----------------
# KS statistic = 0
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6221962496347605
# p-value      = 8.720002230742564e-152
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6325626587508033
# p-value      = 2.3137086288428735e-152
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6088217721216467
# p-value      = 6.479130132908726e-142
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6106314829679621
# p-value      = 5.509379807215842e-140
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5910607910294234
# p-value      = 9.335389549811513e-137
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6407596695047238
# p-value      = 9.552324589478443e-163
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6011632726014268
# p-value      = 2.664136947033548e-141
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6022584692597239
# p-value      = 7.617525632753215e-135
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5259320353423239
# p-value      = 4.94625114507738e-105
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.2585474344993101
# p-value      = 4.00064860467192e-26
# LR statistic = 434.5/49
# p-value      = 3.305492172555467e-63
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.2623134627192397
# p-value      = 1.3583856895474202e-26
# LR statistic = 436.5/49
# p-value      = 1.3604078850720338e-63
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.2798928610351178
# p-value      = 1.2281776661035226e-29
# LR statistic = 430.6/49
# p-value      = 1.8769183228631842e-62
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.632090508360947
# p-value      = 7.243810242862287e-163
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6258248524559692
# p-value      = 1.1361225887186447e-152
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5801218856425883
# p-value      = 1.0868503300076681e-123
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.34213377918390137
# p-value      = 7.146766466115132e-43
# LR statistic = 526.7/49
# p-value      = 2.8503350432409267e-81
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5578321186719702
# p-value      = 4.010069214976294e-118
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.3678101055057093
# p-value      = 8.721493573740423e-53
# LR statistic = 755.6/49
# p-value      = 2.6060562723354572e-127
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.3948619434681297
# p-value      = 2.490956879520865e-61
# LR statistic = 917.6/49
# p-value      = 1.6411194960206433e-160
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6519074735385902
# p-value      = 1.5661266784716744e-176
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.2608093332000142
# p-value      = 4.773380122977838e-24
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6392967467840129
# p-value      = 4.613432387526364e-169
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5252798908686479
# p-value      = 1.0267868066510527e-111
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.7187688078260959
# p-value      = 2.701884184505819e-220
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6374635021517607
# p-value      = 3.299293660223087e-158
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.4135173229235518
# p-value      = 4.059233713372422e-68
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.576374947720619
# p-value      = 2.356378793831694e-134
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.6170791279362575
# p-value      = 6.230528056420831e-148
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.4913323861539597
# p-value      = 6.731011625106093e-89
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.4847388512004764
# p-value      = 1.3303879209648718e-92
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5517127855584568
# p-value      = 4.301313615739413e-118
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5761185419274715
# p-value      = 3.981509654516877e-129
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.27691542222325766
# p-value      = 1.1462246694621923e-26
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.7743095966009356
# p-value      = 1.5338739322980844e-262
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.5940357809447119
# p-value      = 9.365643744727099e-132
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 5.137894498666855e-30
# best LR 257.1578529974308
# ----------------
# KS statistic = 0.1932111808831813
# p-value      = 7.436575410352832e-14
# LR statistic = 233.2/49
# p-value      = 8.303298533465809e-26
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.607132689964317
# p-value      = 1.676304774108512e-140
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.5194842980015638
# p-value      = 1.3570917752848913e-100
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.3166290369239354
# p-value      = 2.3307875669815055e-34
# LR statistic = 747.2/49
# p-value      = 1.3474325590098989e-125
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.5068703112309211
# p-value      = 2.0314863537330995e-97
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.24329455352861187
# p-value      = 4.547083884932218e-23
# LR statistic = 427.3/49
# p-value      = 8.14123544825101e-62
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.7309317499355986
# p-value      = 2.576887916554269e-228
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.19318016596571908
# p-value      = 1.662792034954597e-14
# LR statistic = 291.6/49
# p-value      = 3.2309012543056716e-36
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.5908247852934156
# p-value      = 2.2858473236850826e-140
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.5773918099234675
# p-value      = 3.6455700343560223e-126
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.36011594669254793
# p-value      = 7.094689671010784e-51
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.2991959327676808
# p-value      = 3.277403492296155e-32
# LR statistic = 548.4/49
# p-value      = 1.437299886203898e-85
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.3239280678016646
# p-value      = 2.0508729090085345e-37
# LR statistic = 698.1/49
# p-value      = 1.2421844697994065e-115
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.29768617099739514
# p-value      = 3.753861348902165e-30
# LR statistic = nan/49
# p-value      = nan
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.5654200327250581
# p-value      = 3.4552103303172926e-122
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.6238661373593599
# p-value      = 8.025711414083118e-151
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.3433840302641904
# p-value      = 2.2098824320076633e-45
# LR statistic = 658.2/49
# p-value      = 1.4296142272785314e-107
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.6915447025034716
# p-value      = 8.180863831041526e-203
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.6182003797335732
# p-value      = 8.845931098732123e-158
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 8.303298533465809e-26
# best LR 233.23275157440293
# ----------------
# KS statistic = 0.20228259254737505
# p-value      = 3.0518726600018455e-15
# LR statistic = 219.4/49
# p-value      = 2.037605606908191e-23
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------
# KS statistic = 0.50296630180549
# p-value      = 9.991788545401136e-98
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------
# KS statistic = 0.30753979906920453
# p-value      = 9.291576247529588e-32
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------
# KS statistic = 0.61935161786276
# p-value      = 2.7186016420938706e-148
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------
# KS statistic = 0.31782943019563586
# p-value      = 3.330731164022704e-34
# LR statistic = nan/49
# p-value      = nan
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------
# KS statistic = 0.590706983158841
# p-value      = 2.7183878611447846e-134
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------
# KS statistic = 0.6083924200529504
# p-value      = 7.462111754370731e-143
# LR statistic = inf/49
# p-value      = 0.0
# best pvalue 2.037605606908191e-23
# best LR 219.38048061758417
# ----------------

# %%
plt.figure(0, figsize = (14,14))

print(best_for_dataset)
#best_for_dataset[0] = ("toy/output/tau_120s_theta_22_axial_5.0mK_transv_15.0mK_p_2.npz",0.1)

i = 1
for dataset,simulation in zip(list_dataset, best_for_dataset):
    plt.subplot(3,2,i)
    i += 1
    print(f" {dataset}, {simulation}")
    
    Time_Simulation, counts, edges =  analysis_function("../" + simulation[0])
    Event_Distribution, counts, edges = analysis_data( "../" + dataset, ZCUTS)

    plt.hist(Event_Distribution, bins = 50, range = (0,330), density = True, color = "black", alpha = .5, label = f"dataset: {dataset}")
    plt.hist(Time_Simulation, bins = 50, range = (0,330), density = True, linestyle = "--", histtype = "step" ,color = "red", label = f"simulation: {simulation[0]}\n" +  simulation[1])
    plt.legend(fontsize = 8)
# Out:
# [('toy/output/tau_20s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 329.72454255250705, pvalue = 2.947967135804536e-43'), ('toy/output/tau_20s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 347.52204514560736, pvalue = 1.3732513341689817e-46'), ('toy/output/tau_20s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 424.2828356077288, pvalue = 3.120456563397431e-61'), ('toy/output/tau_40s_theta_45_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 236.26423469878682, pvalue = 2.4626503075120615e-26'), ('toy/output/tau_40s_theta_45_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 219.38048061758417, pvalue = 2.037605606908191e-23')]
#  v1/ag14100/ag14100.vertex.csv, ('toy/output/tau_20s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 329.72454255250705, pvalue = 2.947967135804536e-43')
# ../v1/ag14100/ag14100.vertex.csv
#    [26850.997-26862.199]=  11.202s |          "MBMF RampDown"[0]          |    1074       61       53       29      499      396     1214      852     1931         6
#
# ../v1/ag14100/ag14100.vertex.csv
#    [26983.913-26995.115]=  11.202s |          "MBMF RampDown"[1]          |    1148       51       53       31      545      420     1317     1208     2690       116
#
# ../v1/ag14100/ag14100.vertex.csv
#    [27116.943-27128.146]=  11.202s |          "MBMF RampDown"[2]          |    1104       56       55       42      545      447     1307     1285     2653       142
#
# 0.0; 11.202000000001135
# 132.91600000000108; 11.202000000001135
# 265.9459999999999; 11.203000000001339
#  v1/ag14106/ag14106.vertex.csv, ('toy/output/tau_20s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 347.52204514560736, pvalue = 1.3732513341689817e-46')
# ../v1/ag14106/ag14106.vertex.csv
#    [23785.519-23796.721]=  11.202s |          "MBMF RampDown"[0]          |    1670       81       83       75     1093      800     2652      958     3535         8
#
# ../v1/ag14106/ag14106.vertex.csv
#    [23918.318-23929.520]=  11.202s |          "MBMF RampDown"[1]          |    1150       60       61       41      534      426     1250     1245     2562        99
#
# ../v1/ag14106/ag14106.vertex.csv
#    [24051.306-24062.508]=  11.202s |          "MBMF RampDown"[2]          |    1162       47       57       46      517      380     1268     1177     2345       105
#
# 0.0; 11.202000000001135
# 132.79899999999907; 11.202000000001135
# 265.78700000000026; 11.202000000001135
#  v1/ag14268/ag14268.vertex.csv, ('toy/output/tau_20s_theta_22_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 424.2828356077288, pvalue = 3.120456563397431e-61')
# ../v1/ag14268/ag14268.vertex.csv
#    [26321.536-26332.738]=  11.202s |          "MBMF RampDown"[0]          |    1109       67       52       46      542      388     1216      814     2373         2
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26454.276-26465.478]=  11.202s |          "MBMF RampDown"[1]          |    1138       56       45       44      565      389     1312     1167     2476        89
#
# ../v1/ag14268/ag14268.vertex.csv
#    [26587.290-26598.492]=  11.202s |          "MBMF RampDown"[2]          |    1071       43       65       31      577      386     1322     1206     2697       121
#
# 0.0; 11.202000000001135
# 132.7400000000016; 11.201999999997497
# 265.7540000000008; 11.201999999997497
#  v1/ag14286/ag14286.vertex.csv, ('toy/output/tau_40s_theta_45_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 236.26423469878682, pvalue = 2.4626503075120615e-26')
# ../v1/ag14286/ag14286.vertex.csv
#    [24671.299-24682.501]=  11.202s |          "MBMF RampDown"[0]          |    1684       95       87       80     1135      801     2645      891     3354         3
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24804.010-24815.212]=  11.202s |          "MBMF RampDown"[1]          |    1124       46       57       37      520      403     1231     1225     2584       104
#
# ../v1/ag14286/ag14286.vertex.csv
#    [24936.880-24948.082]=  11.202s |          "MBMF RampDown"[2]          |    1085       54       45       37      529      359     1282     1290     2478       148
#
# 0.0; 11.202000000001135
# 132.71099999999933; 11.202000000001135
# 265.58100000000195; 11.201999999997497
#  v1/ag14308/ag14308.vertex.csv, ('toy/output/tau_40s_theta_45_axial_5.0mK_transv_5.0mK_p_2.npz', 'Best LR: 219.38048061758417, pvalue = 2.037605606908191e-23')
# ../v1/ag14308/ag14308.vertex.csv
#    [25127.404-25138.606]=  11.202s |          "MBMF RampDown"[0]          |    1141       57       58       45      525      375     1278      874     2206        16
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25260.259-25271.461]=  11.202s |          "MBMF RampDown"[1]          |    1134       61       49       43      525      375     1310     1251     2743       117
#
# ../v1/ag14308/ag14308.vertex.csv
#    [25393.143-25404.345]=  11.202s |          "MBMF RampDown"[2]          |    1096       62       47       40      506      424     1300     1168     2368       106
#
# 0.0; 11.202000000001135
# 132.85499999999956; 11.202000000001135
# 265.7390000000014; 11.202000000001135
